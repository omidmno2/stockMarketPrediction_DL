# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "ولساپا"]
# Out:
#               Date  Symbol  ...    Volume  Value Traded
# 75      2008-12-06  ولساپا  ...    164590     397649440
# 105     2008-12-07  ولساپا  ...    118990     290454590
# 208     2008-12-08  ولساپا  ...     92913     226896546
# 304     2008-12-10  ولساپا  ...     83000     202769000
# 400     2008-12-13  ولساپا  ...     73387     179357828
# ...            ...     ...  ...       ...           ...
# 817403  2021-06-22  ولساپا  ...  39328464  109092185313
# 817789  2021-06-23  ولساپا  ...  41723750  117193496811
# 818103  2021-06-26  ولساپا  ...  70567257  206615169408
# 818550  2021-06-27  ولساپا  ...  27104689   80150048460
# 819154  2021-06-28  ولساپا  ...  33965476   98820530355
#
# [2807 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "ولساپا"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2550)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Collecting ta
#   Downloading ta-0.8.0.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.8.0-py3-none-any.whl size=28895 sha256=af518b449521b9598b18c074aba92fdfd23ed718e38e8352a51081bfe6365559
#   Stored in directory: /root/.cache/pip/wheels/7e/da/86/65cba22446ae2ef148de2079907264ef27feecfb7f51a45e0d
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.8.0
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      |████████████████████████████████| 115 kB 4.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218923 sha256=a0fdf57f22b42782208bccf92b09408f8aefc6f31956cf02dbee19ef46fdb990
#   Stored in directory: /root/.cache/pip/wheels/0b/81/f0/cca85757840e4616a2c6b9fe12569d97d324c27cac60724c58
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
# Calculation of the mentioned indicators
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Last", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html


# 1 - RSI - Relative Strength Index
rsi = pd.DataFrame()
for i in range(6, 21):
    indicator_rsi = ta.momentum.RSIIndicator(close=data.Last, window=i)
    string = "RSI_" + str(i) + "d"
    rsi[string] = indicator_rsi.rsi()


# 2 - Williams %R
williamsR = pd.DataFrame()
for i in range(6, 21):
    indicator_WilliamsR = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=i)
    string = "Williams %R_" + str(i) + "d"
    williamsR[string] = indicator_WilliamsR.williams_r()


# 3 - WMA - Weighted Moving Average
wma = pd.DataFrame()
for i in range(6, 21):
    indicator_wma = ta.trend.WMAIndicator(close=data.Last, window=i)
    string = "WMA_" + str(i) + "d"
    wma[string] = indicator_wma.wma()


# 4 - EMA - Exponential Moving Average
ema = pd.DataFrame()
for i in range(6, 21):
    indicator_ema = ta.trend.EMAIndicator(close=data.Last, window=i)
    string = "EMA_" + str(i) + "d"
    ema[string] = indicator_ema.ema_indicator()


# 5 - SMA - Simple Moving Average
sma = pd.DataFrame()
for i in range(6, 21):
    indicator_sma = ta.trend.SMAIndicator(close=data.Last, window=i)
    string = "SMA_" + str(i) + "d"
    sma[string] = indicator_sma.sma_indicator()


# 6 - HMA - Hull Exponential Moving Average
hma = pd.DataFrame()
for i in range(6, 21):
    string = "HMA_" + str(i) + "d"
    hma[string] = pandas_ta.hma(close=data.Last, length=i)


# 7 - Triple EMA - Triple Exponential Moving Average
tema = pd.DataFrame()
for i in range(6, 21):
    string = "Triple EMA_" + str(i) + "d"
    tema[string] = pandas_ta.tema(close=data.Last, length=i)


# 8 - CCI - Commodity Channel Index
cci = pd.DataFrame()
for i in range(6, 21):
    indicator_cci = ta.trend.CCIIndicator(high=data.High, low=data.Low, close=data.Last, window=i)
    string = "CCI_" + str(i) + "d"
    cci[string] = indicator_cci.cci()


# 9 - CMO - Chande Momentum Oscillator
cmo = pd.DataFrame()
for i in range(6, 21):
    string = "CMO_" + str(i) + "d"
    cmo[string] = pandas_ta.cmo(close=data.Last, length=i)


# 10 - MACD - Moving Average Convergence Divergence
macd = pd.DataFrame()
for i in range(6, 21):
    indicator_macd = ta.trend.MACD(close=data.Last, window_slow=26, window_fast=12, window_sign=9)
    string = "MACD_" + str(i) + "d"
    macd[string] = indicator_macd.macd()


# 11 - PPO - The Percentage Price Oscillator
ppo = pd.DataFrame()
for i in range(6, 21):
    indicator_ppo = ta.momentum.PercentagePriceOscillator(close=data.Last, window_slow=26, window_fast=12, window_sign=9)
    string = "PPO_" + str(i) + "d"
    ppo[string] = indicator_ppo.ppo()


# 12 - ROC - Rate of Change
roc = pd.DataFrame()
for i in range(6, 21):
    indicator_roc = ta.momentum.ROCIndicator(close=data.Last, window=i)
    string = "ROC_" + str(i) + "d"
    roc[string] = indicator_roc.roc()


# 13 - CMF - Chaikin Money Flow
cmf = pd.DataFrame()
for i in range(6, 21):
    string = "CMF_" + str(i) + "d"
    cmf[string] = pandas_ta.cmf(high=data.High, low=data.Low, close=data.Last, volume=data.Volume, open=data.Open, length=i)

    
# 14 - ADX - Average Directional Movement Index (ADX)
adx = pd.DataFrame()
for i in range(6, 21):
    string = "ADX_" + str(i) + "d"
    sec_string = "ADX_" + str(i)
    adx[string] = pandas_ta.adx(high=data.High, low=data.Low, close=data.Last, length=i)[sec_string]

    
# 15 - PSI - Parabolic Stop and Reverse (Parabolic SAR)
psi = pd.DataFrame()
for i in range(6, 21):
    indicator_psi = ta.trend.PSARIndicator(high=data.High, low=data.Low, close=data.Last)
    string = "PSI_" + str(i) + "d"
    psi[string] = indicator_psi.psar()

# %%
rsi = rsi[60:]
williamsR = williamsR[60:]
wma = wma[60:]
ema = ema[60:]
sma = sma[60:]
hma = hma[60:]
tema = tema[60:]
cci = cci[60:]
cmo = cmo[60:]
macd = macd[60:]
ppo = ppo[60:]
roc = roc[60:]
cmf = cmf[60:]
adx = adx[60:]
psi = psi[60:]

# %%
# 15x15 pixel image creation phase
pictures = list()
for i in range(0, len(rsi)):
    pic = pd.DataFrame(index=['6d', '7d', '8d', '9d', '10d', '11d', '12d', '13d', '14d', '15d', '16d', '17d', '18d', '19d', '20d'])
    pic["RSI"] = np.array(rsi[i:i+1].transpose())
    pic["Williams %R"] = np.array(williamsR[i:i+1].transpose())
    pic["WMA"] = np.array(wma[i:i+1].transpose())
    pic["EMA"] = np.array(ema[i:i+1].transpose())
    pic["SMA"] = np.array(sma[i:i+1].transpose())
    pic["HMA"] = np.array(hma[i:i+1].transpose())
    pic["Triple EMA"] = np.array(tema[i:i+1].transpose())
    pic["CCI"] = np.array(cci[i:i+1].transpose())
    pic["CMO"] = np.array(cmo[i:i+1].transpose())
    pic["MACD"] = np.array(macd[i:i+1].transpose())
    pic["PPO"] = np.array(ppo[i:i+1].transpose())
    pic["ROC"] = np.array(roc[i:i+1].transpose())
    pic["CMF"] = np.array(cmf[i:i+1].transpose())
    pic["ADX"] = np.array(adx[i:i+1].transpose())
    pic["PSI"] = np.array(psi[i:i+1].transpose())
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2490

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2538

# %%
len(data.Last)
# Out:
# 2550

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[54:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2484
# 2484

# %%
df = pd.DataFrame()
df['Last'] = data.Last[60:-6]
df['Label'] = bsh_labels
df.head()
# Out:
#             Last  Label
# Date
# 2009-04-05  2510      2
# 2009-04-06  2468      1
# 2009-04-07  2469      2
# 2009-04-08  2468      2
# 2009-04-11  2520      2

# %%
# Showing Buy and Sell strategy(Algorithm 1)
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(data['Last'], label='data',linewidth=0.5, color='blue', alpha = 0.9)
ax.scatter(df.loc[df.Label == 1].index, df.Last[df.Label == 1], label='Buy', marker='^', color='green', alpha=1)
ax.scatter(df.loc[df.Label == 0].index, df.Last[df.Label == 0], label='Sell', marker='v', color='red', alpha=1)
ax.set_title('data' + " Price History with buy and sell signals",fontsize=10, backgroundcolor='blue', color='white')
ax.set_ylabel('Last Price' , fontsize=12)
legend = ax.legend()
ax.grid()
plt.tight_layout()
plt.show()

# %%
# 15×15 pixel labeled sample images after image creation phase for algorithm 1
plt.imshow(pictures[0], interpolation='nearest') # Hold
plt.show()
plt.imshow(pictures[12], interpolation='nearest') # Sell
plt.show()
plt.imshow(pictures[1], interpolation='nearest') # Buy
plt.show()

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(15, 15, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 13, 13, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 128)         73856
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 128)        0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 388,227
# Trainable params: 388,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 14s 20ms/step - loss: 19.3959 - accuracy: 0.8286 - val_loss: 0.4756 - val_accuracy: 0.9542
# Epoch 2/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.9392 - accuracy: 0.8759 - val_loss: 0.5896 - val_accuracy: 0.9542
# Epoch 3/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.6876 - accuracy: 0.9077 - val_loss: 0.3416 - val_accuracy: 0.9542
# Epoch 4/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.7517 - accuracy: 0.9064 - val_loss: 0.2984 - val_accuracy: 0.9542
# Epoch 5/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.5859 - accuracy: 0.9100 - val_loss: 0.2934 - val_accuracy: 0.9542
# Epoch 6/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.7784 - accuracy: 0.9036 - val_loss: 0.3637 - val_accuracy: 0.9542
# Epoch 7/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.6849 - accuracy: 0.9164 - val_loss: 0.3316 - val_accuracy: 0.9542
# Epoch 8/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.5216 - accuracy: 0.9114 - val_loss: 0.4050 - val_accuracy: 0.9542
# Epoch 9/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4570 - accuracy: 0.9168 - val_loss: 0.3128 - val_accuracy: 0.9542
# Epoch 10/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0
100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.3374 - accuracy: 0.9195 - val_loss: 0.2270 - val_accuracy: 0.9542
# Epoch 88/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3648 - accuracy: 0.9195 - val_loss: 0.2073 - val_accuracy: 0.9542
# Epoch 89/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3192 - accuracy: 0.9195 - val_loss: 0.2027 - val_accuracy: 0.9542
# Epoch 90/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4282 - accuracy: 0.9214 - val_loss: 0.2902 - val_accuracy: 0.9542
# Epoch 91/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3070 - accuracy: 0.9195 - val_loss: 0.5932 - val_accuracy: 0.9542
# Epoch 92/100
# 69/69 [==============================] - 1s 13ms/step - loss: 4.7196 - accuracy: 0.9177 - val_loss: 0.3700 - val_accuracy: 0.9542
# Epoch 93/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.8809 - accuracy: 0.9177 - val_loss: 0.2312 - val_accuracy: 0.9542
# Epoch 94/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3219 - accuracy: 0.9195 - val_loss: 0.2589 - val_accuracy: 0.9542
# Epoch 95/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3493 - accuracy: 0.9200 - val_loss: 0.2441 - val_accuracy: 0.9542
# Epoch 96/100
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0709 - accuracy: 0.9177 - val_loss: 0.2721 - val_accuracy: 0.9542
# Epoch 97/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3000 - accuracy: 0.9195 - val_loss: 0.1987 - val_accuracy: 0.9542
# Epoch 98/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3144 - accuracy: 0.9182 - val_loss: 2.6175 - val_accuracy: 0.9542
# Epoch 99/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3126 - accuracy: 0.9200 - val_loss: 0.3434 - val_accuracy: 0.9542
# Epoch 100/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6237 - accuracy: 0.9186 - val_loss: 0.1930 - val_accuracy: 0.9542

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test another labaling method(different buy and sell strategy)

# %%
# SMA(Simple Moving Average) BUY and SELL Strategy

short_window = 40
long_window = 100

signals = pd.DataFrame(index=data.index)
signals['signal'] = 0.0

signals['short_mavg'] = data['Last'].rolling(window=short_window, min_periods=1, center=False).mean()
signals['long_mavg'] = data['Last'].rolling(window=long_window, min_periods=1, center=False).mean()
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0, 0.0)   

# Generate trading orders
signals['positions'] = signals['signal'].diff()

signals
# Out:
#             signal   short_mavg    long_mavg  positions
# Date
# 2008-12-06     0.0  2416.000000  2416.000000        NaN
# 2008-12-07     0.0  2428.500000  2428.500000        0.0
# 2008-12-08     0.0  2433.333333  2433.333333        0.0
# 2008-12-10     0.0  2435.750000  2435.750000        0.0
# 2008-12-13     0.0  2437.400000  2437.400000        0.0
# ...            ...          ...          ...        ...
# 2020-05-17     1.0  5441.150000  3855.470000        0.0
# 2020-05-18     1.0  5533.450000  3904.470000        0.0
# 2020-05-19     1.0  5625.050000  3951.710000        0.0
# 2020-05-20     1.0  5712.550000  3997.410000        0.0
# 2020-05-23     1.0  5789.125000  4040.530000        0.0
#
# [2550 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(data['Last'] , label='data' ,linewidth=0.5, color='blue', alpha=0.9)
ax.plot(signals['short_mavg'], label='SMA40', alpha=0.85)
ax.plot(signals['long_mavg'], label='SMA100', alpha=0.85)
ax.scatter(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], label = 'Buy', marker='^', color='green', alpha=1)
ax.scatter(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], label = 'Sell', marker='v', color='red', alpha=1)
ax.set_title('data' + " Price History with buy and sell signals",fontsize=10, backgroundcolor='blue', color='white')
ax.set_ylabel('Last Price', fontsize=12)
legend = ax.legend()
ax.grid()
plt.tight_layout()
plt.show()

# %%
bs_labels = signals.positions[60:-6]

# %%
len(bs_labels)
# Out:
# 2484

# %%
len(pictures)
# Out:
# 2484

# %%
# 15×15 pixel labeled sample images after image creation phase for SMA buy and sell strategy
plt.imshow(pictures[0], interpolation='nearest') # Hold
plt.show()
plt.imshow(pictures[165], interpolation='nearest') # Sell
plt.show()
plt.imshow(pictures[194], interpolation='nearest') # Buy
plt.show()

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bs_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bs_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(15, 15, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 13, 13, 32)        320
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_6 (Conv2D)           (None, 9, 9, 128)         73856
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 128)               147584
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 388,227
# Trainable params: 388,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 16ms/step - loss: 6.1985 - accuracy: 0.9691 - val_loss: 0.1509 - val_accuracy: 0.9965
# Epoch 2/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5545 - accuracy: 0.9805 - val_loss: 0.0595 - val_accuracy: 0.9965
# Epoch 3/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2567 - accuracy: 0.9855 - val_loss: 0.0600 - val_accuracy: 0.9965
# Epoch 4/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2449 - accuracy: 0.9895 - val_loss: 0.0244 - val_accuracy: 0.9965
# Epoch 5/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2066 - accuracy: 0.9895 - val_loss: 0.0986 - val_accuracy: 0.9965
# Epoch 6/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2161 - accuracy: 0.9895 - val_loss: 0.0273 - val_accuracy: 0.9965
# Epoch 7/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2425 - accuracy: 0.9895 - val_loss: 0.0288 - val_accuracy: 0.9965
# Epoch 8/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2013 - accuracy: 0.9895 - val_loss: 0.0456 - val_accuracy: 0.9965
# Epoch 9/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1666 - accuracy: 0.9895 - val_loss: 0.1374 - val_accuracy: 0.9965
# Epoch 10/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2397 - accuracy: 0.9895 - val_loss: 0.0427 - val_accuracy: 0.9965
# Epoch 11/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1927 - accuracy: 0.9895 - val_loss: 0.1036 - val_accuracy: 0.9965
# Epoch 12/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1993 - accuracy: 0.9895 - val_loss: 0.0648 - val_accuracy: 0.9965
# Epoch 13/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1400 - accuracy: 0.9895 - val_loss: 0.4266 - val_accuracy: 0.9965
# Epoch 14/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1618 - accuracy: 0.9895 - val_loss: 0.2255 - val_accuracy: 0.9965
# Epoch 15/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1963 - accuracy: 0.9895 - val_loss: 0.0696 - val_accuracy: 0.9965
# Epoch 16/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1899 - accuracy: 0.9895 - val_loss: 0.2100 - val_accuracy: 0.9965
# Epoch 17/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3052 - accuracy: 0.9895 - val_loss: 0.2159 - val_accuracy: 0.9965
# Epoch 18/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2144 - accuracy: 0.9895 - val_loss: 0.2115 - val_accuracy: 0.9965
# Epoch 19/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2065 - accuracy: 0.9895 - val_loss: 0.0770 - val_accuracy: 0.9965
# Epoch 20/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0720 - accuracy: 0.9895 - val_loss: 0.0341 - val_accuracy: 0.9965
# Epoch 21/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0653 - accuracy: 0.9895 - val_loss: 0.5591 - val_accuracy: 0.9965
# Epoch 22/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1942 - accuracy: 0.9895 - val_loss: 0.0787 - val_accuracy: 0.9965
# Epoch 23/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0847 - accuracy: 0.9895 - val_loss: 0.1735 - val_accuracy: 0.9965
# Epoch 24/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3294 - accuracy: 0.9895 - val_loss: 0.4050 - val_accuracy: 0.9965
# Epoch 25/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1236 - accuracy: 0.9895 - val_loss: 0.3119 - val_accuracy: 0.9965
# Epoch 26/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2471 - accuracy: 0.9895 - val_loss: 0.2101 - val_accuracy: 0.9965
# Epoch 27/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0774 - accuracy: 0.9895 - val_loss: 0.0330 - val_accuracy: 0.9965
# Epoch 28/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0673 - accuracy: 0.9895 - val_loss: 0.0325 - val_accuracy: 0.9965
# Epoch 29/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1571 - accuracy: 0.9895 - val_loss: 0.8631 - val_accuracy: 0.9965
# Epoch 30/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0844 - accuracy: 0.9895 - val_loss: 0.0770 - val_accuracy: 0.9965
# Epoch 31/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0665 - accuracy: 0.9895 - val_loss: 0.4854 - val_accuracy: 0.9965
# Epoch 32/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0977 - accuracy: 0.9895 - val_loss: 0.2337 - val_accuracy: 0.9965
# Epoch 33/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2061 - accuracy: 0.9895 - val_loss: 1.3763 - val_accuracy: 0.9965
# Epoch 34/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1955 - accuracy: 0.9895 - val_loss: 0.3349 - val_accuracy: 0.9965
# Epoch 35/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1239 - accuracy: 0.9895 - val_loss: 0.6578 - val_accuracy: 0.9965
# Epoch 36/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5475 - accuracy: 0.9895 - val_loss: 0.2911 - val_accuracy: 0.9965
# Epoch 37/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0685 - accuracy: 0.9895 - val_loss: 0.5202 - val_accuracy: 0.9965
# Epoch 38/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0744 - accuracy: 0.9895 - val_loss: 0.4347 - val_accuracy: 0.9965
# Epoch 39/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5930 - accuracy: 0.9895 - val_loss: 0.7981 - val_accuracy: 0.9965
# Epoch 40/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0963 - accuracy: 0.9895 - val_loss: 0.3947 - val_accuracy: 0.9965
# Epoch 41/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0678 - accuracy: 0.9895 - val_loss: 0.7541 - val_accuracy: 0.9965
# Epoch 42/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4240 - accuracy: 0.9895 - val_loss: 0.7437 - val_accuracy: 0.9965
# Epoch 43/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0906 - accuracy: 0.9895 - val_loss: 0.2189 - val_accuracy: 0.9965
# Epoch 44/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0663 - accuracy: 0.9895 - val_loss: 1.9387 - val_accuracy: 0.9965
# Epoch 45/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2224 - accuracy: 0.9895 - val_loss: 0.2319 - val_accuracy: 0.9965
# Epoch 46/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5033 - accuracy: 0.9895 - val_loss: 0.1666 - val_accuracy: 0.9965
# Epoch 47/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0682 - accuracy: 0.9895 - val_loss: 0.4409 - val_accuracy: 0.9965
# Epoch 48/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.2058 - accuracy: 0.9895 - val_loss: 0.1878 - val_accuracy: 0.9965
# Epoch 49/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0673 - accuracy: 0.9895 - val_loss: 0.3073 - val_accuracy: 0.9965
# Epoch 50/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5320 - accuracy: 0.9895 - val_loss: 0.2957 - val_accuracy: 0.9965
# Epoch 51/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0692 - accuracy: 0.9895 - val_loss: 0.4945 - val_accuracy: 0.9965
# Epoch 52/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0758 - accuracy: 0.9895 - val_loss: 0.2867 - val_accuracy: 0.9965
# Epoch 53/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0682 - accuracy: 0.9895 - val_loss: 3.7560 - val_accuracy: 0.9965
# Epoch 54/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5918 - accuracy: 0.9895 - val_loss: 0.3681 - val_accuracy: 0.9965
# Epoch 55/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0665 - accuracy: 0.9895 - val_loss: 1.0520 - val_accuracy: 0.9965
# Epoch 56/100
# 69/69 [==============================] - 1s 13ms/step - loss: 20.8647 - accuracy: 0.9895 - val_loss: 0.7533 - val_accuracy: 0.9965
# Epoch 57/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0655 - accuracy: 0.9895 - val_loss: 0.8320 - val_accuracy: 0.9965
# Epoch 58/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0643 - accuracy: 0.9895 - val_loss: 1.9221 - val_accuracy: 0.9965
# Epoch 59/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2875 - accuracy: 0.9895 - val_loss: 0.0275 - val_accuracy: 0.9965
# Epoch 60/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0654 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 61/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0678 - accuracy: 0.9895 - val_loss: 0.0271 - val_accuracy: 0.9965
# Epoch 62/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1806 - accuracy: 0.9895 - val_loss: 0.9416 - val_accuracy: 0.9965
# Epoch 63/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.0909 - accuracy: 0.9895 - val_loss: 0.3485 - val_accuracy: 0.9965
# Epoch 64/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0685 - accuracy: 0.9895 - val_loss: 0.4881 - val_accuracy: 0.9965
# Epoch 65/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1528 - accuracy: 0.9895 - val_loss: 1.5738 - val_accuracy: 0.9965
# Epoch 66/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2036 - accuracy: 0.9895 - val_loss: 0.5289 - val_accuracy: 0.9965
# Epoch 67/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0758 - accuracy: 0.9895 - val_loss: 0.0273 - val_accuracy: 0.9965
# Epoch 68/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0647 - accuracy: 0.9895 - val_loss: 0.0266 - val_accuracy: 0.9965
# Epoch 69/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0691 - accuracy: 0.9895 - val_loss: 0.0272 - val_accuracy: 0.9965
# Epoch 70/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0684 - accuracy: 0.9895 - val_loss: 0.0274 - val_accuracy: 0.9965
# Epoch 71/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0675 - accuracy: 0.9895 - val_loss: 0.0273 - val_accuracy: 0.9965
# Epoch 72/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0714 - accuracy: 0.9895 - val_loss: 0.0273 - val_accuracy: 0.9965
# Epoch 73/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0670 - accuracy: 0.9895 - val_loss: 0.0272 - val_accuracy: 0.9965
# Epoch 74/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0685 - accuracy: 0.9895 - val_loss: 0.0272 - val_accuracy: 0.9965
# Epoch 75/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0688 - accuracy: 0.9895 - val_loss: 0.0270 - val_accuracy: 0.9965
# Epoch 76/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0690 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 77/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0688 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 78/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0689 - accuracy: 0.9895 - val_loss: 0.0271 - val_accuracy: 0.9965
# Epoch 79/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0690 - accuracy: 0.9895 - val_loss: 0.0264 - val_accuracy: 0.9965
# Epoch 80/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0681 - accuracy: 0.9895 - val_loss: 0.0265 - val_accuracy: 0.9965
# Epoch 81/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0680 - accuracy: 0.9895 - val_loss: 0.0268 - val_accuracy: 0.9965
# Epoch 82/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0690 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 83/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0674 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 84/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0661 - accuracy: 0.9895 - val_loss: 0.0265 - val_accuracy: 0.9965
# Epoch 85/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0697 - accuracy: 0.9895 - val_loss: 0.0271 - val_accuracy: 0.9965
# Epoch 86/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0681 - accuracy: 0.9895 - val_loss: 0.0270 - val_accuracy: 0.9965
# Epoch 87/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0662 - accuracy: 0.9895 - val_loss: 0.0265 - val_accuracy: 0.9965
# Epoch 88/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0704 - accuracy: 0.9895 - val_loss: 0.0268 - val_accuracy: 0.9965
# Epoch 89/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0667 - accuracy: 0.9895 - val_loss: 0.0268 - val_accuracy: 0.9965
# Epoch 90/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0679 - accuracy: 0.9895 - val_loss: 0.0264 - val_accuracy: 0.9965
# Epoch 91/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0675 - accuracy: 0.9895 - val_loss: 0.0264 - val_accuracy: 0.9965
# Epoch 92/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0684 - accuracy: 0.9895 - val_loss: 0.0265 - val_accuracy: 0.9965
# Epoch 93/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0699 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 94/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0683 - accuracy: 0.9895 - val_loss: 0.0271 - val_accuracy: 0.9965
# Epoch 95/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0705 - accuracy: 0.9895 - val_loss: 0.0273 - val_accuracy: 0.9965
# Epoch 96/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0674 - accuracy: 0.9895 - val_loss: 0.0270 - val_accuracy: 0.9965
# Epoch 97/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0682 - accuracy: 0.9895 - val_loss: 0.0269 - val_accuracy: 0.9965
# Epoch 98/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0722 - accuracy: 0.9895 - val_loss: 0.0271 - val_accuracy: 0.9965
# Epoch 99/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0674 - accuracy: 0.9895 - val_loss: 0.0271 - val_accuracy: 0.9965
# Epoch 100/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.0680 - accuracy: 0.9895 - val_loss: 0.0267 - val_accuracy: 0.9965

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2008-12-06       2490  2416  2416  ...             66  164590     397649440
# 2008-12-07       2439  2441  2441  ...             47  118990     290454590
# 2008-12-08       2440  2442  2443  ...             41   92913     226896546
# 2008-12-10       2441  2443  2443  ...             29   83000     202769000
# 2008-12-13       2442  2444  2444  ...             33   73387     179357828
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[59:-6]
len(ud_labels)
# Out:
# 2484

# %%
len(pictures)
# Out:
# 2484

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(15, 15, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 13, 13, 32)        320
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_10 (Conv2D)          (None, 9, 9, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 128)               147584
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 387,969
# Trainable params: 387,969
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 16ms/step - loss: 12.0336 - accuracy: 0.4968 - val_loss: 3.5605 - val_accuracy: 0.5739
# Epoch 2/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.0060 - accuracy: 0.4968 - val_loss: 0.6704 - val_accuracy: 0.5739
# Epoch 3/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7745 - accuracy: 0.4968 - val_loss: 0.7261 - val_accuracy: 0.5739
# Epoch 4/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7173 - accuracy: 0.4968 - val_loss: 0.6668 - val_accuracy: 0.5739
# Epoch 5/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6900 - accuracy: 0.4968 - val_loss: 0.6568 - val_accuracy: 0.5739
# Epoch 6/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6958 - accuracy: 0.4968 - val_loss: 0.6191 - val_accuracy: 0.5739
# Epoch 7/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6814 - accuracy: 0.4968 - val_loss: 0.6473 - val_accuracy: 0.5739
# Epoch 8/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6820 - accuracy: 0.4968 - val_loss: 0.5889 - val_accuracy: 0.5739
# Epoch 9/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6524 - accuracy: 0.4968 - val_loss: 0.6117 - val_accuracy: 0.5739
# Epoch 10/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6438 - accuracy: 0.4968 - val_loss: 0.5929 - val_accuracy: 0.5739
# Epoch 11/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6227 - accuracy: 0.4968 - val_loss: 0.6116 - val_accuracy: 0.5739
# Epoch 12/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.
100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.5297 - accuracy: 0.4968 - val_loss: 0.8149 - val_accuracy: 0.5739
# Epoch 74/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.5184 - accuracy: 0.4968 - val_loss: 0.5811 - val_accuracy: 0.5739
# Epoch 75/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4879 - accuracy: 0.4968 - val_loss: 0.5457 - val_accuracy: 0.5739
# Epoch 76/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5594 - accuracy: 0.4968 - val_loss: 0.8948 - val_accuracy: 0.5739
# Epoch 77/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.4951 - accuracy: 0.4968 - val_loss: 1.2437 - val_accuracy: 0.5739
# Epoch 78/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6173 - accuracy: 0.4968 - val_loss: 0.5340 - val_accuracy: 0.5739
# Epoch 79/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4765 - accuracy: 0.4968 - val_loss: 0.7413 - val_accuracy: 0.5739
# Epoch 80/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5180 - accuracy: 0.4968 - val_loss: 0.6648 - val_accuracy: 0.5739
# Epoch 81/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5027 - accuracy: 0.4968 - val_loss: 0.5412 - val_accuracy: 0.5739
# Epoch 82/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4897 - accuracy: 0.4968 - val_loss: 0.8558 - val_accuracy: 0.5739
# Epoch 83/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.5136 - accuracy: 0.4968 - val_loss: 0.8132 - val_accuracy: 0.5739
# Epoch 84/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7691 - accuracy: 0.4968 - val_loss: 0.5499 - val_accuracy: 0.5739
# Epoch 85/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4917 - accuracy: 0.4968 - val_loss: 0.7972 - val_accuracy: 0.5739
# Epoch 86/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5457 - accuracy: 0.4968 - val_loss: 0.7151 - val_accuracy: 0.5739
# Epoch 87/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5319 - accuracy: 0.4968 - val_loss: 0.7288 - val_accuracy: 0.5739
# Epoch 88/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5023 - accuracy: 0.4968 - val_loss: 0.6934 - val_accuracy: 0.5739
# Epoch 89/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6720 - accuracy: 0.4968 - val_loss: 0.6134 - val_accuracy: 0.5739
# Epoch 90/100
# 69/69 [==============================] - 1s 13ms/step - loss: 2.2903 - accuracy: 0.4968 - val_loss: 0.6896 - val_accuracy: 0.5739
# Epoch 91/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4609 - accuracy: 0.4968 - val_loss: 0.9482 - val_accuracy: 0.5739
# Epoch 92/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4695 - accuracy: 0.4968 - val_loss: 1.0121 - val_accuracy: 0.5739
# Epoch 93/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4944 - accuracy: 0.4968 - val_loss: 1.2112 - val_accuracy: 0.5739
# Epoch 94/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5922 - accuracy: 0.4968 - val_loss: 0.4958 - val_accuracy: 0.5739
# Epoch 95/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4875 - accuracy: 0.4968 - val_loss: 0.7256 - val_accuracy: 0.5739
# Epoch 96/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4783 - accuracy: 0.4968 - val_loss: 0.7880 - val_accuracy: 0.5739
# Epoch 97/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4965 - accuracy: 0.4968 - val_loss: 1.0327 - val_accuracy: 0.5739
# Epoch 98/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5855 - accuracy: 0.4968 - val_loss: 1.3964 - val_accuracy: 0.5739
# Epoch 99/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.4879 - accuracy: 0.4968 - val_loss: 1.0236 - val_accuracy: 0.5739
# Epoch 100/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.4649 - accuracy: 0.4968 - val_loss: 0.5242 - val_accuracy: 0.5739

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
