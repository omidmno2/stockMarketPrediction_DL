# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "وغدير"]
# Out:
#               Date Symbol  ...    Volume  Value Traded
# 4447    2009-02-01  وغدير  ...  20335924   34724345237
# 4569    2009-02-02  وغدير  ...   1835207    3042332902
# 4708    2009-02-03  وغدير  ...   2524795    4090167900
# 4840    2009-02-04  وغدير  ...   2527581    3973357332
# 4968    2009-02-07  وغدير  ...   4698245    7186955357
# ...            ...    ...  ...       ...           ...
# 817362  2021-06-22  وغدير  ...  21593318  236133450920
# 817675  2021-06-23  وغدير  ...  74474963  848982027130
# 818116  2021-06-26  وغدير  ...  60215914  713830827180
# 818687  2021-06-27  وغدير  ...  27942565  329721388620
# 819141  2021-06-28  وغدير  ...  26490881  308318403750
#
# [2836 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "وغدير"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2560)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Collecting ta
#   Downloading ta-0.8.0.tar.gz (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.8.0-py3-none-any.whl size=28895 sha256=a1c530f48f529e804920a4b80aa95944cd9cca503f5cdd23f2143586d10acd30
#   Stored in directory: /root/.cache/pip/wheels/7e/da/86/65cba22446ae2ef148de2079907264ef27feecfb7f51a45e0d
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.8.0
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      |████████████████████████████████| 115 kB 4.4 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218923 sha256=3b1b62906f7a1fa0978a1c95b1cfc51a969c3f3415f28c5875aff1931061740c
#   Stored in directory: /root/.cache/pip/wheels/0b/81/f0/cca85757840e4616a2c6b9fe12569d97d324c27cac60724c58
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
# Calculation of the mentioned indicators
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators

import pandas_ta
#https://github.com/twopirllc/pandas-ta

# 1 - RSI - Relative Strength Index
rsi = pd.DataFrame()
for i in range(6, 21):
    indicator_rsi = ta.momentum.RSIIndicator(close=data.Last, window=i)
    string = "RSI_" + str(i) + "d"
    rsi[string] = indicator_rsi.rsi()


# 2 - Williams %R
williamsR = pd.DataFrame()
for i in range(6, 21):
    indicator_WilliamsR = ta.momentum.WilliamsRIndicator(high=data.High,
                                                         low=data.Low,
                                                         close=data.Last,
                                                         lbp=i)
    string = "Williams %R_" + str(i) + "d"
    williamsR[string] = indicator_WilliamsR.williams_r()


# 3 - WMA - Weighted Moving Average
wma = pd.DataFrame()
for i in range(6, 21):
    indicator_wma = ta.trend.WMAIndicator(close=data.Last, window=i)
    string = "WMA_" + str(i) + "d"
    wma[string] = indicator_wma.wma()


# 4 - EMA - Exponential Moving Average
ema = pd.DataFrame()
for i in range(6, 21):
    indicator_ema = ta.trend.EMAIndicator(close=data.Last, window=i)
    string = "EMA_" + str(i) + "d"
    ema[string] = indicator_ema.ema_indicator()


# 5 - SMA - Simple Moving Average
sma = pd.DataFrame()
for i in range(6, 21):
    indicator_sma = ta.trend.SMAIndicator(close=data.Last, window=i)
    string = "SMA_" + str(i) + "d"
    sma[string] = indicator_sma.sma_indicator()


# 6 - HMA - Hull Exponential Moving Average
hma = pd.DataFrame()
for i in range(6, 21):
    string = "HMA_" + str(i) + "d"
    hma[string] = pandas_ta.hma(close=data.Last, length=i)


# 7 - Triple EMA - Triple Exponential Moving Average
tema = pd.DataFrame()
for i in range(6, 21):
    string = "Triple EMA_" + str(i) + "d"
    tema[string] = pandas_ta.tema(close=data.Last, length=i)


# 8 - CCI - Commodity Channel Index
cci = pd.DataFrame()
for i in range(6, 21):
    indicator_cci = ta.trend.CCIIndicator(high=data.High,
                                          low=data.Low,
                                          close=data.Last,
                                          window=i)
    string = "CCI_" + str(i) + "d"
    cci[string] = indicator_cci.cci()


# 9 - CMO - Chande Momentum Oscillator
cmo = pd.DataFrame()
for i in range(6, 21):
    string = "CMO_" + str(i) + "d"
    cmo[string] = pandas_ta.cmo(close=data.Last, length=i)


# 10 - MACD - Moving Average Convergence Divergence
macd = pd.DataFrame()
for i in range(6, 21):
    indicator_macd = ta.trend.MACD(close=data.Last,
                                   window_slow=26,
                                   window_fast=12,
                                   window_sign=9)
    string = "MACD_" + str(i) + "d"
    macd[string] = indicator_macd.macd()


# 11 - PPO - The Percentage Price Oscillator
ppo = pd.DataFrame()
for i in range(6, 21):
    indicator_ppo = ta.momentum.PercentagePriceOscillator(close=data.Last,
                                                          window_slow=26,
                                                          window_fast=12, 
                                                          window_sign=9)
    string = "PPO_" + str(i) + "d"
    ppo[string] = indicator_ppo.ppo()


# 12 - ROC - Rate of Change
roc = pd.DataFrame()
for i in range(6, 21):
    indicator_roc = ta.momentum.ROCIndicator(close=data.Last, window=i)
    string = "ROC_" + str(i) + "d"
    roc[string] = indicator_roc.roc()


# 13 - CMF - Chaikin Money Flow
cmf = pd.DataFrame()
for i in range(6, 21):
    string = "CMF_" + str(i) + "d"
    cmf[string] = pandas_ta.cmf(high=data.High, low=data.Low,
                                close=data.Last, volume=data.Volume,
                                open=data.Open, length=i)

    
# 14 - ADX - Average Directional Movement Index (ADX)
adx = pd.DataFrame()
for i in range(6, 21):
    string = "ADX_" + str(i) + "d"
    sec_string = "ADX_" + str(i)
    adx[string] = pandas_ta.adx(high=data.High, low=data.Low,
                                close=data.Last, length=i)[sec_string]

    
# 15 - PSI - Parabolic Stop and Reverse (Parabolic SAR)
psi = pd.DataFrame()
for i in range(6, 21):
    indicator_psi = ta.trend.PSARIndicator(high=data.High,
                                           low=data.Low,
                                           close=data.Last)
    string = "PSI_" + str(i) + "d"
    psi[string] = indicator_psi.psar()

# %%
rsi = rsi[60:]
williamsR = williamsR[60:]
wma = wma[60:]
ema = ema[60:]
sma = sma[60:]
hma = hma[60:]
tema = tema[60:]
cci = cci[60:]
cmo = cmo[60:]
macd = macd[60:]
ppo = ppo[60:]
roc = roc[60:]
cmf = cmf[60:]
adx = adx[60:]
psi = psi[60:]

# %%
# 15x15 pixel image creation phase
pictures = list()
for i in range(0, len(rsi)):
    pic = pd.DataFrame(index=['6d', '7d', '8d', '9d', '10d',
                              '11d', '12d', '13d', '14d', '15d',
                              '16d', '17d', '18d', '19d', '20d'])
    pic["RSI"] = np.array(rsi[i:i+1].transpose())
    pic["Williams %R"] = np.array(williamsR[i:i+1].transpose())
    pic["WMA"] = np.array(wma[i:i+1].transpose())
    pic["EMA"] = np.array(ema[i:i+1].transpose())
    pic["SMA"] = np.array(sma[i:i+1].transpose())
    pic["HMA"] = np.array(hma[i:i+1].transpose())
    pic["Triple EMA"] = np.array(tema[i:i+1].transpose())
    pic["CCI"] = np.array(cci[i:i+1].transpose())
    pic["CMO"] = np.array(cmo[i:i+1].transpose())
    pic["MACD"] = np.array(macd[i:i+1].transpose())
    pic["PPO"] = np.array(ppo[i:i+1].transpose())
    pic["ROC"] = np.array(roc[i:i+1].transpose())
    pic["CMF"] = np.array(cmf[i:i+1].transpose())
    pic["ADX"] = np.array(adx[i:i+1].transpose())
    pic["PSI"] = np.array(psi[i:i+1].transpose())
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2500

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2548

# %%
len(data.Last)
# Out:
# 2560

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[54:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2494
# 2494

# %%
df = pd.DataFrame()
df['Last'] = data.Last[60:-6]
df['Label'] = bsh_labels
df.head()
# Out:
#             Last  Label
# Date
# 2009-05-19  1700      2
# 2009-05-20  1719      2
# 2009-05-23  1735      0
# 2009-05-24  1691      2
# 2009-05-25  1721      2

# %%
# Showing Buy and Sell strategy(Algorithm 1)
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(data['Last'], label='data',linewidth=0.5, color='blue', alpha = 0.9)
ax.scatter(df.loc[df.Label == 1].index, df.Last[df.Label == 1], label='Buy', marker='^', color='green', alpha=1)
ax.scatter(df.loc[df.Label == 0].index, df.Last[df.Label == 0], label='Sell', marker='v', color='red', alpha=1)
ax.set_title('data' + " Price History with buy and sell signals",fontsize=10, backgroundcolor='blue', color='white')
ax.set_ylabel('Last Price' , fontsize=12)
legend = ax.legend()
ax.grid()
plt.tight_layout()
plt.show()

# %%
# 15×15 pixel labeled sample images after image creation phase for algorithm 1
plt.imshow(pictures[0], interpolation='nearest') # Hold
plt.show()
plt.imshow(pictures[2], interpolation='nearest') # Sell
plt.show()
plt.imshow(pictures[5], interpolation='nearest') # Buy
plt.show()

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                           input_shape=(15, 15, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100,
                    validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 13, 13, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 128)         73856
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 128)        0
#  )
#
#  dropout (Dropout)           (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 388,227
# Trainable params: 388,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 15s 20ms/step - loss: 13.9234 - accuracy: 0.8309 - val_loss: 0.3875 - val_accuracy: 0.9354
# Epoch 2/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.7499 - accuracy: 0.8882 - val_loss: 1.3813 - val_accuracy: 0.9354
# Epoch 3/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.6136 - accuracy: 0.9191 - val_loss: 0.3047 - val_accuracy: 0.9354
# Epoch 4/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.5378 - accuracy: 0.9214 - val_loss: 0.2782 - val_accuracy: 0.9354
# Epoch 5/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4637 - accuracy: 0.9209 - val_loss: 0.2822 - val_accuracy: 0.9354
# Epoch 6/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4658 - accuracy: 0.9186 - val_loss: 0.4728 - val_accuracy: 0.9354
# Epoch 7/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4201 - accuracy: 0.9227 - val_loss: 0.3198 - val_accuracy: 0.9354
# Epoch 8/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4182 - accuracy: 0.9227 - val_loss: 0.3592 - val_accuracy: 0.9354
# Epoch 9/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.3651 - accuracy: 0.9223 - val_loss: 0.3329 - val_accuracy: 0.9354
# Epoch 10/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4202 - accuracy: 0.9227 - val_loss: 0.2703 - val_accuracy: 0.9354
# Epoch 11/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.4241 - accuracy: 0.9223 - val_loss: 0.2734 - val_accuracy: 0.9354
# Epoch 12/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.
100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3120 - accuracy: 0.9195 - val_loss: 0.2908 - val_accuracy: 0.9354
# Epoch 98/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.5005 - accuracy: 0.9223 - val_loss: 0.3616 - val_accuracy: 0.9354
# Epoch 99/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.3908 - accuracy: 0.9223 - val_loss: 0.3641 - val_accuracy: 0.9354
# Epoch 100/100
# 69/69 [==============================] - 1s 18ms/step - loss: 0.3785 - accuracy: 0.9223 - val_loss: 0.2611 - val_accuracy: 0.9354

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test another labaling method(different buy and sell strategy)

# %%
# SMA(Simple Moving Average) BUY and SELL Strategy

short_window = 30
long_window = 100

signals = pd.DataFrame(index=data.index)
signals['signal'] = 0.0

signals['short_mavg'] = data['Last'].rolling(window=short_window, min_periods=1, center=False).mean()
signals['long_mavg'] = data['Last'].rolling(window=long_window, min_periods=1, center=False).mean()
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0, 0.0)   

# Generate trading orders
signals['positions'] = signals['signal'].diff()

signals
# Out:
#             signal   short_mavg    long_mavg  positions
# Date
# 2009-02-01     0.0  1720.000000  1720.000000        NaN
# 2009-02-02     0.0  1688.500000  1688.500000        0.0
# 2009-02-03     0.0  1665.666667  1665.666667        0.0
# 2009-02-04     0.0  1642.250000  1642.250000        0.0
# 2009-02-07     0.0  1635.800000  1635.800000        0.0
# ...            ...          ...          ...        ...
# 2020-04-19     1.0  5220.400000  4226.270000        0.0
# 2020-04-20     1.0  5304.366667  4271.970000        0.0
# 2020-04-21     1.0  5395.666667  4320.770000        0.0
# 2020-04-22     1.0  5490.033333  4372.370000        0.0
# 2020-04-28     1.0  5614.700000  4433.960000        0.0
#
# [2560 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(14, 8))
ax.plot(data['Last'] , label='data' ,linewidth=0.5, color='blue', alpha=0.9)
ax.plot(signals['short_mavg'], label='SMA40', alpha=0.85)
ax.plot(signals['long_mavg'], label='SMA100', alpha=0.85)
ax.scatter(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], label = 'Buy', marker='^', color='green', alpha=1)
ax.scatter(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], label = 'Sell', marker='v', color='red', alpha=1)
ax.set_title('data' + " Price History with buy and sell signals",fontsize=10, backgroundcolor='blue', color='white')
ax.set_ylabel('Last Price', fontsize=12)
legend = ax.legend()
ax.grid()
plt.tight_layout()
plt.show()

# %%
bs_labels = signals.positions[60:-6]

# %%
len(bs_labels)
# Out:
# 2494

# %%
len(pictures)
# Out:
# 2494

# %%
# 15×15 pixel labeled sample images after image creation phase for SMA buy and sell strategy
plt.imshow(pictures[0], interpolation='nearest') # Hold
plt.show()
plt.imshow(pictures[230], interpolation='nearest') # Sell
plt.show()
plt.imshow(pictures[264], interpolation='nearest') # Buy
plt.show()

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bs_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bs_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(15, 15, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 13, 13, 32)        320
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_6 (Conv2D)           (None, 9, 9, 128)         73856
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 128)               147584
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 388,227
# Trainable params: 388,227
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 3s 16ms/step - loss: 8.1039 - accuracy: 0.9582 - val_loss: 0.1003 - val_accuracy: 0.9966
# Epoch 2/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.4379 - accuracy: 0.9764 - val_loss: 0.0570 - val_accuracy: 0.9966
# Epoch 3/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3101 - accuracy: 0.9855 - val_loss: 0.0681 - val_accuracy: 0.9966
# Epoch 4/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3259 - accuracy: 0.9855 - val_loss: 0.0236 - val_accuracy: 0.9966
# Epoch 5/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3262 - accuracy: 0.9850 - val_loss: 0.1024 - val_accuracy: 0.9966
# Epoch 6/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2805 - accuracy: 0.9827 - val_loss: 0.0796 - val_accuracy: 0.9966
# Epoch 7/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2378 - accuracy: 0.9864 - val_loss: 0.0269 - val_accuracy: 0.9966
# Epoch 8/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2767 - accuracy: 0.9823 - val_loss: 0.0952 - val_accuracy: 0.9966
# Epoch 9/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3339 - accuracy: 0.9855 - val_loss: 0.0482 - val_accuracy: 0.9966
# Epoch 10/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2153 - accuracy: 0.9868 - val_loss: 0.0318 - val_accuracy: 0.9966
# Epoch 11/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3457 - accuracy: 0.9823 - val_loss: 0.1113 - val_accuracy: 0.9966
# Epoch 12/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2228 - accuracy: 0.9818 - val_loss: 0.0253 - val_accuracy: 0.9966
# Epoch 13/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2361 - accuracy: 0.9873 - val_loss: 0.0195 - val_accuracy: 0.9966
# Epoch 14/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3244 - accuracy: 0.9864 - val_loss: 0.0886 - val_accuracy: 0.9966
# Epoch 15/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2048 - accuracy: 0.9864 - val_loss: 0.0248 - val_accuracy: 0.9966
# Epoch 16/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1677 - accuracy: 0.9873 - val_loss: 0.1672 - val_accuracy: 0.9966
# Epoch 17/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2281 - accuracy: 0.9873 - val_loss: 0.0216 - val_accuracy: 0.9966
# Epoch 18/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2380 - accuracy: 0.9873 - val_loss: 0.3071 - val_accuracy: 0.9966
# Epoch 19/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2008 - accuracy: 0.9877 - val_loss: 0.0272 - val_accuracy: 0.9966
# Epoch 20/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1631 - accuracy: 0.9877 - val_loss: 0.0194 - val_accuracy: 0.9966
# Epoch 21/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.1555 - accuracy: 0.9877 - val_loss: 0.0270 - val_accuracy: 0.9966
# Epoch 22/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.2758 - accuracy: 0.9877 - val_loss: 0.0290 - val_accuracy: 0.9966
# Epoch 23/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.
t.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded    Volume  Value Traded
# Date                               ...
# 2009-02-01       1888  1640  1720  ...           1069  20335924   34724345237
# 2009-02-02       1708  1750  1657  ...             67   1835207    3042332902
# 2009-02-03       1670  1620  1620  ...            104   2524795    4090167900
# 2009-02-04       1620  1572  1572  ...             87   2527581    3973357332
# 2009-02-07       1572  1525  1610  ...            242   4698245    7186955357
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[59:-6]
len(ud_labels)
# Out:
# 2494

# %%
len(pictures)
# Out:
# 2494

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(15, 15, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 13, 13, 32)        320
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_10 (Conv2D)          (None, 9, 9, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 128)               147584
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 387,969
# Trainable params: 387,969
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 16ms/step - loss: 19.2035 - accuracy: 0.5064 - val_loss: 0.7032 - val_accuracy: 0.6122
# Epoch 2/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.0656 - accuracy: 0.5064 - val_loss: 0.6835 - val_accuracy: 0.6122
# Epoch 3/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.8852 - accuracy: 0.5064 - val_loss: 0.6650 - val_accuracy: 0.6122
# Epoch 4/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7894 - accuracy: 0.5064 - val_loss: 0.6967 - val_accuracy: 0.6122
# Epoch 5/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7131 - accuracy: 0.5064 - val_loss: 0.6396 - val_accuracy: 0.6122
# Epoch 6/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7132 - accuracy: 0.5064 - val_loss: 0.6700 - val_accuracy: 0.6122
# Epoch 7/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6993 - accuracy: 0.5064 - val_loss: 0.6225 - val_accuracy: 0.6122
# Epoch 8/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6803 - accuracy: 0.5064 - val_loss: 0.6452 - val_accuracy: 0.6122
# Epoch 9/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.6843 - accuracy: 0.5064 - val_loss: 0.5815 - val_accuracy: 0.6122
# Epoch 10/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7284 - accuracy: 0.5064 - val_loss: 0.6420 - val_accuracy: 0.6122
# Epoch 11/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7000 - accuracy: 0.5064 - val_loss: 0.6573 - val_accuracy: 0.6122
# Epoch 12/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6780 - accuracy: 0.5064 - val_loss: 0.5917 - val_accuracy: 0.6122
# Epoch 13/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.
100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.7042 - accuracy: 0.5064 - val_loss: 0.5614 - val_accuracy: 0.6122
# Epoch 74/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6270 - accuracy: 0.5064 - val_loss: 0.5983 - val_accuracy: 0.6122
# Epoch 75/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5942 - accuracy: 0.5064 - val_loss: 0.6169 - val_accuracy: 0.6122
# Epoch 76/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6377 - accuracy: 0.5064 - val_loss: 0.5200 - val_accuracy: 0.6122
# Epoch 77/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.8415 - accuracy: 0.5064 - val_loss: 0.5466 - val_accuracy: 0.6122
# Epoch 78/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5840 - accuracy: 0.5064 - val_loss: 0.6309 - val_accuracy: 0.6122
# Epoch 79/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5896 - accuracy: 0.5064 - val_loss: 0.6289 - val_accuracy: 0.6122
# Epoch 80/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.9393 - accuracy: 0.5064 - val_loss: 0.6387 - val_accuracy: 0.6122
# Epoch 81/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5611 - accuracy: 0.5064 - val_loss: 0.6362 - val_accuracy: 0.6122
# Epoch 82/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5959 - accuracy: 0.5064 - val_loss: 0.5862 - val_accuracy: 0.6122
# Epoch 83/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6271 - accuracy: 0.5064 - val_loss: 0.5449 - val_accuracy: 0.6122
# Epoch 84/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5595 - accuracy: 0.5064 - val_loss: 0.5887 - val_accuracy: 0.6122
# Epoch 85/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5685 - accuracy: 0.5064 - val_loss: 0.5488 - val_accuracy: 0.6122
# Epoch 86/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5628 - accuracy: 0.5064 - val_loss: 0.6142 - val_accuracy: 0.6122
# Epoch 87/100
# 69/69 [==============================] - 1s 13ms/step - loss: 4.4214 - accuracy: 0.5064 - val_loss: 0.5639 - val_accuracy: 0.6122
# Epoch 88/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5447 - accuracy: 0.5064 - val_loss: 0.5515 - val_accuracy: 0.6122
# Epoch 89/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6088 - accuracy: 0.5064 - val_loss: 0.6009 - val_accuracy: 0.6122
# Epoch 90/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5700 - accuracy: 0.5064 - val_loss: 0.5396 - val_accuracy: 0.6122
# Epoch 91/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5674 - accuracy: 0.5064 - val_loss: 0.5473 - val_accuracy: 0.6122
# Epoch 92/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5515 - accuracy: 0.5064 - val_loss: 0.5710 - val_accuracy: 0.6122
# Epoch 93/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5654 - accuracy: 0.5064 - val_loss: 0.9371 - val_accuracy: 0.6122
# Epoch 94/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5359 - accuracy: 0.5064 - val_loss: 1.6082 - val_accuracy: 0.6122
# Epoch 95/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6351 - accuracy: 0.5064 - val_loss: 0.5795 - val_accuracy: 0.6122
# Epoch 96/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6703 - accuracy: 0.5064 - val_loss: 0.5150 - val_accuracy: 0.6122
# Epoch 97/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5400 - accuracy: 0.5064 - val_loss: 1.6774 - val_accuracy: 0.6122
# Epoch 98/100
# 69/69 [==============================] - 1s 13ms/step - loss: 1.9447 - accuracy: 0.5064 - val_loss: 0.6454 - val_accuracy: 0.6122
# Epoch 99/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.5270 - accuracy: 0.5064 - val_loss: 0.5556 - val_accuracy: 0.6122
# Epoch 100/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.6031 - accuracy: 0.5064 - val_loss: 0.5821 - val_accuracy: 0.6122

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
