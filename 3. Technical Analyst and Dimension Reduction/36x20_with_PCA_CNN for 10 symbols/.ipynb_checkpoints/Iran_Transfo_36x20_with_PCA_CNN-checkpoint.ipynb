# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "بترانس"].head()
# Out:
#            Date  Symbol            Name  ...  Number Traded  Volume  Value Traded
# 59   2008-12-06  بترانس  ايران‌ ترانسفو  ...             15   35925     194207342
# 172  2008-12-07  بترانس  ايران‌ ترانسفو  ...             54  172971     919695657
# 264  2008-12-08  بترانس  ايران‌ ترانسفو  ...             38   92277     480199827
# 359  2008-12-10  بترانس  ايران‌ ترانسفو  ...             10   37685     193813955
# 449  2008-12-13  بترانس  ايران‌ ترانسفو  ...              6   15154      77573326
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "بترانس"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2580)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, low=data.Low, close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2561

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2568

# %%
len(data.Last)
# Out:
# 2580

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2555
# 2555

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
    x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    x = principalDf.transpose()

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    pictures[i] = principalDf

# %%
pictures[100]
# Out:
#               0            1           2  ...          7          8             9
# 0  69791.037121     0.395286    0.004016  ...   0.000044  -0.000014  1.585237e-12
# 1  -7765.128206  2578.960648    3.014703  ...   0.031599  -0.009759  1.585237e-12
# 2  -7753.694950  -336.859650  580.941951  ...   0.623987  -0.189999  1.585237e-12
# 3  -7753.419109  -327.901789 -159.948872  ...   1.140688  -0.343125  1.585237e-12
# 4  -7753.285969  -323.746199  -99.003146  ...   1.900203  -0.561599  1.585237e-12
# 5  -7753.148223  -319.556127  -71.009293  ...   6.107967  -1.645791  1.585237e-12
# 6  -7753.114867  -318.557705  -66.458635  ...  13.170576  -3.090734  1.585237e-12
# 7  -7753.091216  -317.853564  -63.570100  ...  73.108781  -8.187450  1.585237e-12
# 8  -7753.079966  -317.519706  -62.282412  ... -62.765040 -37.978472  1.585237e-12
# 9  -7753.074616  -317.361194  -61.688211  ... -33.318807  52.006941  1.585237e-12
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_33 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_34 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_35 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_8 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_16 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_8 (Flatten)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 14ms/step - loss: 4.0314 - accuracy: 0.8550 - val_loss: 0.4120 - val_accuracy: 0.9302
# Epoch 2/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7616 - accuracy: 0.8977 - val_loss: 0.3409 - val_accuracy: 0.9302
# Epoch 3/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6146 - accuracy: 0.9200 - val_loss: 0.3675 - val_accuracy: 0.9302
# Epoch 4/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.5573 - accuracy: 0.9255 - val_loss: 0.5264 - val_accuracy: 0.9302
# Epoch 5/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.5144 - accuracy: 0.9282 - val_loss: 0.3286 - val_accuracy: 0.9302
# Epoch 6/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4681 - accuracy: 0.9291 - val_loss: 0.4601 - val_accuracy: 0.9302
# Epoch 7/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4577 - accuracy: 0.9291 - val_loss: 0.6571 - val_accuracy: 0.9302
# Epoch 8/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4599 - accuracy: 0.9291 - val_loss: 0.3788 - val_accuracy: 0.9302
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3858 - accuracy: 0.9291 - val_loss: 0.3625 - val_accuracy: 0.9302
# Epoch 10/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4204 - accuracy: 0.9291 - val_loss: 0.3275 - val_accuracy: 0.9302
# Epoch 11/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3950 - accuracy: 0.9291 - val_loss: 0.3779 - val_accuracy: 0.9302
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3668 - accuracy: 0.9291 - val_loss: 0.3895 - val_accuracy: 0.9302
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4389 - accuracy: 0.9291 - val_loss: 0.3768 - val_accuracy: 0.9302
# Epoch 14/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3500 - accuracy: 0.9291 - val_loss: 0.9424 - val_accuracy: 0.9302
# Epoch 15/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3513 - accuracy: 0.9291 - val_loss: 0.3372 - val_accuracy: 0.9302
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3361 - accuracy: 0.9291 - val_loss: 0.3927 - val_accuracy: 0.9302
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3382 - accuracy: 0.9291 - val_loss: 0.3279 - val_accuracy: 0.9302
# Epoch 18/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3576 - accuracy: 0.9286 - val_loss: 0.7389 - val_accuracy: 0.9302
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3288 - accuracy: 0.9291 - val_loss: 0.4378 - val_accuracy: 0.9302
# Epoch 20/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3466 - accuracy: 0.9291 - val_loss: 0.3402 - val_accuracy: 0.9302
# Epoch 21/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3282 - accuracy: 0.9291 - val_loss: 0.3438 - val_accuracy: 0.9302
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3302 - accuracy: 0.9291 - val_loss: 0.5025 - val_accuracy: 0.9302
# Epoch 23/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3349 - accuracy: 0.9286 - val_loss: 0.3822 - val_accuracy: 0.9302
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3409 - accuracy: 0.9286 - val_loss: 0.3522 - val_accuracy: 0.9302
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3242 - accuracy: 0.9291 - val_loss: 0.3627 - val_accuracy: 0.9302
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3479 - accuracy: 0.9291 - val_loss: 0.3693 - val_accuracy: 0.9302
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3164 - accuracy: 0.9291 - val_loss: 0.4969 - val_accuracy: 0.9302
# Epoch 28/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3391 - accuracy: 0.9291 - val_loss: 0.3538 - val_accuracy: 0.9302
# Epoch 29/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3342 - accuracy: 0.9286 - val_loss: 0.3198 - val_accuracy: 0.9302
# Epoch 30/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3131 - accuracy: 0.9291 - val_loss: 0.3546 - val_accuracy: 0.9302
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3461 - accuracy: 0.9291 - val_loss: 0.4285 - val_accuracy: 0.9302
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3320 - accuracy: 0.9286 - val_loss: 0.3496 - val_accuracy: 0.9302
# Epoch 33/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3258 - accuracy: 0.9291 - val_loss: 0.3252 - val_accuracy: 0.9302
# Epoch 34/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3829 - accuracy: 0.9291 - val_loss: 0.3166 - val_accuracy: 0.9302
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3269 - accuracy: 0.9291 - val_loss: 0.3487 - val_accuracy: 0.9302
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3390 - accuracy: 0.9286 - val_loss: 0.3325 - val_accuracy: 0.9302
# Epoch 37/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3143 - accuracy: 0.9291 - val_loss: 0.3245 - val_accuracy: 0.9302
# Epoch 38/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3170 - accuracy: 0.9291 - val_loss: 0.3285 - val_accuracy: 0.9302
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3149 - accuracy: 0.9291 - val_loss: 0.3171 - val_accuracy: 0.9302
# Epoch 40/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3205 - accuracy: 0.9291 - val_loss: 0.3404 - val_accuracy: 0.9302
# Epoch 41/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3365 - accuracy: 0.9291 - val_loss: 0.3585 - val_accuracy: 0.9302
# Epoch 42/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3370 - accuracy: 0.9286 - val_loss: 0.3611 - val_accuracy: 0.9302
# Epoch 43/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3253 - accuracy: 0.9286 - val_loss: 0.3980 - val_accuracy: 0.9302
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3142 - accuracy: 0.9291 - val_loss: 0.4143 - val_accuracy: 0.9302
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3249 - accuracy: 0.9291 - val_loss: 0.3709 - val_accuracy: 0.9302
# Epoch 46/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.3100 - accuracy: 0.9291 - val_loss: 0.3800 - val_accuracy: 0.9302
# Epoch 47/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.3096 - accuracy: 0.9291 - val_loss: 0.3936 - val_accuracy: 0.9302
# Epoch 48/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.3128 - accuracy: 0.9291 - val_loss: 0.6732 - val_accuracy: 0.9302
# Epoch 49/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.3418 - accuracy: 0.9291 - val_loss: 0.4536 - val_accuracy: 0.9302
# Epoch 50/100
# 69/69 [==============================] - 1s 11ms/step - loss: 0.3121 - accuracy: 0.9291 - val_loss: 0.4027 - val_accuracy: 0.9302
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3095 - accuracy: 0.9291 - val_loss: 0.3743 - val_accuracy: 0.9302
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3140 - accuracy: 0.9291 - val_loss: 0.3934 - val_accuracy: 0.9302
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3536 - accuracy: 0.9291 - val_loss: 0.4242 - val_accuracy: 0.9302
# Epoch 54/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3183 - accuracy: 0.9291 - val_loss: 0.4711 - val_accuracy: 0.9302
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3266 - accuracy: 0.9291 - val_loss: 0.4784 - val_accuracy: 0.9302
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3300 - accuracy: 0.9291 - val_loss: 0.4005 - val_accuracy: 0.9302
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3089 - accuracy: 0.9291 - val_loss: 0.5498 - val_accuracy: 0.9302
# Epoch 58/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3228 - accuracy: 0.9291 - val_loss: 0.3960 - val_accuracy: 0.9302
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3113 - accuracy: 0.9291 - val_loss: 0.4304 - val_accuracy: 0.9302
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3104 - accuracy: 0.9291 - val_loss: 0.4436 - val_accuracy: 0.9302
# Epoch 61/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3090 - accuracy: 0.9291 - val_loss: 0.4430 - val_accuracy: 0.9302
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3085 - accuracy: 0.9291 - val_loss: 0.4231 - val_accuracy: 0.9302
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3274 - accuracy: 0.9291 - val_loss: 0.4790 - val_accuracy: 0.9302
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3093 - accuracy: 0.9291 - val_loss: 0.4774 - val_accuracy: 0.9302
# Epoch 65/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3077 - accuracy: 0.9291 - val_loss: 0.4933 - val_accuracy: 0.9302
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3100 - accuracy: 0.9291 - val_loss: 0.5061 - val_accuracy: 0.9302
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3069 - accuracy: 0.9291 - val_loss: 0.5183 - val_accuracy: 0.9302
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3079 - accuracy: 0.9291 - val_loss: 0.5193 - val_accuracy: 0.9302
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3088 - accuracy: 0.9291 - val_loss: 0.5575 - val_accuracy: 0.9302
# Epoch 70/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3097 - accuracy: 0.9291 - val_loss: 0.5291 - val_accuracy: 0.9302
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3090 - accuracy: 0.9291 - val_loss: 0.5470 - val_accuracy: 0.9302
# Epoch 72/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3091 - accuracy: 0.9291 - val_loss: 0.5690 - val_accuracy: 0.9302
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3088 - accuracy: 0.9291 - val_loss: 0.5633 - val_accuracy: 0.9302
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3070 - accuracy: 0.9291 - val_loss: 0.5591 - val_accuracy: 0.9302
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3095 - accuracy: 0.9291 - val_loss: 0.5750 - val_accuracy: 0.9302
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3074 - accuracy: 0.9291 - val_loss: 0.5703 - val_accuracy: 0.9302
# Epoch 77/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3074 - accuracy: 0.9291 - val_loss: 0.5733 - val_accuracy: 0.9302
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3069 - accuracy: 0.9291 - val_loss: 0.5961 - val_accuracy: 0.9302
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3119 - accuracy: 0.9291 - val_loss: 0.5770 - val_accuracy: 0.9302
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3084 - accuracy: 0.9291 - val_loss: 0.6078 - val_accuracy: 0.9302
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3088 - accuracy: 0.9291 - val_loss: 0.5918 - val_accuracy: 0.9302
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3064 - accuracy: 0.9291 - val_loss: 0.6246 - val_accuracy: 0.9302
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3088 - accuracy: 0.9291 - val_loss: 0.6324 - val_accuracy: 0.9302
# Epoch 84/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3079 - accuracy: 0.9291 - val_loss: 0.5936 - val_accuracy: 0.9302
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3073 - accuracy: 0.9291 - val_loss: 0.6369 - val_accuracy: 0.9302
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3067 - accuracy: 0.9291 - val_loss: 0.6349 - val_accuracy: 0.9302
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3063 - accuracy: 0.9291 - val_loss: 0.6278 - val_accuracy: 0.9302
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3075 - accuracy: 0.9291 - val_loss: 0.6204 - val_accuracy: 0.9302
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3077 - accuracy: 0.9291 - val_loss: 0.6226 - val_accuracy: 0.9302
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3102 - accuracy: 0.9291 - val_loss: 0.6253 - val_accuracy: 0.9302
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3087 - accuracy: 0.9291 - val_loss: 0.6174 - val_accuracy: 0.9302
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3073 - accuracy: 0.9291 - val_loss: 0.6456 - val_accuracy: 0.9302
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3076 - accuracy: 0.9291 - val_loss: 0.6415 - val_accuracy: 0.9302
# Epoch 94/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3105 - accuracy: 0.9291 - val_loss: 0.6422 - val_accuracy: 0.9302
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3072 - accuracy: 0.9291 - val_loss: 0.6513 - val_accuracy: 0.9302
# Epoch 96/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3096 - accuracy: 0.9291 - val_loss: 0.6589 - val_accuracy: 0.9302
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3095 - accuracy: 0.9291 - val_loss: 0.6533 - val_accuracy: 0.9302
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3093 - accuracy: 0.9291 - val_loss: 0.6412 - val_accuracy: 0.9302
# Epoch 99/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3073 - accuracy: 0.9291 - val_loss: 0.6637 - val_accuracy: 0.9302
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3119 - accuracy: 0.9291 - val_loss: 0.6726 - val_accuracy: 0.9302

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2008-12-06       5494  5357  5401  ...             15   35925     194207342
# 2008-12-07       5481  5317  5317  ...             54  172971     919695657
# 2008-12-08       5363  5206  5203  ...             38   92277     480199827
# 2008-12-10       5302  5143  5143  ...             10   37685     193813955
# 2008-12-13       5277  5119  5119  ...              6   15154      77573326
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 2515

# %%
len(pictures)
# Out:
# 2515

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_37 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_38 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_39 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_9 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_18 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_9 (Flatten)         (None, 128)               0
#
#  dense_18 (Dense)            (None, 128)               16512
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 13ms/step - loss: 6.8639 - accuracy: 0.4991 - val_loss: 0.8380 - val_accuracy: 0.5175
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 1.1695 - accuracy: 0.4991 - val_loss: 0.6953 - val_accuracy: 0.5175
# Epoch 3/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.8854 - accuracy: 0.4991 - val_loss: 0.6976 - val_accuracy: 0.5175
# Epoch 4/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7631 - accuracy: 0.4991 - val_loss: 0.6906 - val_accuracy: 0.5175
# Epoch 5/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7697 - accuracy: 0.4991 - val_loss: 0.6971 - val_accuracy: 0.5175
# Epoch 6/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7317 - accuracy: 0.4991 - val_loss: 0.6922 - val_accuracy: 0.5175
# Epoch 7/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7422 - accuracy: 0.4991 - val_loss: 0.6913 - val_accuracy: 0.5175
# Epoch 8/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7307 - accuracy: 0.4991 - val_loss: 0.6960 - val_accuracy: 0.5175
# Epoch 9/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7135 - accuracy: 0.4991 - val_loss: 0.6925 - val_accuracy: 0.5175
# Epoch 10/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7284 - accuracy: 0.4991 - val_loss: 0.6954 - val_accuracy: 0.5175
# Epoch 11/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7107 - accuracy: 0.4991 - val_loss: 0.6945 - val_accuracy: 0.5175
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7022 - accuracy: 0.4991 - val_loss: 0.6994 - val_accuracy: 0.5175
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7062 - accuracy: 0.4991 - val_loss: 0.7001 - val_accuracy: 0.5175
# Epoch 14/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7038 - accuracy: 0.4991 - val_loss: 0.6937 - val_accuracy: 0.5175
# Epoch 15/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7042 - accuracy: 0.4991 - val_loss: 0.6930 - val_accuracy: 0.5175
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6987 - accuracy: 0.4991 - val_loss: 0.6917 - val_accuracy: 0.5175
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7035 - accuracy: 0.4991 - val_loss: 0.7016 - val_accuracy: 0.5175
# Epoch 18/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7055 - accuracy: 0.4991 - val_loss: 0.6944 - val_accuracy: 0.5175
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6996 - accuracy: 0.4991 - val_loss: 0.6936 - val_accuracy: 0.5175
# Epoch 20/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7032 - accuracy: 0.4991 - val_loss: 0.6929 - val_accuracy: 0.5175
# Epoch 21/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7014 - accuracy: 0.4991 - val_loss: 0.6939 - val_accuracy: 0.5175
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6953 - accuracy: 0.4991 - val_loss: 0.7014 - val_accuracy: 0.5175
# Epoch 23/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6997 - accuracy: 0.4991 - val_loss: 0.6935 - val_accuracy: 0.5175
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6993 - accuracy: 0.4991 - val_loss: 0.7042 - val_accuracy: 0.5175
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7012 - accuracy: 0.4991 - val_loss: 0.6931 - val_accuracy: 0.5175
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6974 - accuracy: 0.4991 - val_loss: 0.7139 - val_accuracy: 0.5175
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6974 - accuracy: 0.4991 - val_loss: 0.6940 - val_accuracy: 0.5175
# Epoch 28/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6949 - accuracy: 0.4991 - val_loss: 0.7274 - val_accuracy: 0.5175
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7010 - accuracy: 0.4991 - val_loss: 0.7003 - val_accuracy: 0.5175
# Epoch 30/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6986 - accuracy: 0.4991 - val_loss: 0.6969 - val_accuracy: 0.5175
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7084 - accuracy: 0.4991 - val_loss: 0.6921 - val_accuracy: 0.5175
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6942 - accuracy: 0.4991 - val_loss: 0.7024 - val_accuracy: 0.5175
# Epoch 33/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.4991 - val_loss: 0.6936 - val_accuracy: 0.5175
# Epoch 34/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6954 - accuracy: 0.4991 - val_loss: 0.6940 - val_accuracy: 0.5175
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6948 - accuracy: 0.4991 - val_loss: 0.6906 - val_accuracy: 0.5175
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7047 - accuracy: 0.4991 - val_loss: 0.7127 - val_accuracy: 0.5175
# Epoch 37/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6910 - accuracy: 0.4991 - val_loss: 0.6920 - val_accuracy: 0.5175
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6983 - accuracy: 0.4991 - val_loss: 0.6945 - val_accuracy: 0.5175
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6993 - accuracy: 0.4991 - val_loss: 0.6952 - val_accuracy: 0.5175
# Epoch 40/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7002 - accuracy: 0.4991 - val_loss: 0.7001 - val_accuracy: 0.5175
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6943 - accuracy: 0.4991 - val_loss: 0.6944 - val_accuracy: 0.5175
# Epoch 42/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6960 - accuracy: 0.4991 - val_loss: 0.7148 - val_accuracy: 0.5175
# Epoch 43/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.4991 - val_loss: 0.7034 - val_accuracy: 0.5175
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6954 - accuracy: 0.4991 - val_loss: 0.6954 - val_accuracy: 0.5175
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6930 - accuracy: 0.4991 - val_loss: 0.7211 - val_accuracy: 0.5175
# Epoch 46/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6954 - accuracy: 0.4991 - val_loss: 0.7236 - val_accuracy: 0.5175
# Epoch 47/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6905 - accuracy: 0.4991 - val_loss: 0.7185 - val_accuracy: 0.5175
# Epoch 48/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6915 - accuracy: 0.4991 - val_loss: 0.7511 - val_accuracy: 0.5175
# Epoch 49/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6945 - accuracy: 0.4991 - val_loss: 0.7367 - val_accuracy: 0.5175
# Epoch 50/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6937 - accuracy: 0.4991 - val_loss: 0.7103 - val_accuracy: 0.5175
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6937 - accuracy: 0.4991 - val_loss: 0.6914 - val_accuracy: 0.5175
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6948 - accuracy: 0.4991 - val_loss: 0.6961 - val_accuracy: 0.5175
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6909 - accuracy: 0.4991 - val_loss: 0.7196 - val_accuracy: 0.5175
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6964 - accuracy: 0.4991 - val_loss: 0.6873 - val_accuracy: 0.5175
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6893 - accuracy: 0.4991 - val_loss: 0.7003 - val_accuracy: 0.5175
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6947 - accuracy: 0.4991 - val_loss: 0.6849 - val_accuracy: 0.5175
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.4991 - val_loss: 0.6972 - val_accuracy: 0.5175
# Epoch 58/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6953 - accuracy: 0.4991 - val_loss: 0.6855 - val_accuracy: 0.5175
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6998 - accuracy: 0.4991 - val_loss: 0.6967 - val_accuracy: 0.5175
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6892 - accuracy: 0.4991 - val_loss: 0.6998 - val_accuracy: 0.5175
# Epoch 61/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7007 - accuracy: 0.4991 - val_loss: 0.7211 - val_accuracy: 0.5175
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.4991 - val_loss: 0.8166 - val_accuracy: 0.5175
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6972 - accuracy: 0.4991 - val_loss: 0.7627 - val_accuracy: 0.5175
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.4991 - val_loss: 0.8487 - val_accuracy: 0.5175
# Epoch 65/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7032 - accuracy: 0.4991 - val_loss: 0.6851 - val_accuracy: 0.5175
# Epoch 66/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6939 - accuracy: 0.4991 - val_loss: 0.6881 - val_accuracy: 0.5175
# Epoch 67/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6903 - accuracy: 0.4991 - val_loss: 0.8655 - val_accuracy: 0.5175
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6936 - accuracy: 0.4991 - val_loss: 0.8071 - val_accuracy: 0.5175
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.4991 - val_loss: 0.7099 - val_accuracy: 0.5175
# Epoch 70/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6906 - accuracy: 0.4991 - val_loss: 0.7498 - val_accuracy: 0.5175
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7174 - accuracy: 0.4991 - val_loss: 0.8112 - val_accuracy: 0.5175
# Epoch 72/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.4991 - val_loss: 0.6930 - val_accuracy: 0.5175
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6842 - accuracy: 0.4991 - val_loss: 0.7978 - val_accuracy: 0.5175
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7069 - accuracy: 0.4991 - val_loss: 0.7126 - val_accuracy: 0.5175
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6906 - accuracy: 0.4991 - val_loss: 0.6975 - val_accuracy: 0.5175
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6943 - accuracy: 0.4991 - val_loss: 0.6858 - val_accuracy: 0.5175
# Epoch 77/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6995 - accuracy: 0.4991 - val_loss: 1.1181 - val_accuracy: 0.5175
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7231 - accuracy: 0.4991 - val_loss: 0.7908 - val_accuracy: 0.5175
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7026 - accuracy: 0.4991 - val_loss: 0.6877 - val_accuracy: 0.5175
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6917 - accuracy: 0.4991 - val_loss: 0.7409 - val_accuracy: 0.5175
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7000 - accuracy: 0.4991 - val_loss: 0.6882 - val_accuracy: 0.5175
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6953 - accuracy: 0.4991 - val_loss: 0.8780 - val_accuracy: 0.5175
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7242 - accuracy: 0.4991 - val_loss: 0.9435 - val_accuracy: 0.5175
# Epoch 84/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7061 - accuracy: 0.4991 - val_loss: 0.7244 - val_accuracy: 0.5175
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.4991 - val_loss: 0.6922 - val_accuracy: 0.5175
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7032 - accuracy: 0.4991 - val_loss: 0.7090 - val_accuracy: 0.5175
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6873 - accuracy: 0.4991 - val_loss: 0.9808 - val_accuracy: 0.5175
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7019 - accuracy: 0.4991 - val_loss: 0.7505 - val_accuracy: 0.5175
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6987 - accuracy: 0.4991 - val_loss: 0.6963 - val_accuracy: 0.5175
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7028 - accuracy: 0.4991 - val_loss: 0.8802 - val_accuracy: 0.5175
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7179 - accuracy: 0.4991 - val_loss: 0.7575 - val_accuracy: 0.5175
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7069 - accuracy: 0.4991 - val_loss: 1.3041 - val_accuracy: 0.5175
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6890 - accuracy: 0.4991 - val_loss: 0.7401 - val_accuracy: 0.5175
# Epoch 94/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7227 - accuracy: 0.4991 - val_loss: 0.8853 - val_accuracy: 0.5175
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7003 - accuracy: 0.4991 - val_loss: 0.6901 - val_accuracy: 0.5175
# Epoch 96/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6919 - accuracy: 0.4991 - val_loss: 1.2095 - val_accuracy: 0.5175
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7222 - accuracy: 0.4991 - val_loss: 1.0327 - val_accuracy: 0.5175
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.4991 - val_loss: 0.7408 - val_accuracy: 0.5175
# Epoch 99/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6952 - accuracy: 0.4991 - val_loss: 0.7374 - val_accuracy: 0.5175
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6973 - accuracy: 0.4991 - val_loss: 0.6875 - val_accuracy: 0.5175

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
