# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "غپينو"].head()
# Out:
#             Date Symbol        Name  ...  Number Traded  Volume  Value Traded
# 2726  2009-01-13  غپينو  پارس‌ مينو  ...              2    3000       3537000
# 3656  2009-01-25  غپينو  پارس‌ مينو  ...              1     500        572000
# 5328  2009-02-11  غپينو  پارس‌ مينو  ...              7   10690      12229360
# 6484  2009-03-01  غپينو  پارس‌ مينو  ...              5   18005      20067984
# 6998  2009-03-08  غپينو  پارس‌ مينو  ...              1    1000       1082000
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "غپينو"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2110)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, low=data.Low, close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2091

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2098

# %%
len(data.Last)
# Out:
# 2110

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2085
# 2085

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
    x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    x = principalDf.transpose()

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    pictures[i] = principalDf

# %%
pictures[100]
# Out:
#               0           1           2  ...          7          8             9
# 0  30013.097225    0.089842    0.015920  ...   0.000047  -0.000020  4.451158e-13
# 1  -3337.726362  922.429515   22.965528  ...   0.049464  -0.021258  4.451158e-13
# 2  -3335.273072 -159.157179  502.033937  ...   0.160237  -0.068541  4.451158e-13
# 3  -3334.742094 -126.918972 -142.665931  ...   0.311219  -0.132277  4.451158e-13
# 4  -3334.339621 -110.022114  -72.285083  ...   1.089703  -0.448469  4.451158e-13
# 5  -3334.251071 -106.890752  -65.206611  ...   2.423847  -0.946127  4.451158e-13
# 6  -3334.239390 -106.490913  -64.374986  ...   2.890747  -1.108386  4.451158e-13
# 7  -3334.182288 -104.578598  -60.597015  ...  49.543580  -6.857167  4.451158e-13
# 8  -3334.174157 -104.311878  -60.094841  ... -38.170113 -26.224181  4.451158e-13
# 9  -3334.169170 -104.148950  -59.790916  ... -18.298731  35.806425  4.451158e-13
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 1800
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 32)          320
#
#  conv2d_1 (Conv2D)           (None, 6, 6, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 128)         147584
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 128)        0
#  )
#
#  dropout (Dropout)           (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 57/57 [==============================] - 3s 18ms/step - loss: 5.3345 - accuracy: 0.8256 - val_loss: 0.3010 - val_accuracy: 0.9429
# Epoch 2/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6451 - accuracy: 0.8917 - val_loss: 0.3749 - val_accuracy: 0.9429
# Epoch 3/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.5619 - accuracy: 0.9100 - val_loss: 0.3957 - val_accuracy: 0.9429
# Epoch 4/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.4912 - accuracy: 0.9194 - val_loss: 0.3318 - val_accuracy: 0.9429
# Epoch 5/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4512 - accuracy: 0.9211 - val_loss: 0.2981 - val_accuracy: 0.9429
# Epoch 6/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4609 - accuracy: 0.9217 - val_loss: 0.2946 - val_accuracy: 0.9429
# Epoch 7/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4493 - accuracy: 0.9217 - val_loss: 0.3090 - val_accuracy: 0.9429
# Epoch 8/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.4295 - accuracy: 0.9217 - val_loss: 0.3539 - val_accuracy: 0.9429
# Epoch 9/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4059 - accuracy: 0.9217 - val_loss: 0.3174 - val_accuracy: 0.9429
# Epoch 10/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4107 - accuracy: 0.9217 - val_loss: 0.3445 - val_accuracy: 0.9429
# Epoch 11/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3949 - accuracy: 0.9217 - val_loss: 0.2761 - val_accuracy: 0.9429
# Epoch 12/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3814 - accuracy: 0.9217 - val_loss: 0.5687 - val_accuracy: 0.9429
# Epoch 13/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.5014 - accuracy: 0.9217 - val_loss: 0.2857 - val_accuracy: 0.9429
# Epoch 14/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3664 - accuracy: 0.9217 - val_loss: 0.2813 - val_accuracy: 0.9429
# Epoch 15/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3670 - accuracy: 0.9217 - val_loss: 0.2635 - val_accuracy: 0.9429
# Epoch 16/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3764 - accuracy: 0.9217 - val_loss: 0.2712 - val_accuracy: 0.9429
# Epoch 17/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3532 - accuracy: 0.9217 - val_loss: 0.2621 - val_accuracy: 0.9429
# Epoch 18/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3805 - accuracy: 0.9217 - val_loss: 0.2833 - val_accuracy: 0.9429
# Epoch 19/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3669 - accuracy: 0.9217 - val_loss: 0.2673 - val_accuracy: 0.9429
# Epoch 20/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3539 - accuracy: 0.9217 - val_loss: 0.2606 - val_accuracy: 0.9429
# Epoch 21/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3749 - accuracy: 0.9217 - val_loss: 0.2662 - val_accuracy: 0.9429
# Epoch 22/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3615 - accuracy: 0.9217 - val_loss: 0.2717 - val_accuracy: 0.9429
# Epoch 23/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3427 - accuracy: 0.9217 - val_loss: 0.3338 - val_accuracy: 0.9429
# Epoch 24/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3551 - accuracy: 0.9217 - val_loss: 0.2604 - val_accuracy: 0.9429
# Epoch 25/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3645 - accuracy: 0.9217 - val_loss: 0.2626 - val_accuracy: 0.9429
# Epoch 26/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3619 - accuracy: 0.9217 - val_loss: 0.2658 - val_accuracy: 0.9429
# Epoch 27/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3495 - accuracy: 0.9217 - val_loss: 0.9553 - val_accuracy: 0.9429
# Epoch 28/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3945 - accuracy: 0.9217 - val_loss: 0.2664 - val_accuracy: 0.9429
# Epoch 29/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3557 - accuracy: 0.9217 - val_loss: 0.2608 - val_accuracy: 0.9429
# Epoch 30/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3596 - accuracy: 0.9217 - val_loss: 0.2640 - val_accuracy: 0.9429
# Epoch 31/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3418 - accuracy: 0.9217 - val_loss: 0.2697 - val_accuracy: 0.9429
# Epoch 32/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3390 - accuracy: 0.9217 - val_loss: 0.2652 - val_accuracy: 0.9429
# Epoch 33/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.4051 - accuracy: 0.9217 - val_loss: 0.2661 - val_accuracy: 0.9429
# Epoch 34/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3484 - accuracy: 0.9217 - val_loss: 0.3353 - val_accuracy: 0.9429
# Epoch 35/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3542 - accuracy: 0.9217 - val_loss: 0.2627 - val_accuracy: 0.9429
# Epoch 36/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3783 - accuracy: 0.9217 - val_loss: 0.2669 - val_accuracy: 0.9429
# Epoch 37/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3478 - accuracy: 0.9217 - val_loss: 0.2666 - val_accuracy: 0.9429
# Epoch 38/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3361 - accuracy: 0.9217 - val_loss: 0.2658 - val_accuracy: 0.9429
# Epoch 39/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3664 - accuracy: 0.9217 - val_loss: 0.2592 - val_accuracy: 0.9429
# Epoch 40/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3892 - accuracy: 0.9217 - val_loss: 0.2623 - val_accuracy: 0.9429
# Epoch 41/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3801 - accuracy: 0.9217 - val_loss: 0.2628 - val_accuracy: 0.9429
# Epoch 42/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3422 - accuracy: 0.9217 - val_loss: 0.2640 - val_accuracy: 0.9429
# Epoch 43/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3444 - accuracy: 0.9217 - val_loss: 0.2635 - val_accuracy: 0.9429
# Epoch 44/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3688 - accuracy: 0.9217 - val_loss: 0.2619 - val_accuracy: 0.9429
# Epoch 45/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4195 - accuracy: 0.9217 - val_loss: 0.2644 - val_accuracy: 0.9429
# Epoch 46/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3550 - accuracy: 0.9217 - val_loss: 0.2609 - val_accuracy: 0.9429
# Epoch 47/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3935 - accuracy: 0.9217 - val_loss: 0.2633 - val_accuracy: 0.9429
# Epoch 48/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3776 - accuracy: 0.9217 - val_loss: 0.2623 - val_accuracy: 0.9429
# Epoch 49/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3400 - accuracy: 0.9217 - val_loss: 0.2616 - val_accuracy: 0.9429
# Epoch 50/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3768 - accuracy: 0.9217 - val_loss: 0.3605 - val_accuracy: 0.9429
# Epoch 51/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4632 - accuracy: 0.9217 - val_loss: 0.2636 - val_accuracy: 0.9429
# Epoch 52/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3374 - accuracy: 0.9217 - val_loss: 0.2746 - val_accuracy: 0.9429
# Epoch 53/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3334 - accuracy: 0.9217 - val_loss: 0.2621 - val_accuracy: 0.9429
# Epoch 54/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6684 - accuracy: 0.9217 - val_loss: 0.2639 - val_accuracy: 0.9429
# Epoch 55/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3430 - accuracy: 0.9217 - val_loss: 0.2629 - val_accuracy: 0.9429
# Epoch 56/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3459 - accuracy: 0.9217 - val_loss: 0.2604 - val_accuracy: 0.9429
# Epoch 57/100
# 57/57 [==============================] - 1s 16ms/step - loss: 0.3617 - accuracy: 0.9217 - val_loss: 0.5586 - val_accuracy: 0.9429
# Epoch 58/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3824 - accuracy: 0.9217 - val_loss: 0.2618 - val_accuracy: 0.9429
# Epoch 59/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.5196 - accuracy: 0.9217 - val_loss: 0.2620 - val_accuracy: 0.9429
# Epoch 60/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3416 - accuracy: 0.9217 - val_loss: 0.2623 - val_accuracy: 0.9429
# Epoch 61/100
# 57/57 [==============================] - 1s 16ms/step - loss: 0.3332 - accuracy: 0.9217 - val_loss: 0.2616 - val_accuracy: 0.9429
# Epoch 62/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3966 - accuracy: 0.9217 - val_loss: 0.2635 - val_accuracy: 0.9429
# Epoch 63/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4579 - accuracy: 0.9217 - val_loss: 0.2593 - val_accuracy: 0.9429
# Epoch 64/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3637 - accuracy: 0.9217 - val_loss: 0.2604 - val_accuracy: 0.9429
# Epoch 65/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3607 - accuracy: 0.9217 - val_loss: 0.2729 - val_accuracy: 0.9429
# Epoch 66/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4023 - accuracy: 0.9217 - val_loss: 0.2613 - val_accuracy: 0.9429
# Epoch 67/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3421 - accuracy: 0.9217 - val_loss: 0.2615 - val_accuracy: 0.9429
# Epoch 68/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3544 - accuracy: 0.9217 - val_loss: 0.2613 - val_accuracy: 0.9429
# Epoch 69/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3331 - accuracy: 0.9217 - val_loss: 0.5485 - val_accuracy: 0.9429
# Epoch 70/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3490 - accuracy: 0.9217 - val_loss: 0.2646 - val_accuracy: 0.9429
# Epoch 71/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3766 - accuracy: 0.9217 - val_loss: 0.2640 - val_accuracy: 0.9429
# Epoch 72/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3726 - accuracy: 0.9217 - val_loss: 0.2602 - val_accuracy: 0.9429
# Epoch 73/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3374 - accuracy: 0.9217 - val_loss: 0.2629 - val_accuracy: 0.9429
# Epoch 74/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3540 - accuracy: 0.9217 - val_loss: 0.2615 - val_accuracy: 0.9429
# Epoch 75/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3642 - accuracy: 0.9217 - val_loss: 0.2624 - val_accuracy: 0.9429
# Epoch 76/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3570 - accuracy: 0.9217 - val_loss: 0.2618 - val_accuracy: 0.9429
# Epoch 77/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3917 - accuracy: 0.9217 - val_loss: 0.2606 - val_accuracy: 0.9429
# Epoch 78/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3569 - accuracy: 0.9217 - val_loss: 0.2614 - val_accuracy: 0.9429
# Epoch 79/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3384 - accuracy: 0.9217 - val_loss: 0.2603 - val_accuracy: 0.9429
# Epoch 80/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.8704 - accuracy: 0.9217 - val_loss: 0.2624 - val_accuracy: 0.9429
# Epoch 81/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3891 - accuracy: 0.9217 - val_loss: 0.2623 - val_accuracy: 0.9429
# Epoch 82/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3493 - accuracy: 0.9217 - val_loss: 0.2600 - val_accuracy: 0.9429
# Epoch 83/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3783 - accuracy: 0.9217 - val_loss: 0.2637 - val_accuracy: 0.9429
# Epoch 84/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3360 - accuracy: 0.9217 - val_loss: 0.2604 - val_accuracy: 0.9429
# Epoch 85/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3299 - accuracy: 0.9217 - val_loss: 0.2604 - val_accuracy: 0.9429
# Epoch 86/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3674 - accuracy: 0.9217 - val_loss: 0.2603 - val_accuracy: 0.9429
# Epoch 87/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4209 - accuracy: 0.9217 - val_loss: 0.2642 - val_accuracy: 0.9429
# Epoch 88/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3294 - accuracy: 0.9217 - val_loss: 0.2591 - val_accuracy: 0.9429
# Epoch 89/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3542 - accuracy: 0.9217 - val_loss: 0.2598 - val_accuracy: 0.9429
# Epoch 90/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3816 - accuracy: 0.9217 - val_loss: 0.2629 - val_accuracy: 0.9429
# Epoch 91/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.3310 - accuracy: 0.9217 - val_loss: 0.2587 - val_accuracy: 0.9429
# Epoch 92/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3399 - accuracy: 0.9217 - val_loss: 0.2577 - val_accuracy: 0.9429
# Epoch 93/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3380 - accuracy: 0.9217 - val_loss: 0.2619 - val_accuracy: 0.9429
# Epoch 94/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4433 - accuracy: 0.9217 - val_loss: 0.2646 - val_accuracy: 0.9429
# Epoch 95/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3303 - accuracy: 0.9217 - val_loss: 0.2624 - val_accuracy: 0.9429
# Epoch 96/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3979 - accuracy: 0.9217 - val_loss: 0.2613 - val_accuracy: 0.9429
# Epoch 97/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.4846 - accuracy: 0.9217 - val_loss: 0.2635 - val_accuracy: 0.9429
# Epoch 98/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.3478 - accuracy: 0.9217 - val_loss: 0.2617 - val_accuracy: 0.9429
# Epoch 99/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3505 - accuracy: 0.9217 - val_loss: 0.2626 - val_accuracy: 0.9429
# Epoch 100/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.3283 - accuracy: 0.9217 - val_loss: 0.2621 - val_accuracy: 0.9429

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2009-01-13       1179  1179  1179  ...              2    3000       3537000
# 2009-01-25       1179  1144  1144  ...              1     500        572000
# 2009-02-11       1179  1144  1144  ...              7   10690      12229360
# 2009-03-01       1172  1000  1136  ...              5   18005      20067984
# 2009-03-08       1115  1082  1082  ...              1    1000       1082000
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 2045

# %%
len(pictures)
# Out:
# 2045

# %%
# Divide the data into training and validation data
split_time = 1800
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          320
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 64)          18496
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 128)         73856
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 128)         147584
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 57/57 [==============================] - 2s 13ms/step - loss: 7.6706 - accuracy: 0.4867 - val_loss: 1.0755 - val_accuracy: 0.4980
# Epoch 2/100
# 57/57 [==============================] - 1s 9ms/step - loss: 1.0023 - accuracy: 0.4867 - val_loss: 0.7415 - val_accuracy: 0.4980
# Epoch 3/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.8114 - accuracy: 0.4867 - val_loss: 0.8178 - val_accuracy: 0.4980
# Epoch 4/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7652 - accuracy: 0.4867 - val_loss: 0.6982 - val_accuracy: 0.4980
# Epoch 5/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.7217 - accuracy: 0.4867 - val_loss: 0.6965 - val_accuracy: 0.4980
# Epoch 6/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7136 - accuracy: 0.4867 - val_loss: 0.7111 - val_accuracy: 0.4980
# Epoch 7/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7138 - accuracy: 0.4867 - val_loss: 0.6965 - val_accuracy: 0.4980
# Epoch 8/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7120 - accuracy: 0.4867 - val_loss: 0.6964 - val_accuracy: 0.4980
# Epoch 9/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7036 - accuracy: 0.4867 - val_loss: 0.6934 - val_accuracy: 0.4980
# Epoch 10/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7013 - accuracy: 0.4867 - val_loss: 0.6934 - val_accuracy: 0.4980
# Epoch 11/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.7015 - accuracy: 0.4867 - val_loss: 0.6958 - val_accuracy: 0.4980
# Epoch 12/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.7007 - accuracy: 0.4867 - val_loss: 0.6896 - val_accuracy: 0.4980
# Epoch 13/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6991 - accuracy: 0.4867 - val_loss: 0.6939 - val_accuracy: 0.4980
# Epoch 14/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6947 - accuracy: 0.4867 - val_loss: 0.6934 - val_accuracy: 0.4980
# Epoch 15/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6973 - accuracy: 0.4867 - val_loss: 0.6943 - val_accuracy: 0.4980
# Epoch 16/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7147 - accuracy: 0.4867 - val_loss: 0.6936 - val_accuracy: 0.4980
# Epoch 17/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6954 - accuracy: 0.4867 - val_loss: 0.6976 - val_accuracy: 0.4980
# Epoch 18/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.7039 - accuracy: 0.4867 - val_loss: 0.8033 - val_accuracy: 0.4980
# Epoch 19/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6970 - accuracy: 0.4867 - val_loss: 0.6944 - val_accuracy: 0.4980
# Epoch 20/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6992 - accuracy: 0.4867 - val_loss: 0.6923 - val_accuracy: 0.4980
# Epoch 21/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7032 - accuracy: 0.4867 - val_loss: 0.6896 - val_accuracy: 0.4980
# Epoch 22/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6927 - accuracy: 0.4867 - val_loss: 0.6935 - val_accuracy: 0.4980
# Epoch 23/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6907 - accuracy: 0.4867 - val_loss: 0.6926 - val_accuracy: 0.4980
# Epoch 24/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6929 - accuracy: 0.4867 - val_loss: 0.6920 - val_accuracy: 0.4980
# Epoch 25/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7087 - accuracy: 0.4867 - val_loss: 0.6917 - val_accuracy: 0.4980
# Epoch 26/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6964 - accuracy: 0.4867 - val_loss: 0.6893 - val_accuracy: 0.4980
# Epoch 27/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7003 - accuracy: 0.4867 - val_loss: 0.6941 - val_accuracy: 0.4980
# Epoch 28/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6943 - accuracy: 0.4867 - val_loss: 0.6933 - val_accuracy: 0.4980
# Epoch 29/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6961 - accuracy: 0.4867 - val_loss: 0.6920 - val_accuracy: 0.4980
# Epoch 30/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6908 - accuracy: 0.4867 - val_loss: 0.6950 - val_accuracy: 0.4980
# Epoch 31/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6959 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 32/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6961 - accuracy: 0.4867 - val_loss: 0.6933 - val_accuracy: 0.4980
# Epoch 33/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.4867 - val_loss: 0.6887 - val_accuracy: 0.4980
# Epoch 34/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6918 - accuracy: 0.4867 - val_loss: 0.7007 - val_accuracy: 0.4980
# Epoch 35/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6970 - accuracy: 0.4867 - val_loss: 0.6933 - val_accuracy: 0.4980
# Epoch 36/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6977 - accuracy: 0.4867 - val_loss: 0.6799 - val_accuracy: 0.4980
# Epoch 37/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6984 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 38/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6920 - accuracy: 0.4867 - val_loss: 0.6921 - val_accuracy: 0.4980
# Epoch 39/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6936 - accuracy: 0.4867 - val_loss: 0.6934 - val_accuracy: 0.4980
# Epoch 40/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7024 - accuracy: 0.4867 - val_loss: 0.6927 - val_accuracy: 0.4980
# Epoch 41/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.4867 - val_loss: 0.6920 - val_accuracy: 0.4980
# Epoch 42/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6963 - accuracy: 0.4867 - val_loss: 0.6916 - val_accuracy: 0.4980
# Epoch 43/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6995 - accuracy: 0.4867 - val_loss: 0.6932 - val_accuracy: 0.4980
# Epoch 44/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6904 - accuracy: 0.4867 - val_loss: 0.6944 - val_accuracy: 0.4980
# Epoch 45/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6978 - accuracy: 0.4867 - val_loss: 0.6926 - val_accuracy: 0.4980
# Epoch 46/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.4867 - val_loss: 0.6930 - val_accuracy: 0.4980
# Epoch 47/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6923 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.4980
# Epoch 48/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6911 - accuracy: 0.4867 - val_loss: 0.6907 - val_accuracy: 0.4980
# Epoch 49/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6929 - accuracy: 0.4867 - val_loss: 0.6882 - val_accuracy: 0.4980
# Epoch 50/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7008 - accuracy: 0.4867 - val_loss: 0.6893 - val_accuracy: 0.4980
# Epoch 51/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6942 - accuracy: 0.4867 - val_loss: 0.6912 - val_accuracy: 0.4980
# Epoch 52/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6981 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.4980
# Epoch 53/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6961 - accuracy: 0.4867 - val_loss: 0.6924 - val_accuracy: 0.4980
# Epoch 54/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7243 - accuracy: 0.4867 - val_loss: 0.6919 - val_accuracy: 0.4980
# Epoch 55/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6985 - accuracy: 0.4867 - val_loss: 0.6925 - val_accuracy: 0.4980
# Epoch 56/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.4867 - val_loss: 0.6916 - val_accuracy: 0.4980
# Epoch 57/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6978 - accuracy: 0.4867 - val_loss: 0.6922 - val_accuracy: 0.4980
# Epoch 58/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6972 - accuracy: 0.4867 - val_loss: 0.6922 - val_accuracy: 0.4980
# Epoch 59/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6936 - accuracy: 0.4867 - val_loss: 0.6918 - val_accuracy: 0.4980
# Epoch 60/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.7045 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.4980
# Epoch 61/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6985 - accuracy: 0.4867 - val_loss: 0.6917 - val_accuracy: 0.4980
# Epoch 62/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6956 - accuracy: 0.4867 - val_loss: 0.6929 - val_accuracy: 0.4980
# Epoch 63/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7024 - accuracy: 0.4867 - val_loss: 0.6884 - val_accuracy: 0.4980
# Epoch 64/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.4867 - val_loss: 0.7040 - val_accuracy: 0.4980
# Epoch 65/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6980 - accuracy: 0.4867 - val_loss: 0.6771 - val_accuracy: 0.4980
# Epoch 66/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6933 - accuracy: 0.4867 - val_loss: 0.6920 - val_accuracy: 0.4980
# Epoch 67/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6915 - accuracy: 0.4867 - val_loss: 0.6902 - val_accuracy: 0.4980
# Epoch 68/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7161 - accuracy: 0.4867 - val_loss: 0.6897 - val_accuracy: 0.4980
# Epoch 69/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6927 - accuracy: 0.4867 - val_loss: 0.6847 - val_accuracy: 0.4980
# Epoch 70/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6962 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.4980
# Epoch 71/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6896 - accuracy: 0.4867 - val_loss: 0.6849 - val_accuracy: 0.4980
# Epoch 72/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.7007 - accuracy: 0.4867 - val_loss: 0.6885 - val_accuracy: 0.4980
# Epoch 73/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.4867 - val_loss: 0.6926 - val_accuracy: 0.4980
# Epoch 74/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6970 - accuracy: 0.4867 - val_loss: 0.6922 - val_accuracy: 0.4980
# Epoch 75/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.4867 - val_loss: 0.6921 - val_accuracy: 0.4980
# Epoch 76/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6943 - accuracy: 0.4867 - val_loss: 0.6929 - val_accuracy: 0.4980
# Epoch 77/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6973 - accuracy: 0.4867 - val_loss: 0.6913 - val_accuracy: 0.4980
# Epoch 78/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6989 - accuracy: 0.4867 - val_loss: 0.6908 - val_accuracy: 0.4980
# Epoch 79/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6919 - accuracy: 0.4867 - val_loss: 0.6929 - val_accuracy: 0.4980
# Epoch 80/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6929 - accuracy: 0.4867 - val_loss: 0.6904 - val_accuracy: 0.4980
# Epoch 81/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6998 - accuracy: 0.4867 - val_loss: 0.6897 - val_accuracy: 0.4980
# Epoch 82/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6987 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.4980
# Epoch 83/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.4867 - val_loss: 0.6915 - val_accuracy: 0.4980
# Epoch 84/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7044 - accuracy: 0.4867 - val_loss: 0.6922 - val_accuracy: 0.4980
# Epoch 85/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6927 - accuracy: 0.4867 - val_loss: 0.6900 - val_accuracy: 0.4980
# Epoch 86/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7322 - accuracy: 0.4867 - val_loss: 0.6929 - val_accuracy: 0.4980
# Epoch 87/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6945 - accuracy: 0.4867 - val_loss: 0.6930 - val_accuracy: 0.4980
# Epoch 88/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6944 - accuracy: 0.4867 - val_loss: 0.6788 - val_accuracy: 0.4980
# Epoch 89/100
# 57/57 [==============================] - 1s 9ms/step - loss: 0.6910 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 90/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7068 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 91/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7003 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 92/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7035 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 93/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7024 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 94/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6992 - accuracy: 0.4867 - val_loss: 0.6930 - val_accuracy: 0.4980
# Epoch 95/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6963 - accuracy: 0.4867 - val_loss: 0.6854 - val_accuracy: 0.4980
# Epoch 96/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6980 - accuracy: 0.4867 - val_loss: 0.6931 - val_accuracy: 0.4980
# Epoch 97/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7035 - accuracy: 0.4867 - val_loss: 0.6932 - val_accuracy: 0.4980
# Epoch 98/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.7021 - accuracy: 0.4867 - val_loss: 0.6918 - val_accuracy: 0.4980
# Epoch 99/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6922 - accuracy: 0.4867 - val_loss: 0.6927 - val_accuracy: 0.4980
# Epoch 100/100
# 57/57 [==============================] - 1s 10ms/step - loss: 0.6952 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.4980

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
