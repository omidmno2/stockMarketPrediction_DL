# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "ولساپا"].head()
# Out:
#            Date  Symbol  ...  Volume  Value Traded
# 75   2008-12-06  ولساپا  ...  164590     397649440
# 105  2008-12-07  ولساپا  ...  118990     290454590
# 208  2008-12-08  ولساپا  ...   92913     226896546
# 304  2008-12-10  ولساپا  ...   83000     202769000
# 400  2008-12-13  ولساپا  ...   73387     179357828
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "ولساپا"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2550)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, low=data.Low, close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2531

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2538

# %%
len(data.Last)
# Out:
# 2550

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2525
# 2525

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
    x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    x = principalDf.transpose()

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    pictures[i] = principalDf

# %%
pictures[100]
# Out:
#               0            1           2  ...          7          8             9
# 0  31862.535606     0.181144    0.004095  ...   0.000044  -0.000030  2.798267e-13
# 1  -3545.101560  1183.907435    3.153648  ...   0.030995  -0.021526  2.798267e-13
# 2  -3540.032777  -159.558337  347.756289  ...   0.362455  -0.247745  2.798267e-13
# 3  -3539.815148  -152.134995  -94.024214  ...   0.671016  -0.451997  2.798267e-13
# 4  -3539.726352  -149.300624  -61.924108  ...   1.028185  -0.681147  2.798267e-13
# 5  -3539.615879  -145.918251  -43.462616  ...   3.044253  -1.844748  2.798267e-13
# 6  -3539.576394  -144.746158  -39.277164  ...  10.176554  -4.737437  2.798267e-13
# 7  -3539.563016  -144.353290  -38.036112  ...  49.355200 -10.107416  2.798267e-13
# 8  -3539.556059  -144.149812  -37.421173  ... -49.245577 -24.622999  2.798267e-13
# 9  -3539.548421  -143.927112  -36.768646  ... -15.423125  42.715046  2.798267e-13
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_56 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_57 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_58 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_59 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_14 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_28 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_14 (Flatten)        (None, 128)               0
#
#  dense_28 (Dense)            (None, 128)               16512
#
#  dropout_29 (Dropout)        (None, 128)               0
#
#  dense_29 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 13ms/step - loss: 2.9935 - accuracy: 0.8305 - val_loss: 0.5044 - val_accuracy: 0.9544
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5752 - accuracy: 0.9105 - val_loss: 0.4532 - val_accuracy: 0.9544
# Epoch 3/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.5100 - accuracy: 0.9195 - val_loss: 0.3166 - val_accuracy: 0.9544
# Epoch 4/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4731 - accuracy: 0.9200 - val_loss: 0.3178 - val_accuracy: 0.9544
# Epoch 5/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4647 - accuracy: 0.9200 - val_loss: 0.2903 - val_accuracy: 0.9544
# Epoch 6/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4017 - accuracy: 0.9200 - val_loss: 0.3273 - val_accuracy: 0.9544
# Epoch 7/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3857 - accuracy: 0.9200 - val_loss: 0.2691 - val_accuracy: 0.9544
# Epoch 8/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3971 - accuracy: 0.9200 - val_loss: 0.2613 - val_accuracy: 0.9544
# Epoch 9/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3675 - accuracy: 0.9200 - val_loss: 0.2658 - val_accuracy: 0.9544
# Epoch 10/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3663 - accuracy: 0.9200 - val_loss: 0.2371 - val_accuracy: 0.9544
# Epoch 11/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3566 - accuracy: 0.9200 - val_loss: 0.2343 - val_accuracy: 0.9544
# Epoch 12/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3523 - accuracy: 0.9200 - val_loss: 0.2353 - val_accuracy: 0.9544
# Epoch 13/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3572 - accuracy: 0.9200 - val_loss: 0.2296 - val_accuracy: 0.9544
# Epoch 14/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3629 - accuracy: 0.9200 - val_loss: 0.2394 - val_accuracy: 0.9544
# Epoch 15/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3515 - accuracy: 0.9200 - val_loss: 0.2262 - val_accuracy: 0.9544
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3533 - accuracy: 0.9200 - val_loss: 0.2332 - val_accuracy: 0.9544
# Epoch 17/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3677 - accuracy: 0.9200 - val_loss: 0.2312 - val_accuracy: 0.9544
# Epoch 18/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3487 - accuracy: 0.9200 - val_loss: 0.2305 - val_accuracy: 0.9544
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3656 - accuracy: 0.9200 - val_loss: 0.2362 - val_accuracy: 0.9544
# Epoch 20/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3451 - accuracy: 0.9200 - val_loss: 0.2263 - val_accuracy: 0.9544
# Epoch 21/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3566 - accuracy: 0.9200 - val_loss: 0.2308 - val_accuracy: 0.9544
# Epoch 22/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3521 - accuracy: 0.9200 - val_loss: 0.2336 - val_accuracy: 0.9544
# Epoch 23/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3491 - accuracy: 0.9200 - val_loss: 0.2402 - val_accuracy: 0.9544
# Epoch 24/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3554 - accuracy: 0.9200 - val_loss: 0.2269 - val_accuracy: 0.9544
# Epoch 25/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3512 - accuracy: 0.9200 - val_loss: 0.2247 - val_accuracy: 0.9544
# Epoch 26/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3499 - accuracy: 0.9200 - val_loss: 0.2291 - val_accuracy: 0.9544
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3493 - accuracy: 0.9200 - val_loss: 0.2320 - val_accuracy: 0.9544
# Epoch 28/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3514 - accuracy: 0.9200 - val_loss: 0.2283 - val_accuracy: 0.9544
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3435 - accuracy: 0.9200 - val_loss: 0.2244 - val_accuracy: 0.9544
# Epoch 30/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3890 - accuracy: 0.9200 - val_loss: 0.2410 - val_accuracy: 0.9544
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3472 - accuracy: 0.9200 - val_loss: 0.2301 - val_accuracy: 0.9544
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3501 - accuracy: 0.9200 - val_loss: 0.2239 - val_accuracy: 0.9544
# Epoch 33/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3488 - accuracy: 0.9200 - val_loss: 0.2215 - val_accuracy: 0.9544
# Epoch 34/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3509 - accuracy: 0.9200 - val_loss: 0.2264 - val_accuracy: 0.9544
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3447 - accuracy: 0.9200 - val_loss: 0.2278 - val_accuracy: 0.9544
# Epoch 36/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3443 - accuracy: 0.9200 - val_loss: 0.2201 - val_accuracy: 0.9544
# Epoch 37/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3526 - accuracy: 0.9200 - val_loss: 0.2262 - val_accuracy: 0.9544
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3424 - accuracy: 0.9200 - val_loss: 0.4119 - val_accuracy: 0.9544
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3643 - accuracy: 0.9200 - val_loss: 0.2217 - val_accuracy: 0.9544
# Epoch 40/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3551 - accuracy: 0.9200 - val_loss: 0.2220 - val_accuracy: 0.9544
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4065 - accuracy: 0.9200 - val_loss: 0.2287 - val_accuracy: 0.9544
# Epoch 42/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3423 - accuracy: 0.9200 - val_loss: 0.2305 - val_accuracy: 0.9544
# Epoch 43/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3453 - accuracy: 0.9200 - val_loss: 0.2241 - val_accuracy: 0.9544
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3487 - accuracy: 0.9200 - val_loss: 0.2215 - val_accuracy: 0.9544
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3386 - accuracy: 0.9200 - val_loss: 0.2285 - val_accuracy: 0.9544
# Epoch 46/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.3483 - accuracy: 0.9200 - val_loss: 0.2271 - val_accuracy: 0.9544
# Epoch 47/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.3484 - accuracy: 0.9200 - val_loss: 0.2253 - val_accuracy: 0.9544
# Epoch 48/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.3457 - accuracy: 0.9200 - val_loss: 0.7350 - val_accuracy: 0.9544
# Epoch 49/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.3573 - accuracy: 0.9200 - val_loss: 0.2303 - val_accuracy: 0.9544
# Epoch 50/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.3430 - accuracy: 0.9200 - val_loss: 0.2272 - val_accuracy: 0.9544
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3508 - accuracy: 0.9200 - val_loss: 0.2266 - val_accuracy: 0.9544
# Epoch 52/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3821 - accuracy: 0.9200 - val_loss: 0.2347 - val_accuracy: 0.9544
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3500 - accuracy: 0.9200 - val_loss: 0.2320 - val_accuracy: 0.9544
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3425 - accuracy: 0.9200 - val_loss: 0.2226 - val_accuracy: 0.9544
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3388 - accuracy: 0.9200 - val_loss: 0.2483 - val_accuracy: 0.9544
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3646 - accuracy: 0.9200 - val_loss: 0.2376 - val_accuracy: 0.9544
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3445 - accuracy: 0.9200 - val_loss: 0.2264 - val_accuracy: 0.9544
# Epoch 58/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3544 - accuracy: 0.9200 - val_loss: 0.2341 - val_accuracy: 0.9544
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3540 - accuracy: 0.9200 - val_loss: 0.2353 - val_accuracy: 0.9544
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3580 - accuracy: 0.9200 - val_loss: 0.2348 - val_accuracy: 0.9544
# Epoch 61/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3460 - accuracy: 0.9200 - val_loss: 0.2416 - val_accuracy: 0.9544
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3813 - accuracy: 0.9200 - val_loss: 0.2461 - val_accuracy: 0.9544
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3499 - accuracy: 0.9200 - val_loss: 0.2307 - val_accuracy: 0.9544
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3421 - accuracy: 0.9200 - val_loss: 0.2319 - val_accuracy: 0.9544
# Epoch 65/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3726 - accuracy: 0.9200 - val_loss: 0.2691 - val_accuracy: 0.9544
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3511 - accuracy: 0.9200 - val_loss: 0.2330 - val_accuracy: 0.9544
# Epoch 67/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3803 - accuracy: 0.9200 - val_loss: 0.2301 - val_accuracy: 0.9544
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3672 - accuracy: 0.9200 - val_loss: 0.2380 - val_accuracy: 0.9544
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3469 - accuracy: 0.9200 - val_loss: 0.2333 - val_accuracy: 0.9544
# Epoch 70/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3383 - accuracy: 0.9200 - val_loss: 0.2285 - val_accuracy: 0.9544
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3459 - accuracy: 0.9200 - val_loss: 0.2369 - val_accuracy: 0.9544
# Epoch 72/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3542 - accuracy: 0.9200 - val_loss: 0.2261 - val_accuracy: 0.9544
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3806 - accuracy: 0.9200 - val_loss: 0.2388 - val_accuracy: 0.9544
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3599 - accuracy: 0.9200 - val_loss: 0.2308 - val_accuracy: 0.9544
# Epoch 75/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3426 - accuracy: 0.9200 - val_loss: 0.2281 - val_accuracy: 0.9544
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3735 - accuracy: 0.9200 - val_loss: 0.2276 - val_accuracy: 0.9544
# Epoch 77/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3464 - accuracy: 0.9200 - val_loss: 1.3667 - val_accuracy: 0.9544
# Epoch 78/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3608 - accuracy: 0.9200 - val_loss: 0.2343 - val_accuracy: 0.9544
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3690 - accuracy: 0.9200 - val_loss: 0.2385 - val_accuracy: 0.9544
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3658 - accuracy: 0.9200 - val_loss: 0.2474 - val_accuracy: 0.9544
# Epoch 81/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3865 - accuracy: 0.9200 - val_loss: 0.2427 - val_accuracy: 0.9544
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3495 - accuracy: 0.9200 - val_loss: 0.2285 - val_accuracy: 0.9544
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3668 - accuracy: 0.9200 - val_loss: 0.2296 - val_accuracy: 0.9544
# Epoch 84/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3393 - accuracy: 0.9200 - val_loss: 0.2370 - val_accuracy: 0.9544
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3741 - accuracy: 0.9200 - val_loss: 0.2325 - val_accuracy: 0.9544
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3555 - accuracy: 0.9200 - val_loss: 0.2396 - val_accuracy: 0.9544
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3640 - accuracy: 0.9191 - val_loss: 0.2349 - val_accuracy: 0.9544
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3561 - accuracy: 0.9195 - val_loss: 0.2438 - val_accuracy: 0.9544
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3491 - accuracy: 0.9200 - val_loss: 0.2248 - val_accuracy: 0.9544
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3526 - accuracy: 0.9200 - val_loss: 0.2344 - val_accuracy: 0.9544
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3427 - accuracy: 0.9200 - val_loss: 0.2295 - val_accuracy: 0.9544
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3523 - accuracy: 0.9200 - val_loss: 0.2563 - val_accuracy: 0.9544
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3484 - accuracy: 0.9200 - val_loss: 0.4483 - val_accuracy: 0.9544
# Epoch 94/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3562 - accuracy: 0.9200 - val_loss: 0.2375 - val_accuracy: 0.9544
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3468 - accuracy: 0.9200 - val_loss: 0.2307 - val_accuracy: 0.9544
# Epoch 96/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3513 - accuracy: 0.9200 - val_loss: 0.2295 - val_accuracy: 0.9544
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3791 - accuracy: 0.9200 - val_loss: 0.2320 - val_accuracy: 0.9544
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3518 - accuracy: 0.9200 - val_loss: 0.2310 - val_accuracy: 0.9544
# Epoch 99/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3523 - accuracy: 0.9191 - val_loss: 0.3226 - val_accuracy: 0.9544
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3436 - accuracy: 0.9195 - val_loss: 0.2342 - val_accuracy: 0.9544

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2008-12-06       2490  2416  2416  ...             66  164590     397649440
# 2008-12-07       2439  2441  2441  ...             47  118990     290454590
# 2008-12-08       2440  2442  2443  ...             41   92913     226896546
# 2008-12-10       2441  2443  2443  ...             29   83000     202769000
# 2008-12-13       2442  2444  2444  ...             33   73387     179357828
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 2485

# %%
len(pictures)
# Out:
# 2485

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_60 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_61 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_62 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_63 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_15 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_30 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_15 (Flatten)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 128)               16512
#
#  dropout_31 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 13ms/step - loss: 2.1081 - accuracy: 0.4973 - val_loss: 0.6835 - val_accuracy: 0.5719
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7380 - accuracy: 0.4973 - val_loss: 0.6864 - val_accuracy: 0.5719
# Epoch 3/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7151 - accuracy: 0.4973 - val_loss: 0.7020 - val_accuracy: 0.5719
# Epoch 4/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7093 - accuracy: 0.4973 - val_loss: 0.6891 - val_accuracy: 0.5719
# Epoch 5/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7080 - accuracy: 0.4973 - val_loss: 0.6954 - val_accuracy: 0.5719
# Epoch 6/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7032 - accuracy: 0.4973 - val_loss: 0.6968 - val_accuracy: 0.5719
# Epoch 7/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7009 - accuracy: 0.4973 - val_loss: 0.7088 - val_accuracy: 0.5719
# Epoch 8/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6992 - accuracy: 0.4973 - val_loss: 0.7021 - val_accuracy: 0.5719
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7066 - accuracy: 0.4973 - val_loss: 0.6870 - val_accuracy: 0.5719
# Epoch 10/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6977 - accuracy: 0.4973 - val_loss: 0.6963 - val_accuracy: 0.5719
# Epoch 11/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6964 - accuracy: 0.4973 - val_loss: 0.6956 - val_accuracy: 0.5719
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.4973 - val_loss: 0.7030 - val_accuracy: 0.5719
# Epoch 13/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6965 - accuracy: 0.4973 - val_loss: 0.6966 - val_accuracy: 0.5719
# Epoch 14/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6962 - accuracy: 0.4973 - val_loss: 0.7018 - val_accuracy: 0.5719
# Epoch 15/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6991 - accuracy: 0.4973 - val_loss: 0.7029 - val_accuracy: 0.5719
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7062 - accuracy: 0.4973 - val_loss: 0.6931 - val_accuracy: 0.5719
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6974 - accuracy: 0.4973 - val_loss: 0.7016 - val_accuracy: 0.5719
# Epoch 18/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6952 - accuracy: 0.4973 - val_loss: 0.6914 - val_accuracy: 0.5719
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6934 - accuracy: 0.4973 - val_loss: 0.7059 - val_accuracy: 0.5719
# Epoch 20/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6935 - accuracy: 0.4973 - val_loss: 0.7085 - val_accuracy: 0.5719
# Epoch 21/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6951 - accuracy: 0.4973 - val_loss: 0.6989 - val_accuracy: 0.5719
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6922 - accuracy: 0.4973 - val_loss: 0.6952 - val_accuracy: 0.5719
# Epoch 23/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6947 - accuracy: 0.4973 - val_loss: 0.7026 - val_accuracy: 0.5719
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6952 - accuracy: 0.4973 - val_loss: 0.7020 - val_accuracy: 0.5719
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6933 - accuracy: 0.4973 - val_loss: 0.7067 - val_accuracy: 0.5719
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.4973 - val_loss: 0.6992 - val_accuracy: 0.5719
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6943 - accuracy: 0.4973 - val_loss: 0.7061 - val_accuracy: 0.5719
# Epoch 28/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6948 - accuracy: 0.4973 - val_loss: 0.7053 - val_accuracy: 0.5719
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6936 - accuracy: 0.4973 - val_loss: 0.7132 - val_accuracy: 0.5719
# Epoch 30/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6921 - accuracy: 0.4973 - val_loss: 0.7844 - val_accuracy: 0.5719
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6921 - accuracy: 0.4973 - val_loss: 0.7056 - val_accuracy: 0.5719
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6918 - accuracy: 0.4973 - val_loss: 0.7199 - val_accuracy: 0.5719
# Epoch 33/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6921 - accuracy: 0.4973 - val_loss: 0.7358 - val_accuracy: 0.5719
# Epoch 34/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6899 - accuracy: 0.4973 - val_loss: 0.7247 - val_accuracy: 0.5719
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6923 - accuracy: 0.4973 - val_loss: 0.6950 - val_accuracy: 0.5719
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6899 - accuracy: 0.4973 - val_loss: 0.7249 - val_accuracy: 0.5719
# Epoch 37/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6932 - accuracy: 0.4973 - val_loss: 0.6981 - val_accuracy: 0.5719
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6898 - accuracy: 0.4973 - val_loss: 0.7067 - val_accuracy: 0.5719
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6874 - accuracy: 0.4973 - val_loss: 0.7596 - val_accuracy: 0.5719
# Epoch 40/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6902 - accuracy: 0.4973 - val_loss: 0.7477 - val_accuracy: 0.5719
# Epoch 41/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6904 - accuracy: 0.4973 - val_loss: 0.7096 - val_accuracy: 0.5719
# Epoch 42/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6897 - accuracy: 0.4973 - val_loss: 0.7028 - val_accuracy: 0.5719
# Epoch 43/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6942 - accuracy: 0.4973 - val_loss: 0.7240 - val_accuracy: 0.5719
# Epoch 44/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6896 - accuracy: 0.4973 - val_loss: 0.7491 - val_accuracy: 0.5719
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6908 - accuracy: 0.4973 - val_loss: 0.7027 - val_accuracy: 0.5719
# Epoch 46/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6878 - accuracy: 0.4973 - val_loss: 0.7172 - val_accuracy: 0.5719
# Epoch 47/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6888 - accuracy: 0.4973 - val_loss: 0.7061 - val_accuracy: 0.5719
# Epoch 48/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6913 - accuracy: 0.4973 - val_loss: 0.7181 - val_accuracy: 0.5719
# Epoch 49/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.4973 - val_loss: 0.7151 - val_accuracy: 0.5719
# Epoch 50/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6911 - accuracy: 0.4973 - val_loss: 0.7150 - val_accuracy: 0.5719
# Epoch 51/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6872 - accuracy: 0.4973 - val_loss: 0.7105 - val_accuracy: 0.5719
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6890 - accuracy: 0.4973 - val_loss: 0.6943 - val_accuracy: 0.5719
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6886 - accuracy: 0.4973 - val_loss: 0.7108 - val_accuracy: 0.5719
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.4973 - val_loss: 0.7185 - val_accuracy: 0.5719
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6869 - accuracy: 0.4973 - val_loss: 0.7411 - val_accuracy: 0.5719
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6860 - accuracy: 0.4973 - val_loss: 0.7131 - val_accuracy: 0.5719
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.4973 - val_loss: 0.7191 - val_accuracy: 0.5719
# Epoch 58/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6894 - accuracy: 0.4973 - val_loss: 0.7051 - val_accuracy: 0.5719
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6914 - accuracy: 0.4973 - val_loss: 0.7107 - val_accuracy: 0.5719
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.4973 - val_loss: 0.7078 - val_accuracy: 0.5719
# Epoch 61/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6897 - accuracy: 0.4973 - val_loss: 0.7400 - val_accuracy: 0.5719
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6850 - accuracy: 0.4973 - val_loss: 0.7116 - val_accuracy: 0.5719
# Epoch 63/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6863 - accuracy: 0.4973 - val_loss: 0.7556 - val_accuracy: 0.5719
# Epoch 64/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6884 - accuracy: 0.4973 - val_loss: 0.7170 - val_accuracy: 0.5719
# Epoch 65/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6832 - accuracy: 0.4973 - val_loss: 0.7484 - val_accuracy: 0.5719
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6889 - accuracy: 0.4973 - val_loss: 0.7080 - val_accuracy: 0.5719
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6859 - accuracy: 0.4973 - val_loss: 0.7115 - val_accuracy: 0.5719
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6842 - accuracy: 0.4973 - val_loss: 0.7217 - val_accuracy: 0.5719
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6893 - accuracy: 0.4973 - val_loss: 0.7239 - val_accuracy: 0.5719
# Epoch 70/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6871 - accuracy: 0.4973 - val_loss: 0.7158 - val_accuracy: 0.5719
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6832 - accuracy: 0.4973 - val_loss: 0.7093 - val_accuracy: 0.5719
# Epoch 72/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6859 - accuracy: 0.4973 - val_loss: 0.7289 - val_accuracy: 0.5719
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6880 - accuracy: 0.4973 - val_loss: 0.7156 - val_accuracy: 0.5719
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6886 - accuracy: 0.4973 - val_loss: 0.7050 - val_accuracy: 0.5719
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6829 - accuracy: 0.4973 - val_loss: 0.7614 - val_accuracy: 0.5719
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6828 - accuracy: 0.4973 - val_loss: 0.7081 - val_accuracy: 0.5719
# Epoch 77/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6843 - accuracy: 0.4973 - val_loss: 0.7112 - val_accuracy: 0.5719
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6859 - accuracy: 0.4973 - val_loss: 0.7185 - val_accuracy: 0.5719
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6833 - accuracy: 0.4973 - val_loss: 0.6911 - val_accuracy: 0.5719
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6772 - accuracy: 0.4973 - val_loss: 0.7558 - val_accuracy: 0.5719
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6886 - accuracy: 0.4973 - val_loss: 0.6930 - val_accuracy: 0.5719
# Epoch 82/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6885 - accuracy: 0.4973 - val_loss: 0.7075 - val_accuracy: 0.5719
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6818 - accuracy: 0.4973 - val_loss: 0.7336 - val_accuracy: 0.5719
# Epoch 84/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6889 - accuracy: 0.4973 - val_loss: 0.6990 - val_accuracy: 0.5719
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6876 - accuracy: 0.4973 - val_loss: 0.7470 - val_accuracy: 0.5719
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7139 - accuracy: 0.4973 - val_loss: 0.7750 - val_accuracy: 0.5719
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6803 - accuracy: 0.4973 - val_loss: 0.7047 - val_accuracy: 0.5719
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6940 - accuracy: 0.4973 - val_loss: 0.7720 - val_accuracy: 0.5719
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6889 - accuracy: 0.4973 - val_loss: 0.7189 - val_accuracy: 0.5719
# Epoch 90/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6800 - accuracy: 0.4973 - val_loss: 0.7577 - val_accuracy: 0.5719
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6837 - accuracy: 0.4973 - val_loss: 0.6946 - val_accuracy: 0.5719
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6838 - accuracy: 0.4973 - val_loss: 0.7240 - val_accuracy: 0.5719
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6810 - accuracy: 0.4973 - val_loss: 0.7028 - val_accuracy: 0.5719
# Epoch 94/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6931 - accuracy: 0.4973 - val_loss: 0.7329 - val_accuracy: 0.5719
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6854 - accuracy: 0.4973 - val_loss: 0.7237 - val_accuracy: 0.5719
# Epoch 96/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6889 - accuracy: 0.4973 - val_loss: 0.7022 - val_accuracy: 0.5719
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6821 - accuracy: 0.4973 - val_loss: 0.6946 - val_accuracy: 0.5719
# Epoch 98/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6819 - accuracy: 0.4973 - val_loss: 0.7068 - val_accuracy: 0.5719
# Epoch 99/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6804 - accuracy: 0.4973 - val_loss: 0.7155 - val_accuracy: 0.5719
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6794 - accuracy: 0.4973 - val_loss: 0.6904 - val_accuracy: 0.5719

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
