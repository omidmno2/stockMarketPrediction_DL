# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "شپارس"].head()
# Out:
#            Date Symbol  ... Volume  Value Traded
# 43   2008-12-06  شپارس  ...    103        388104
# 130  2008-12-07  شپارس  ...    213        802584
# 232  2008-12-08  شپارس  ...    107        403069
# 319  2008-12-10  شپارس  ...    104        391768
# 422  2008-12-13  شپارس  ...    106        399302
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "شپارس"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(1830)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, low=data.Low, close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 1811

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 1818

# %%
len(data.Last)
# Out:
# 1830

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 1805
# 1805

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
    x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    x = principalDf.transpose()

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    pictures[i] = principalDf

# %%
pictures[100]
# Out:
#               0            1  ...             8             9
# 0  35043.185103     1.702668  ... -4.098797e-08  2.906489e-13
# 1  -3916.032954  2637.359206  ... -7.060955e-06  2.906489e-13
# 2  -3891.592148  -340.541267  ... -2.173961e-04  2.906489e-13
# 3  -3890.866655  -329.428569  ... -1.975435e-03  2.906489e-13
# 4  -3890.793514  -328.348124  ... -1.070380e-02  2.906489e-13
# 5  -3890.789592  -328.290378  ... -1.402801e-02  2.906489e-13
# 6  -3890.779169  -328.137045  ... -8.023787e-02  2.906489e-13
# 7  -3890.777129  -328.107040  ... -1.057771e+00  2.906489e-13
# 8  -3890.777027  -328.105553  ... -2.668562e+00  2.906489e-13
# 9  -3890.776915  -328.103897  ...  3.833503e+00  2.906489e-13
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 1500
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 8, 8, 32)          320
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 64)          18496
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 47/47 [==============================] - 2s 19ms/step - loss: 3.2802 - accuracy: 0.8587 - val_loss: 1.0227 - val_accuracy: 0.8868
# Epoch 2/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7011 - accuracy: 0.8953 - val_loss: 1.0154 - val_accuracy: 0.8868
# Epoch 3/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.5626 - accuracy: 0.9213 - val_loss: 0.8027 - val_accuracy: 0.8868
# Epoch 4/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.5065 - accuracy: 0.9280 - val_loss: 0.4949 - val_accuracy: 0.8868
# Epoch 5/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4964 - accuracy: 0.9287 - val_loss: 0.7546 - val_accuracy: 0.8868
# Epoch 6/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4472 - accuracy: 0.9287 - val_loss: 1.0853 - val_accuracy: 0.8868
# Epoch 7/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.5096 - accuracy: 0.9287 - val_loss: 0.6084 - val_accuracy: 0.8868
# Epoch 8/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4665 - accuracy: 0.9287 - val_loss: 0.4718 - val_accuracy: 0.8868
# Epoch 9/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4235 - accuracy: 0.9287 - val_loss: 0.8359 - val_accuracy: 0.8868
# Epoch 10/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4109 - accuracy: 0.9287 - val_loss: 0.4627 - val_accuracy: 0.8868
# Epoch 11/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3912 - accuracy: 0.9287 - val_loss: 0.4783 - val_accuracy: 0.8868
# Epoch 12/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3761 - accuracy: 0.9287 - val_loss: 0.4489 - val_accuracy: 0.8868
# Epoch 13/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3817 - accuracy: 0.9287 - val_loss: 0.5381 - val_accuracy: 0.8868
# Epoch 14/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3864 - accuracy: 0.9287 - val_loss: 0.4695 - val_accuracy: 0.8868
# Epoch 15/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3914 - accuracy: 0.9287 - val_loss: 0.7402 - val_accuracy: 0.8868
# Epoch 16/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3558 - accuracy: 0.9287 - val_loss: 0.4261 - val_accuracy: 0.8868
# Epoch 17/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3472 - accuracy: 0.9287 - val_loss: 0.4905 - val_accuracy: 0.8868
# Epoch 18/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3746 - accuracy: 0.9287 - val_loss: 0.5156 - val_accuracy: 0.8868
# Epoch 19/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3432 - accuracy: 0.9287 - val_loss: 0.4530 - val_accuracy: 0.8868
# Epoch 20/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3516 - accuracy: 0.9287 - val_loss: 0.4333 - val_accuracy: 0.8868
# Epoch 21/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3768 - accuracy: 0.9287 - val_loss: 0.4265 - val_accuracy: 0.8868
# Epoch 22/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3378 - accuracy: 0.9287 - val_loss: 0.4319 - val_accuracy: 0.8868
# Epoch 23/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3383 - accuracy: 0.9287 - val_loss: 0.7220 - val_accuracy: 0.8868
# Epoch 24/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3473 - accuracy: 0.9287 - val_loss: 0.5973 - val_accuracy: 0.8868
# Epoch 25/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3370 - accuracy: 0.9287 - val_loss: 0.4517 - val_accuracy: 0.8868
# Epoch 26/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3418 - accuracy: 0.9287 - val_loss: 0.4279 - val_accuracy: 0.8868
# Epoch 27/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3511 - accuracy: 0.9287 - val_loss: 0.4321 - val_accuracy: 0.8868
# Epoch 28/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3821 - accuracy: 0.9287 - val_loss: 0.4534 - val_accuracy: 0.8868
# Epoch 29/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3190 - accuracy: 0.9287 - val_loss: 0.4278 - val_accuracy: 0.8868
# Epoch 30/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3407 - accuracy: 0.9287 - val_loss: 0.4871 - val_accuracy: 0.8868
# Epoch 31/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3324 - accuracy: 0.9287 - val_loss: 0.4960 - val_accuracy: 0.8868
# Epoch 32/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3343 - accuracy: 0.9287 - val_loss: 0.4312 - val_accuracy: 0.8868
# Epoch 33/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3534 - accuracy: 0.9287 - val_loss: 0.4324 - val_accuracy: 0.8868
# Epoch 34/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3517 - accuracy: 0.9287 - val_loss: 0.4337 - val_accuracy: 0.8868
# Epoch 35/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3222 - accuracy: 0.9287 - val_loss: 0.4418 - val_accuracy: 0.8868
# Epoch 36/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3139 - accuracy: 0.9287 - val_loss: 0.4369 - val_accuracy: 0.8868
# Epoch 37/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3282 - accuracy: 0.9287 - val_loss: 0.5542 - val_accuracy: 0.8868
# Epoch 38/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3212 - accuracy: 0.9287 - val_loss: 0.4509 - val_accuracy: 0.8868
# Epoch 39/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3997 - accuracy: 0.9287 - val_loss: 0.4303 - val_accuracy: 0.8868
# Epoch 40/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3182 - accuracy: 0.9287 - val_loss: 0.4310 - val_accuracy: 0.8868
# Epoch 41/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3127 - accuracy: 0.9287 - val_loss: 0.6151 - val_accuracy: 0.8868
# Epoch 42/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3550 - accuracy: 0.9287 - val_loss: 0.5215 - val_accuracy: 0.8868
# Epoch 43/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3680 - accuracy: 0.9287 - val_loss: 0.4812 - val_accuracy: 0.8868
# Epoch 44/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3292 - accuracy: 0.9287 - val_loss: 0.4370 - val_accuracy: 0.8868
# Epoch 45/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.4906 - accuracy: 0.9287 - val_loss: 0.4747 - val_accuracy: 0.8868
# Epoch 46/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3352 - accuracy: 0.9287 - val_loss: 0.4367 - val_accuracy: 0.8868
# Epoch 47/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3191 - accuracy: 0.9287 - val_loss: 0.4374 - val_accuracy: 0.8868
# Epoch 48/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3149 - accuracy: 0.9287 - val_loss: 0.4423 - val_accuracy: 0.8868
# Epoch 49/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3586 - accuracy: 0.9287 - val_loss: 0.4370 - val_accuracy: 0.8868
# Epoch 50/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3238 - accuracy: 0.9287 - val_loss: 0.4367 - val_accuracy: 0.8868
# Epoch 51/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3287 - accuracy: 0.9287 - val_loss: 0.4409 - val_accuracy: 0.8868
# Epoch 52/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3296 - accuracy: 0.9287 - val_loss: 0.4394 - val_accuracy: 0.8868
# Epoch 53/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3584 - accuracy: 0.9287 - val_loss: 0.4370 - val_accuracy: 0.8868
# Epoch 54/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.4134 - accuracy: 0.9287 - val_loss: 0.4398 - val_accuracy: 0.8868
# Epoch 55/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3279 - accuracy: 0.9287 - val_loss: 0.4391 - val_accuracy: 0.8868
# Epoch 56/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3577 - accuracy: 0.9287 - val_loss: 0.6477 - val_accuracy: 0.8868
# Epoch 57/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3648 - accuracy: 0.9287 - val_loss: 0.4358 - val_accuracy: 0.8868
# Epoch 58/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3141 - accuracy: 0.9287 - val_loss: 0.4394 - val_accuracy: 0.8868
# Epoch 59/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3287 - accuracy: 0.9287 - val_loss: 0.4393 - val_accuracy: 0.8868
# Epoch 60/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3194 - accuracy: 0.9287 - val_loss: 0.5494 - val_accuracy: 0.8868
# Epoch 61/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3534 - accuracy: 0.9287 - val_loss: 1.0664 - val_accuracy: 0.8868
# Epoch 62/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3288 - accuracy: 0.9287 - val_loss: 0.4367 - val_accuracy: 0.8868
# Epoch 63/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3448 - accuracy: 0.9287 - val_loss: 0.4351 - val_accuracy: 0.8868
# Epoch 64/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3174 - accuracy: 0.9287 - val_loss: 0.4404 - val_accuracy: 0.8868
# Epoch 65/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4236 - accuracy: 0.9287 - val_loss: 1.2391 - val_accuracy: 0.8868
# Epoch 66/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3277 - accuracy: 0.9287 - val_loss: 4.3915 - val_accuracy: 0.8868
# Epoch 67/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3605 - accuracy: 0.9287 - val_loss: 0.4681 - val_accuracy: 0.8868
# Epoch 68/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3244 - accuracy: 0.9287 - val_loss: 0.4359 - val_accuracy: 0.8868
# Epoch 69/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3536 - accuracy: 0.9287 - val_loss: 0.4377 - val_accuracy: 0.8868
# Epoch 70/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3341 - accuracy: 0.9287 - val_loss: 0.4609 - val_accuracy: 0.8868
# Epoch 71/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3299 - accuracy: 0.9287 - val_loss: 0.5656 - val_accuracy: 0.8868
# Epoch 72/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3351 - accuracy: 0.9280 - val_loss: 0.4372 - val_accuracy: 0.8868
# Epoch 73/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3137 - accuracy: 0.9287 - val_loss: 0.4406 - val_accuracy: 0.8868
# Epoch 74/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3647 - accuracy: 0.9287 - val_loss: 0.4367 - val_accuracy: 0.8868
# Epoch 75/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3188 - accuracy: 0.9287 - val_loss: 0.4362 - val_accuracy: 0.8868
# Epoch 76/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3276 - accuracy: 0.9287 - val_loss: 0.4390 - val_accuracy: 0.8868
# Epoch 77/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3112 - accuracy: 0.9287 - val_loss: 0.4424 - val_accuracy: 0.8868
# Epoch 78/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3532 - accuracy: 0.9287 - val_loss: 0.4378 - val_accuracy: 0.8868
# Epoch 79/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3290 - accuracy: 0.9287 - val_loss: 0.4353 - val_accuracy: 0.8868
# Epoch 80/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3657 - accuracy: 0.9287 - val_loss: 0.4348 - val_accuracy: 0.8868
# Epoch 81/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3263 - accuracy: 0.9287 - val_loss: 0.5591 - val_accuracy: 0.8868
# Epoch 82/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3273 - accuracy: 0.9287 - val_loss: 0.5619 - val_accuracy: 0.8868
# Epoch 83/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3147 - accuracy: 0.9287 - val_loss: 0.4413 - val_accuracy: 0.8868
# Epoch 84/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3182 - accuracy: 0.9287 - val_loss: 0.4433 - val_accuracy: 0.8868
# Epoch 85/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6131 - accuracy: 0.9287 - val_loss: 0.4333 - val_accuracy: 0.8868
# Epoch 86/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3077 - accuracy: 0.9287 - val_loss: 0.4370 - val_accuracy: 0.8868
# Epoch 87/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3189 - accuracy: 0.9287 - val_loss: 0.4355 - val_accuracy: 0.8868
# Epoch 88/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3768 - accuracy: 0.9287 - val_loss: 0.4357 - val_accuracy: 0.8868
# Epoch 89/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3110 - accuracy: 0.9287 - val_loss: 0.4378 - val_accuracy: 0.8868
# Epoch 90/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3081 - accuracy: 0.9287 - val_loss: 0.4373 - val_accuracy: 0.8868
# Epoch 91/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3255 - accuracy: 0.9287 - val_loss: 0.5281 - val_accuracy: 0.8868
# Epoch 92/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3271 - accuracy: 0.9287 - val_loss: 0.4398 - val_accuracy: 0.8868
# Epoch 93/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3198 - accuracy: 0.9287 - val_loss: 0.4373 - val_accuracy: 0.8868
# Epoch 94/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.5238 - accuracy: 0.9287 - val_loss: 0.4391 - val_accuracy: 0.8868
# Epoch 95/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3107 - accuracy: 0.9287 - val_loss: 0.4377 - val_accuracy: 0.8868
# Epoch 96/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3228 - accuracy: 0.9287 - val_loss: 0.4402 - val_accuracy: 0.8868
# Epoch 97/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.3646 - accuracy: 0.9287 - val_loss: 0.4350 - val_accuracy: 0.8868
# Epoch 98/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3075 - accuracy: 0.9287 - val_loss: 0.4421 - val_accuracy: 0.8868
# Epoch 99/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3550 - accuracy: 0.9287 - val_loss: 0.4371 - val_accuracy: 0.8868
# Epoch 100/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3347 - accuracy: 0.9287 - val_loss: 0.5909 - val_accuracy: 0.8868

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2008-12-06       3884  3768  3768  ...              1     103        388104
# 2008-12-07       3884  3768  3768  ...              2     213        802584
# 2008-12-08       3883  3767  3767  ...              1     107        403069
# 2008-12-10       3883  3767  3767  ...              1     104        391768
# 2008-12-13       3883  3767  3767  ...              1     106        399302
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 1765

# %%
len(pictures)
# Out:
# 1765

# %%
# Divide the data into training and validation data
split_time = 1500
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_13 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 47/47 [==============================] - 2s 14ms/step - loss: 5.2423 - accuracy: 0.5233 - val_loss: 1.7069 - val_accuracy: 0.5585
# Epoch 2/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.9363 - accuracy: 0.5233 - val_loss: 0.7479 - val_accuracy: 0.5585
# Epoch 3/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.8347 - accuracy: 0.5233 - val_loss: 0.8341 - val_accuracy: 0.5585
# Epoch 4/100
# 47/47 [==============================] - 1s 17ms/step - loss: 0.7837 - accuracy: 0.5233 - val_loss: 0.6885 - val_accuracy: 0.5585
# Epoch 5/100
# 47/47 [==============================] - 1s 13ms/step - loss: 0.7430 - accuracy: 0.5233 - val_loss: 0.6886 - val_accuracy: 0.5585
# Epoch 6/100
# 47/47 [==============================] - 1s 17ms/step - loss: 0.7180 - accuracy: 0.5233 - val_loss: 0.6840 - val_accuracy: 0.5585
# Epoch 7/100
# 47/47 [==============================] - 1s 14ms/step - loss: 0.7183 - accuracy: 0.5233 - val_loss: 0.7212 - val_accuracy: 0.5585
# Epoch 8/100
# 47/47 [==============================] - 1s 16ms/step - loss: 0.7206 - accuracy: 0.5233 - val_loss: 0.7161 - val_accuracy: 0.5585
# Epoch 9/100
# 47/47 [==============================] - 1s 15ms/step - loss: 0.7101 - accuracy: 0.5233 - val_loss: 0.7017 - val_accuracy: 0.5585
# Epoch 10/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7083 - accuracy: 0.5233 - val_loss: 0.6990 - val_accuracy: 0.5585
# Epoch 11/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7030 - accuracy: 0.5233 - val_loss: 0.7196 - val_accuracy: 0.5585
# Epoch 12/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7076 - accuracy: 0.5233 - val_loss: 0.7052 - val_accuracy: 0.5585
# Epoch 13/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.7196 - accuracy: 0.5233 - val_loss: 0.6927 - val_accuracy: 0.5585
# Epoch 14/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6950 - accuracy: 0.5233 - val_loss: 0.6842 - val_accuracy: 0.5585
# Epoch 15/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6958 - accuracy: 0.5233 - val_loss: 0.6895 - val_accuracy: 0.5585
# Epoch 16/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7227 - accuracy: 0.5233 - val_loss: 0.6920 - val_accuracy: 0.5585
# Epoch 17/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6887 - accuracy: 0.5233 - val_loss: 0.6830 - val_accuracy: 0.5585
# Epoch 18/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6983 - accuracy: 0.5233 - val_loss: 0.6914 - val_accuracy: 0.5585
# Epoch 19/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6963 - accuracy: 0.5233 - val_loss: 0.6903 - val_accuracy: 0.5585
# Epoch 20/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6956 - accuracy: 0.5233 - val_loss: 0.6858 - val_accuracy: 0.5585
# Epoch 21/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7011 - accuracy: 0.5233 - val_loss: 0.6876 - val_accuracy: 0.5585
# Epoch 22/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6985 - accuracy: 0.5233 - val_loss: 0.6875 - val_accuracy: 0.5585
# Epoch 23/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6975 - accuracy: 0.5233 - val_loss: 0.7384 - val_accuracy: 0.5585
# Epoch 24/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7025 - accuracy: 0.5233 - val_loss: 0.6977 - val_accuracy: 0.5585
# Epoch 25/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6894 - accuracy: 0.5233 - val_loss: 0.6954 - val_accuracy: 0.5585
# Epoch 26/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 0.5233 - val_loss: 0.6876 - val_accuracy: 0.5585
# Epoch 27/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6970 - accuracy: 0.5233 - val_loss: 0.7075 - val_accuracy: 0.5585
# Epoch 28/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6924 - accuracy: 0.5233 - val_loss: 0.6836 - val_accuracy: 0.5585
# Epoch 29/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7043 - accuracy: 0.5233 - val_loss: 0.6867 - val_accuracy: 0.5585
# Epoch 30/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.7127 - accuracy: 0.5233 - val_loss: 0.6913 - val_accuracy: 0.5585
# Epoch 31/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6862 - accuracy: 0.5233 - val_loss: 0.7186 - val_accuracy: 0.5585
# Epoch 32/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6867 - accuracy: 0.5233 - val_loss: 0.7500 - val_accuracy: 0.5585
# Epoch 33/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7027 - accuracy: 0.5233 - val_loss: 0.7055 - val_accuracy: 0.5585
# Epoch 34/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.7037 - accuracy: 0.5233 - val_loss: 0.7429 - val_accuracy: 0.5585
# Epoch 35/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6886 - accuracy: 0.5233 - val_loss: 0.6943 - val_accuracy: 0.5585
# Epoch 36/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7272 - accuracy: 0.5233 - val_loss: 0.7089 - val_accuracy: 0.5585
# Epoch 37/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6992 - accuracy: 0.5233 - val_loss: 0.6983 - val_accuracy: 0.5585
# Epoch 38/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6853 - accuracy: 0.5233 - val_loss: 0.6800 - val_accuracy: 0.5585
# Epoch 39/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6928 - accuracy: 0.5233 - val_loss: 0.6930 - val_accuracy: 0.5585
# Epoch 40/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6883 - accuracy: 0.5233 - val_loss: 0.7184 - val_accuracy: 0.5585
# Epoch 41/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6961 - accuracy: 0.5233 - val_loss: 0.7459 - val_accuracy: 0.5585
# Epoch 42/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6920 - accuracy: 0.5233 - val_loss: 0.7181 - val_accuracy: 0.5585
# Epoch 43/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7080 - accuracy: 0.5233 - val_loss: 0.7162 - val_accuracy: 0.5585
# Epoch 44/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7469 - accuracy: 0.5233 - val_loss: 0.7325 - val_accuracy: 0.5585
# Epoch 45/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.6959 - accuracy: 0.5233 - val_loss: 0.6939 - val_accuracy: 0.5585
# Epoch 46/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6847 - accuracy: 0.5233 - val_loss: 0.7740 - val_accuracy: 0.5585
# Epoch 47/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6921 - accuracy: 0.5233 - val_loss: 0.7192 - val_accuracy: 0.5585
# Epoch 48/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7027 - accuracy: 0.5233 - val_loss: 0.7722 - val_accuracy: 0.5585
# Epoch 49/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.7000 - accuracy: 0.5233 - val_loss: 0.6915 - val_accuracy: 0.5585
# Epoch 50/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6945 - accuracy: 0.5233 - val_loss: 0.7009 - val_accuracy: 0.5585
# Epoch 51/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.6881 - accuracy: 0.5233 - val_loss: 0.7395 - val_accuracy: 0.5585
# Epoch 52/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7408 - accuracy: 0.5233 - val_loss: 0.7326 - val_accuracy: 0.5585
# Epoch 53/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6889 - accuracy: 0.5233 - val_loss: 0.7672 - val_accuracy: 0.5585
# Epoch 54/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7124 - accuracy: 0.5233 - val_loss: 0.7079 - val_accuracy: 0.5585
# Epoch 55/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.7041 - accuracy: 0.5233 - val_loss: 0.7047 - val_accuracy: 0.5585
# Epoch 56/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6934 - accuracy: 0.5233 - val_loss: 0.6984 - val_accuracy: 0.5585
# Epoch 57/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6998 - accuracy: 0.5233 - val_loss: 0.7651 - val_accuracy: 0.5585
# Epoch 58/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6933 - accuracy: 0.5233 - val_loss: 0.7138 - val_accuracy: 0.5585
# Epoch 59/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6789 - accuracy: 0.5233 - val_loss: 0.7092 - val_accuracy: 0.5585
# Epoch 60/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7643 - accuracy: 0.5233 - val_loss: 0.7418 - val_accuracy: 0.5585
# Epoch 61/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6887 - accuracy: 0.5233 - val_loss: 0.7437 - val_accuracy: 0.5585
# Epoch 62/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.7805 - accuracy: 0.5233 - val_loss: 0.7048 - val_accuracy: 0.5585
# Epoch 63/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.7170 - accuracy: 0.5233 - val_loss: 1.0500 - val_accuracy: 0.5585
# Epoch 64/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6997 - accuracy: 0.5233 - val_loss: 0.7151 - val_accuracy: 0.5585
# Epoch 65/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.6965 - accuracy: 0.5233 - val_loss: 0.7540 - val_accuracy: 0.5585
# Epoch 66/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7018 - accuracy: 0.5233 - val_loss: 0.8049 - val_accuracy: 0.5585
# Epoch 67/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6998 - accuracy: 0.5233 - val_loss: 0.7547 - val_accuracy: 0.5585
# Epoch 68/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7902 - accuracy: 0.5233 - val_loss: 0.8535 - val_accuracy: 0.5585
# Epoch 69/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6925 - accuracy: 0.5233 - val_loss: 0.8333 - val_accuracy: 0.5585
# Epoch 70/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6773 - accuracy: 0.5233 - val_loss: 0.7844 - val_accuracy: 0.5585
# Epoch 71/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7204 - accuracy: 0.5233 - val_loss: 0.8418 - val_accuracy: 0.5585
# Epoch 72/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6906 - accuracy: 0.5233 - val_loss: 0.7943 - val_accuracy: 0.5585
# Epoch 73/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6875 - accuracy: 0.5233 - val_loss: 1.0633 - val_accuracy: 0.5585
# Epoch 74/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6829 - accuracy: 0.5233 - val_loss: 0.9426 - val_accuracy: 0.5585
# Epoch 75/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7411 - accuracy: 0.5233 - val_loss: 0.7956 - val_accuracy: 0.5585
# Epoch 76/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7821 - accuracy: 0.5233 - val_loss: 0.7700 - val_accuracy: 0.5585
# Epoch 77/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6965 - accuracy: 0.5233 - val_loss: 0.8715 - val_accuracy: 0.5585
# Epoch 78/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7265 - accuracy: 0.5233 - val_loss: 0.7535 - val_accuracy: 0.5585
# Epoch 79/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6845 - accuracy: 0.5233 - val_loss: 0.7577 - val_accuracy: 0.5585
# Epoch 80/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6857 - accuracy: 0.5233 - val_loss: 0.8546 - val_accuracy: 0.5585
# Epoch 81/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7272 - accuracy: 0.5233 - val_loss: 0.9222 - val_accuracy: 0.5585
# Epoch 82/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6879 - accuracy: 0.5233 - val_loss: 0.7456 - val_accuracy: 0.5585
# Epoch 83/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6798 - accuracy: 0.5233 - val_loss: 0.7873 - val_accuracy: 0.5585
# Epoch 84/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6918 - accuracy: 0.5233 - val_loss: 0.7745 - val_accuracy: 0.5585
# Epoch 85/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.7388 - accuracy: 0.5233 - val_loss: 0.8267 - val_accuracy: 0.5585
# Epoch 86/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.6847 - accuracy: 0.5233 - val_loss: 0.7704 - val_accuracy: 0.5585
# Epoch 87/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6797 - accuracy: 0.5233 - val_loss: 0.8082 - val_accuracy: 0.5585
# Epoch 88/100
# 47/47 [==============================] - 1s 11ms/step - loss: 0.6837 - accuracy: 0.5233 - val_loss: 0.6966 - val_accuracy: 0.5585
# Epoch 89/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6953 - accuracy: 0.5233 - val_loss: 0.7704 - val_accuracy: 0.5585
# Epoch 90/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6879 - accuracy: 0.5233 - val_loss: 0.7741 - val_accuracy: 0.5585
# Epoch 91/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6892 - accuracy: 0.5233 - val_loss: 0.8728 - val_accuracy: 0.5585
# Epoch 92/100
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6767 - accuracy: 0.5233 - val_loss: 0.8501 - val_accuracy: 0.5585
# Epoch 93/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7094 - accuracy: 0.5233 - val_loss: 0.8965 - val_accuracy: 0.5585
# Epoch 94/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7027 - accuracy: 0.5233 - val_loss: 0.8299 - val_accuracy: 0.5585
# Epoch 95/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6772 - accuracy: 0.5233 - val_loss: 0.9397 - val_accuracy: 0.5585
# Epoch 96/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.7079 - accuracy: 0.5233 - val_loss: 0.7895 - val_accuracy: 0.5585
# Epoch 97/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6890 - accuracy: 0.5233 - val_loss: 0.8416 - val_accuracy: 0.5585
# Epoch 98/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6825 - accuracy: 0.5233 - val_loss: 0.8310 - val_accuracy: 0.5585
# Epoch 99/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6767 - accuracy: 0.5233 - val_loss: 0.8702 - val_accuracy: 0.5585
# Epoch 100/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.6818 - accuracy: 0.5233 - val_loss: 1.1211 - val_accuracy: 0.5585

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
