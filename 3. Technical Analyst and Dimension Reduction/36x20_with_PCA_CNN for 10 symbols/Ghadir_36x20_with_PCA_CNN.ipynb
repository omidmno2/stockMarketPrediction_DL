# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "وغدير"].head()
# Out:
#             Date Symbol  ...    Volume  Value Traded
# 4447  2009-02-01  وغدير  ...  20335924   34724345237
# 4569  2009-02-02  وغدير  ...   1835207    3042332902
# 4708  2009-02-03  وغدير  ...   2524795    4090167900
# 4840  2009-02-04  وغدير  ...   2527581    3973357332
# 4968  2009-02-07  وغدير  ...   4698245    7186955357
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "وغدير"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2560)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, 
                                    low=data.Low, 
                                    close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, 
                                                low=data.Low, 
                                                close=data.Last, 
                                                lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, 
                                               low=data.Low, 
                                               close=data.Last, 
                                               lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, 
                                                        low=data.Low, 
                                                        window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, 
                                                         low=data.Low, 
                                                         window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2541

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2548

# %%
len(data.Last)
# Out:
# 2560

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2535
# 2535

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
    x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    x = principalDf.transpose()

    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents)

    pictures[i] = principalDf

# %%
pictures[100]
# Out:
#               0           1           2  ...          7          8             9
# 0  21735.221113    0.099832    0.006496  ...  -0.000097  -0.000009  2.847431e-13
# 1  -2417.870893  755.455290    6.128450  ...  -0.079082  -0.007592  2.847431e-13
# 2  -2415.082063 -110.083904  296.227217  ...  -0.512585  -0.048571  2.847431e-13
# 3  -2414.739087  -96.472948  -61.342314  ...  -1.577311  -0.144853  2.847431e-13
# 4  -2414.631505  -92.870509  -44.493026  ...  -4.528181  -0.383105  2.847431e-13
# 5  -2414.595334  -91.718919  -40.731219  ... -12.206762  -0.857138  2.847431e-13
# 6  -2414.586228  -91.433472  -39.882262  ... -21.300703  -1.244978  2.847431e-13
# 7  -2414.583689  -91.354218  -39.651880  ... -26.883701  -1.424677  2.847431e-13
# 8  -2414.566975  -90.835793  -38.198994  ...  37.041277 -28.708716  2.847431e-13
# 9  -2414.565339  -90.785359  -38.062468  ...  30.047144  32.819639  2.847431e-13
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_25 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_27 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_6 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_12 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_6 (Flatten)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 128)               16512
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 13ms/step - loss: 1.6933 - accuracy: 0.8677 - val_loss: 0.3548 - val_accuracy: 0.9356
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5538 - accuracy: 0.9118 - val_loss: 0.3294 - val_accuracy: 0.9356
# Epoch 3/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4937 - accuracy: 0.9218 - val_loss: 0.3636 - val_accuracy: 0.9356
# Epoch 4/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4915 - accuracy: 0.9227 - val_loss: 0.3354 - val_accuracy: 0.9356
# Epoch 5/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4671 - accuracy: 0.9227 - val_loss: 0.3856 - val_accuracy: 0.9356
# Epoch 6/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4371 - accuracy: 0.9227 - val_loss: 0.3478 - val_accuracy: 0.9356
# Epoch 7/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3896 - accuracy: 0.9227 - val_loss: 0.3017 - val_accuracy: 0.9356
# Epoch 8/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3906 - accuracy: 0.9227 - val_loss: 0.3124 - val_accuracy: 0.9356
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3595 - accuracy: 0.9227 - val_loss: 0.2914 - val_accuracy: 0.9356
# Epoch 10/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3642 - accuracy: 0.9227 - val_loss: 0.2932 - val_accuracy: 0.9356
# Epoch 11/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3543 - accuracy: 0.9227 - val_loss: 0.2971 - val_accuracy: 0.9356
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3562 - accuracy: 0.9227 - val_loss: 0.3014 - val_accuracy: 0.9356
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3600 - accuracy: 0.9227 - val_loss: 0.2940 - val_accuracy: 0.9356
# Epoch 14/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3538 - accuracy: 0.9227 - val_loss: 0.2986 - val_accuracy: 0.9356
# Epoch 15/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3446 - accuracy: 0.9227 - val_loss: 0.2888 - val_accuracy: 0.9356
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3497 - accuracy: 0.9227 - val_loss: 0.2884 - val_accuracy: 0.9356
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3613 - accuracy: 0.9227 - val_loss: 0.2863 - val_accuracy: 0.9356
# Epoch 18/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3443 - accuracy: 0.9227 - val_loss: 0.2904 - val_accuracy: 0.9356
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3630 - accuracy: 0.9227 - val_loss: 0.2902 - val_accuracy: 0.9356
# Epoch 20/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3462 - accuracy: 0.9227 - val_loss: 0.2914 - val_accuracy: 0.9356
# Epoch 21/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3506 - accuracy: 0.9227 - val_loss: 0.3011 - val_accuracy: 0.9356
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3678 - accuracy: 0.9227 - val_loss: 0.2870 - val_accuracy: 0.9356
# Epoch 23/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3412 - accuracy: 0.9227 - val_loss: 0.2875 - val_accuracy: 0.9356
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3437 - accuracy: 0.9227 - val_loss: 0.2866 - val_accuracy: 0.9356
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3579 - accuracy: 0.9227 - val_loss: 0.2898 - val_accuracy: 0.9356
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3458 - accuracy: 0.9227 - val_loss: 0.2901 - val_accuracy: 0.9356
# Epoch 27/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3634 - accuracy: 0.9227 - val_loss: 0.2856 - val_accuracy: 0.9356
# Epoch 28/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3350 - accuracy: 0.9227 - val_loss: 0.3322 - val_accuracy: 0.9356
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3439 - accuracy: 0.9227 - val_loss: 0.5302 - val_accuracy: 0.9356
# Epoch 30/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3546 - accuracy: 0.9227 - val_loss: 0.2936 - val_accuracy: 0.9356
# Epoch 31/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.3453 - accuracy: 0.9227 - val_loss: 0.2855 - val_accuracy: 0.9356
# Epoch 32/100
# 69/69 [==============================] - 1s 13ms/step - loss: 0.3407 - accuracy: 0.9227 - val_loss: 0.2845 - val_accuracy: 0.9356
# Epoch 33/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.3526 - accuracy: 0.9227 - val_loss: 0.2838 - val_accuracy: 0.9356
# Epoch 34/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.3455 - accuracy: 0.9227 - val_loss: 0.2864 - val_accuracy: 0.9356
# Epoch 35/100
# 69/69 [==============================] - 1s 14ms/step - loss: 0.3376 - accuracy: 0.9227 - val_loss: 0.2852 - val_accuracy: 0.9356
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3574 - accuracy: 0.9227 - val_loss: 0.2874 - val_accuracy: 0.9356
# Epoch 37/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3342 - accuracy: 0.9227 - val_loss: 0.2892 - val_accuracy: 0.9356
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3646 - accuracy: 0.9227 - val_loss: 0.3762 - val_accuracy: 0.9356
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3500 - accuracy: 0.9227 - val_loss: 0.2848 - val_accuracy: 0.9356
# Epoch 40/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3511 - accuracy: 0.9227 - val_loss: 0.3035 - val_accuracy: 0.9356
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3516 - accuracy: 0.9227 - val_loss: 0.2889 - val_accuracy: 0.9356
# Epoch 42/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3399 - accuracy: 0.9227 - val_loss: 0.2895 - val_accuracy: 0.9356
# Epoch 43/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3462 - accuracy: 0.9227 - val_loss: 0.2839 - val_accuracy: 0.9356
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3434 - accuracy: 0.9227 - val_loss: 0.2929 - val_accuracy: 0.9356
# Epoch 45/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3621 - accuracy: 0.9227 - val_loss: 0.2863 - val_accuracy: 0.9356
# Epoch 46/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3488 - accuracy: 0.9227 - val_loss: 0.2860 - val_accuracy: 0.9356
# Epoch 47/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3433 - accuracy: 0.9227 - val_loss: 0.2931 - val_accuracy: 0.9356
# Epoch 48/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3626 - accuracy: 0.9227 - val_loss: 0.3051 - val_accuracy: 0.9356
# Epoch 49/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3452 - accuracy: 0.9227 - val_loss: 0.2982 - val_accuracy: 0.9356
# Epoch 50/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3619 - accuracy: 0.9227 - val_loss: 0.3220 - val_accuracy: 0.9356
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3389 - accuracy: 0.9227 - val_loss: 0.3058 - val_accuracy: 0.9356
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3320 - accuracy: 0.9227 - val_loss: 0.2969 - val_accuracy: 0.9356
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3312 - accuracy: 0.9227 - val_loss: 0.2830 - val_accuracy: 0.9356
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3939 - accuracy: 0.9227 - val_loss: 0.3871 - val_accuracy: 0.9356
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3471 - accuracy: 0.9227 - val_loss: 0.2853 - val_accuracy: 0.9356
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3350 - accuracy: 0.9227 - val_loss: 0.2844 - val_accuracy: 0.9356
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3668 - accuracy: 0.9227 - val_loss: 0.2870 - val_accuracy: 0.9356
# Epoch 58/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3338 - accuracy: 0.9227 - val_loss: 0.5051 - val_accuracy: 0.9356
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3678 - accuracy: 0.9223 - val_loss: 0.2841 - val_accuracy: 0.9356
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3409 - accuracy: 0.9227 - val_loss: 0.3582 - val_accuracy: 0.9356
# Epoch 61/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3521 - accuracy: 0.9227 - val_loss: 0.2945 - val_accuracy: 0.9356
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3691 - accuracy: 0.9227 - val_loss: 0.2866 - val_accuracy: 0.9356
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3362 - accuracy: 0.9227 - val_loss: 0.2868 - val_accuracy: 0.9356
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3688 - accuracy: 0.9223 - val_loss: 0.3662 - val_accuracy: 0.9356
# Epoch 65/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3404 - accuracy: 0.9227 - val_loss: 0.4163 - val_accuracy: 0.9356
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3393 - accuracy: 0.9227 - val_loss: 0.3001 - val_accuracy: 0.9356
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3676 - accuracy: 0.9227 - val_loss: 0.3366 - val_accuracy: 0.9356
# Epoch 68/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3464 - accuracy: 0.9227 - val_loss: 0.3059 - val_accuracy: 0.9356
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3374 - accuracy: 0.9227 - val_loss: 0.2969 - val_accuracy: 0.9356
# Epoch 70/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3452 - accuracy: 0.9223 - val_loss: 0.2859 - val_accuracy: 0.9356
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3306 - accuracy: 0.9227 - val_loss: 1.3908 - val_accuracy: 0.9356
# Epoch 72/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3720 - accuracy: 0.9232 - val_loss: 0.2944 - val_accuracy: 0.9356
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3546 - accuracy: 0.9227 - val_loss: 0.2862 - val_accuracy: 0.9356
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3350 - accuracy: 0.9227 - val_loss: 0.2845 - val_accuracy: 0.9356
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3538 - accuracy: 0.9227 - val_loss: 0.2891 - val_accuracy: 0.9356
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3405 - accuracy: 0.9227 - val_loss: 0.2852 - val_accuracy: 0.9356
# Epoch 77/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3527 - accuracy: 0.9223 - val_loss: 0.4626 - val_accuracy: 0.9356
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3331 - accuracy: 0.9227 - val_loss: 0.2888 - val_accuracy: 0.9356
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3696 - accuracy: 0.9227 - val_loss: 0.2994 - val_accuracy: 0.9356
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3458 - accuracy: 0.9227 - val_loss: 0.3038 - val_accuracy: 0.9356
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3414 - accuracy: 0.9223 - val_loss: 0.2846 - val_accuracy: 0.9356
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3339 - accuracy: 0.9227 - val_loss: 0.3102 - val_accuracy: 0.9356
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3330 - accuracy: 0.9227 - val_loss: 0.3140 - val_accuracy: 0.9356
# Epoch 84/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3319 - accuracy: 0.9227 - val_loss: 0.2843 - val_accuracy: 0.9356
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3286 - accuracy: 0.9227 - val_loss: 0.2900 - val_accuracy: 0.9356
# Epoch 86/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3898 - accuracy: 0.9227 - val_loss: 0.2879 - val_accuracy: 0.9356
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3338 - accuracy: 0.9227 - val_loss: 0.4606 - val_accuracy: 0.9356
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3609 - accuracy: 0.9227 - val_loss: 0.2857 - val_accuracy: 0.9356
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3262 - accuracy: 0.9227 - val_loss: 0.2932 - val_accuracy: 0.9356
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3351 - accuracy: 0.9227 - val_loss: 0.2858 - val_accuracy: 0.9356
# Epoch 91/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4399 - accuracy: 0.9227 - val_loss: 0.4341 - val_accuracy: 0.9356
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3771 - accuracy: 0.9227 - val_loss: 0.2847 - val_accuracy: 0.9356
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3282 - accuracy: 0.9227 - val_loss: 0.5233 - val_accuracy: 0.9356
# Epoch 94/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3539 - accuracy: 0.9227 - val_loss: 0.2859 - val_accuracy: 0.9356
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3608 - accuracy: 0.9227 - val_loss: 0.2896 - val_accuracy: 0.9356
# Epoch 96/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3328 - accuracy: 0.9227 - val_loss: 0.3930 - val_accuracy: 0.9356
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3340 - accuracy: 0.9227 - val_loss: 0.2847 - val_accuracy: 0.9356
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4281 - accuracy: 0.9227 - val_loss: 0.3096 - val_accuracy: 0.9356
# Epoch 99/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3476 - accuracy: 0.9223 - val_loss: 0.2847 - val_accuracy: 0.9356
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3290 - accuracy: 0.9227 - val_loss: 0.2852 - val_accuracy: 0.9356

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded    Volume  Value Traded
# Date                               ...
# 2009-02-01       1888  1640  1720  ...           1069  20335924   34724345237
# 2009-02-02       1708  1750  1657  ...             67   1835207    3042332902
# 2009-02-03       1670  1620  1620  ...            104   2524795    4090167900
# 2009-02-04       1620  1572  1572  ...             87   2527581    3973357332
# 2009-02-07       1572  1525  1610  ...            242   4698245    7186955357
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 2495

# %%
len(pictures)
# Out:
# 2495

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_29 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_30 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_31 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_14 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_7 (Flatten)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 13ms/step - loss: 3.2792 - accuracy: 0.5068 - val_loss: 0.7069 - val_accuracy: 0.6102
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.8015 - accuracy: 0.5068 - val_loss: 0.7114 - val_accuracy: 0.6102
# Epoch 3/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7527 - accuracy: 0.5068 - val_loss: 0.6739 - val_accuracy: 0.6102
# Epoch 4/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7238 - accuracy: 0.5068 - val_loss: 0.6719 - val_accuracy: 0.6102
# Epoch 5/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7120 - accuracy: 0.5068 - val_loss: 0.6782 - val_accuracy: 0.6102
# Epoch 6/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7138 - accuracy: 0.5068 - val_loss: 0.6742 - val_accuracy: 0.6102
# Epoch 7/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7121 - accuracy: 0.5068 - val_loss: 0.6918 - val_accuracy: 0.6102
# Epoch 8/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6988 - accuracy: 0.5068 - val_loss: 0.6942 - val_accuracy: 0.6102
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7108 - accuracy: 0.5068 - val_loss: 0.6928 - val_accuracy: 0.6102
# Epoch 10/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7010 - accuracy: 0.5068 - val_loss: 0.6946 - val_accuracy: 0.6102
# Epoch 11/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.7011 - accuracy: 0.5068 - val_loss: 0.6875 - val_accuracy: 0.6102
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6981 - accuracy: 0.5068 - val_loss: 0.6987 - val_accuracy: 0.6102
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6977 - accuracy: 0.5068 - val_loss: 0.6891 - val_accuracy: 0.6102
# Epoch 14/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6986 - accuracy: 0.5068 - val_loss: 0.6882 - val_accuracy: 0.6102
# Epoch 15/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6964 - accuracy: 0.5068 - val_loss: 0.6901 - val_accuracy: 0.6102
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.5068 - val_loss: 0.6896 - val_accuracy: 0.6102
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7000 - accuracy: 0.5068 - val_loss: 0.6818 - val_accuracy: 0.6102
# Epoch 18/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6975 - accuracy: 0.5068 - val_loss: 0.6852 - val_accuracy: 0.6102
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7013 - accuracy: 0.5068 - val_loss: 0.6918 - val_accuracy: 0.6102
# Epoch 20/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6989 - accuracy: 0.5068 - val_loss: 0.6888 - val_accuracy: 0.6102
# Epoch 21/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6953 - accuracy: 0.5068 - val_loss: 0.6908 - val_accuracy: 0.6102
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6962 - accuracy: 0.5068 - val_loss: 0.6877 - val_accuracy: 0.6102
# Epoch 23/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6964 - accuracy: 0.5068 - val_loss: 0.6932 - val_accuracy: 0.6102
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7004 - accuracy: 0.5068 - val_loss: 0.6929 - val_accuracy: 0.6102
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6973 - accuracy: 0.5068 - val_loss: 0.7172 - val_accuracy: 0.6102
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6949 - accuracy: 0.5068 - val_loss: 0.6922 - val_accuracy: 0.6102
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6985 - accuracy: 0.5068 - val_loss: 0.6912 - val_accuracy: 0.6102
# Epoch 28/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6953 - accuracy: 0.5068 - val_loss: 0.6903 - val_accuracy: 0.6102
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6963 - accuracy: 0.5068 - val_loss: 0.6930 - val_accuracy: 0.6102
# Epoch 30/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6991 - accuracy: 0.5068 - val_loss: 0.6946 - val_accuracy: 0.6102
# Epoch 31/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6958 - accuracy: 0.5068 - val_loss: 0.6889 - val_accuracy: 0.6102
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6979 - accuracy: 0.5068 - val_loss: 0.6918 - val_accuracy: 0.6102
# Epoch 33/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6955 - accuracy: 0.5068 - val_loss: 0.6770 - val_accuracy: 0.6102
# Epoch 34/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6969 - accuracy: 0.5068 - val_loss: 0.6915 - val_accuracy: 0.6102
# Epoch 35/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6943 - accuracy: 0.5068 - val_loss: 0.6937 - val_accuracy: 0.6102
# Epoch 36/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6963 - accuracy: 0.5068 - val_loss: 0.6926 - val_accuracy: 0.6102
# Epoch 37/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6945 - accuracy: 0.5068 - val_loss: 0.6868 - val_accuracy: 0.6102
# Epoch 38/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6969 - accuracy: 0.5068 - val_loss: 0.6922 - val_accuracy: 0.6102
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6938 - accuracy: 0.5068 - val_loss: 0.6903 - val_accuracy: 0.6102
# Epoch 40/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6945 - accuracy: 0.5068 - val_loss: 0.6922 - val_accuracy: 0.6102
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.5068 - val_loss: 0.6941 - val_accuracy: 0.6102
# Epoch 42/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6982 - accuracy: 0.5068 - val_loss: 0.6898 - val_accuracy: 0.6102
# Epoch 43/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6949 - accuracy: 0.5068 - val_loss: 0.6945 - val_accuracy: 0.6102
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6981 - accuracy: 0.5068 - val_loss: 0.6940 - val_accuracy: 0.6102
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6929 - accuracy: 0.5068 - val_loss: 0.6924 - val_accuracy: 0.6102
# Epoch 46/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6957 - accuracy: 0.5068 - val_loss: 0.6911 - val_accuracy: 0.6102
# Epoch 47/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6961 - accuracy: 0.5068 - val_loss: 0.6962 - val_accuracy: 0.6102
# Epoch 48/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6918 - accuracy: 0.5068 - val_loss: 0.6878 - val_accuracy: 0.6102
# Epoch 49/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6989 - accuracy: 0.5068 - val_loss: 0.6902 - val_accuracy: 0.6102
# Epoch 50/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6954 - accuracy: 0.5068 - val_loss: 0.6912 - val_accuracy: 0.6102
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6942 - accuracy: 0.5068 - val_loss: 0.6916 - val_accuracy: 0.6102
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6933 - accuracy: 0.5068 - val_loss: 0.6851 - val_accuracy: 0.6102
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6951 - accuracy: 0.5068 - val_loss: 0.6916 - val_accuracy: 0.6102
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6983 - accuracy: 0.5068 - val_loss: 0.6885 - val_accuracy: 0.6102
# Epoch 55/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6953 - accuracy: 0.5068 - val_loss: 0.6912 - val_accuracy: 0.6102
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6919 - accuracy: 0.5068 - val_loss: 0.6872 - val_accuracy: 0.6102
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6917 - accuracy: 0.5068 - val_loss: 0.6808 - val_accuracy: 0.6102
# Epoch 58/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.5068 - val_loss: 0.6942 - val_accuracy: 0.6102
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6932 - accuracy: 0.5068 - val_loss: 0.6919 - val_accuracy: 0.6102
# Epoch 60/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6925 - accuracy: 0.5068 - val_loss: 0.6866 - val_accuracy: 0.6102
# Epoch 61/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6926 - accuracy: 0.5068 - val_loss: 0.6860 - val_accuracy: 0.6102
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.5068 - val_loss: 0.7000 - val_accuracy: 0.6102
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6912 - accuracy: 0.5068 - val_loss: 0.6903 - val_accuracy: 0.6102
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6946 - accuracy: 0.5068 - val_loss: 0.6911 - val_accuracy: 0.6102
# Epoch 65/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6894 - accuracy: 0.5068 - val_loss: 0.6830 - val_accuracy: 0.6102
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6899 - accuracy: 0.5068 - val_loss: 0.6934 - val_accuracy: 0.6102
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6926 - accuracy: 0.5068 - val_loss: 0.6962 - val_accuracy: 0.6102
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6919 - accuracy: 0.5068 - val_loss: 0.6876 - val_accuracy: 0.6102
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.5068 - val_loss: 0.7080 - val_accuracy: 0.6102
# Epoch 70/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.5068 - val_loss: 0.7111 - val_accuracy: 0.6102
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6878 - accuracy: 0.5068 - val_loss: 0.6991 - val_accuracy: 0.6102
# Epoch 72/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6896 - accuracy: 0.5068 - val_loss: 0.7030 - val_accuracy: 0.6102
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6933 - accuracy: 0.5068 - val_loss: 0.6845 - val_accuracy: 0.6102
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6956 - accuracy: 0.5068 - val_loss: 0.6904 - val_accuracy: 0.6102
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6930 - accuracy: 0.5068 - val_loss: 0.6982 - val_accuracy: 0.6102
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6880 - accuracy: 0.5068 - val_loss: 0.6829 - val_accuracy: 0.6102
# Epoch 77/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6922 - accuracy: 0.5068 - val_loss: 0.6878 - val_accuracy: 0.6102
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6917 - accuracy: 0.5068 - val_loss: 0.7013 - val_accuracy: 0.6102
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6911 - accuracy: 0.5068 - val_loss: 0.6875 - val_accuracy: 0.6102
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.5068 - val_loss: 0.6953 - val_accuracy: 0.6102
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6939 - accuracy: 0.5068 - val_loss: 0.6972 - val_accuracy: 0.6102
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6871 - accuracy: 0.5068 - val_loss: 0.6965 - val_accuracy: 0.6102
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6892 - accuracy: 0.5068 - val_loss: 0.6876 - val_accuracy: 0.6102
# Epoch 84/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6885 - accuracy: 0.5068 - val_loss: 0.6871 - val_accuracy: 0.6102
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6852 - accuracy: 0.5068 - val_loss: 0.6893 - val_accuracy: 0.6102
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6892 - accuracy: 0.5068 - val_loss: 0.7354 - val_accuracy: 0.6102
# Epoch 87/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6894 - accuracy: 0.5068 - val_loss: 0.6976 - val_accuracy: 0.6102
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6865 - accuracy: 0.5068 - val_loss: 0.6903 - val_accuracy: 0.6102
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6887 - accuracy: 0.5068 - val_loss: 0.6863 - val_accuracy: 0.6102
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6855 - accuracy: 0.5068 - val_loss: 0.6941 - val_accuracy: 0.6102
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6878 - accuracy: 0.5068 - val_loss: 0.6858 - val_accuracy: 0.6102
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6890 - accuracy: 0.5068 - val_loss: 0.6964 - val_accuracy: 0.6102
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6849 - accuracy: 0.5068 - val_loss: 0.6845 - val_accuracy: 0.6102
# Epoch 94/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6930 - accuracy: 0.5068 - val_loss: 0.7619 - val_accuracy: 0.6102
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6880 - accuracy: 0.5068 - val_loss: 0.6949 - val_accuracy: 0.6102
# Epoch 96/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6870 - accuracy: 0.5068 - val_loss: 0.6940 - val_accuracy: 0.6102
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6850 - accuracy: 0.5068 - val_loss: 0.6883 - val_accuracy: 0.6102
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.5068 - val_loss: 0.7076 - val_accuracy: 0.6102
# Epoch 99/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6949 - accuracy: 0.5068 - val_loss: 0.7432 - val_accuracy: 0.6102
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.5068 - val_loss: 0.7081 - val_accuracy: 0.6102

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
