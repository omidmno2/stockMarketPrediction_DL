# %% [markdown]
# <a href="https://colab.research.google.com/github/omidmno2/stockMarketPrediction_DL/blob/main/Vatoosaa_36x20_with_PCA_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "وتوصا"].head()
# Out:
#            Date Symbol  ...  Volume  Value Traded
# 18   2008-12-06  وتوصا  ...   28297      21222750
# 116  2008-12-07  وتوصا  ...   13832      10374000
# 366  2008-12-10  وتوصا  ...  315545     228454580
# 413  2008-12-13  وتوصا  ...    7274       5186362
# 493  2008-12-14  وتوصا  ...  635286     476425695
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "وتوصا"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2560)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, low=data.Low, close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2541

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2548

# %%
len(data.Last)
# Out:
# 2560

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2535
# 2535

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
  x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

  pca = PCA(n_components=10)
  principalComponents = pca.fit_transform(x)
  principalDf = pd.DataFrame(data = principalComponents)

  x = principalDf.transpose()

  pca = PCA(n_components=10)
  principalComponents = pca.fit_transform(x)
  principalDf = pd.DataFrame(data = principalComponents)

  pictures[i] = principalDf

# %%
pictures[100]
# Out:
#              0           1           2  ...          7          8             9
# 0  9192.263764    0.433485    0.028281  ...  -0.000382  -0.000088  9.721945e-14
# 1 -1027.053158  693.974810    5.671163  ...  -0.066014  -0.015111  9.721945e-14
# 2 -1021.479288 -101.268460  274.660467  ...  -0.419739  -0.094800  9.721945e-14
# 3 -1020.835451  -89.367264  -60.871701  ...  -1.112511  -0.244866  9.721945e-14
# 4 -1020.563475  -85.136886  -40.139198  ...  -3.681872  -0.740445  9.721945e-14
# 5 -1020.541981  -84.819481  -39.086790  ...  -4.504226  -0.881475  9.721945e-14
# 6 -1020.470928  -83.786799  -35.969057  ... -17.217217  -2.380257  9.721945e-14
# 7 -1020.460098  -83.631581  -35.536951  ... -30.219311  -3.213076  9.721945e-14
# 8 -1020.433529  -83.253223  -34.519621  ...  35.443132 -22.682136  9.721945e-14
# 9 -1020.425857  -83.144600  -34.236594  ...  21.778140  30.252254  9.721945e-14
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_17 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 15ms/step - loss: 1.1127 - accuracy: 0.9100 - val_loss: 1.8036 - val_accuracy: 0.9051
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4078 - accuracy: 0.9423 - val_loss: 0.6733 - val_accuracy: 0.9051
# Epoch 3/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3735 - accuracy: 0.9436 - val_loss: 0.8918 - val_accuracy: 0.9051
# Epoch 4/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3583 - accuracy: 0.9441 - val_loss: 0.9801 - val_accuracy: 0.9051
# Epoch 5/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3385 - accuracy: 0.9441 - val_loss: 0.9888 - val_accuracy: 0.9051
# Epoch 6/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3410 - accuracy: 0.9441 - val_loss: 0.7490 - val_accuracy: 0.9051
# Epoch 7/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3305 - accuracy: 0.9441 - val_loss: 0.8061 - val_accuracy: 0.9051
# Epoch 8/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3240 - accuracy: 0.9441 - val_loss: 1.0283 - val_accuracy: 0.9051
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3052 - accuracy: 0.9441 - val_loss: 0.6910 - val_accuracy: 0.9051
# Epoch 10/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2986 - accuracy: 0.9441 - val_loss: 0.8668 - val_accuracy: 0.9051
# Epoch 11/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3119 - accuracy: 0.9441 - val_loss: 1.0587 - val_accuracy: 0.9051
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3173 - accuracy: 0.9441 - val_loss: 0.8383 - val_accuracy: 0.9051
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2902 - accuracy: 0.9441 - val_loss: 0.6042 - val_accuracy: 0.9051
# Epoch 14/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3171 - accuracy: 0.9441 - val_loss: 0.8109 - val_accuracy: 0.9051
# Epoch 15/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2910 - accuracy: 0.9441 - val_loss: 0.7644 - val_accuracy: 0.9051
# Epoch 16/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2771 - accuracy: 0.9441 - val_loss: 1.1863 - val_accuracy: 0.9051
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2819 - accuracy: 0.9441 - val_loss: 0.6407 - val_accuracy: 0.9051
# Epoch 18/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2868 - accuracy: 0.9441 - val_loss: 0.6787 - val_accuracy: 0.9051
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2755 - accuracy: 0.9441 - val_loss: 0.7674 - val_accuracy: 0.9051
# Epoch 20/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2733 - accuracy: 0.9441 - val_loss: 0.7788 - val_accuracy: 0.9051
# Epoch 21/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2769 - accuracy: 0.9441 - val_loss: 0.4346 - val_accuracy: 0.9051
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2962 - accuracy: 0.9441 - val_loss: 0.7012 - val_accuracy: 0.9051
# Epoch 23/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3150 - accuracy: 0.9441 - val_loss: 0.4688 - val_accuracy: 0.9051
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3090 - accuracy: 0.9441 - val_loss: 0.9682 - val_accuracy: 0.9051
# Epoch 25/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2925 - accuracy: 0.9441 - val_loss: 8.3766 - val_accuracy: 0.9051
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2961 - accuracy: 0.9441 - val_loss: 3.7070 - val_accuracy: 0.9051
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2841 - accuracy: 0.9441 - val_loss: 0.4467 - val_accuracy: 0.9051
# Epoch 28/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3041 - accuracy: 0.9441 - val_loss: 2.7972 - val_accuracy: 0.9051
# Epoch 29/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2701 - accuracy: 0.9441 - val_loss: 0.5668 - val_accuracy: 0.9051
# Epoch 30/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2784 - accuracy: 0.9441 - val_loss: 0.4740 - val_accuracy: 0.9051
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3889 - accuracy: 0.9441 - val_loss: 2.7322 - val_accuracy: 0.9051
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2688 - accuracy: 0.9441 - val_loss: 2.7428 - val_accuracy: 0.9051
# Epoch 33/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2812 - accuracy: 0.9441 - val_loss: 0.5136 - val_accuracy: 0.9051
# Epoch 34/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2734 - accuracy: 0.9441 - val_loss: 0.5829 - val_accuracy: 0.9051
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2991 - accuracy: 0.9441 - val_loss: 0.3948 - val_accuracy: 0.9051
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3161 - accuracy: 0.9441 - val_loss: 1.8232 - val_accuracy: 0.9051
# Epoch 37/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2698 - accuracy: 0.9441 - val_loss: 1.0447 - val_accuracy: 0.9051
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3164 - accuracy: 0.9441 - val_loss: 0.4149 - val_accuracy: 0.9051
# Epoch 39/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2768 - accuracy: 0.9441 - val_loss: 0.3970 - val_accuracy: 0.9051
# Epoch 40/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2976 - accuracy: 0.9441 - val_loss: 0.6107 - val_accuracy: 0.9051
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2726 - accuracy: 0.9441 - val_loss: 0.4582 - val_accuracy: 0.9051
# Epoch 42/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3577 - accuracy: 0.9441 - val_loss: 1.3571 - val_accuracy: 0.9051
# Epoch 43/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2857 - accuracy: 0.9441 - val_loss: 0.4983 - val_accuracy: 0.9051
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2755 - accuracy: 0.9441 - val_loss: 0.7717 - val_accuracy: 0.9051
# Epoch 45/100
# 69/69 [==============================] - 1s 11ms/step - loss: 0.3202 - accuracy: 0.9441 - val_loss: 0.8507 - val_accuracy: 0.9051
# Epoch 46/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.2613 - accuracy: 0.9441 - val_loss: 0.4636 - val_accuracy: 0.9051
# Epoch 47/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.3076 - accuracy: 0.9441 - val_loss: 0.5834 - val_accuracy: 0.9051
# Epoch 48/100
# 69/69 [==============================] - 1s 12ms/step - loss: 0.2747 - accuracy: 0.9441 - val_loss: 1.2192 - val_accuracy: 0.9051
# Epoch 49/100
# 69/69 [==============================] - 1s 15ms/step - loss: 0.2813 - accuracy: 0.9441 - val_loss: 1.4864 - val_accuracy: 0.9051
# Epoch 50/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3391 - accuracy: 0.9441 - val_loss: 2.2329 - val_accuracy: 0.9051
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2547 - accuracy: 0.9441 - val_loss: 4.8259 - val_accuracy: 0.9051
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3489 - accuracy: 0.9441 - val_loss: 1.5680 - val_accuracy: 0.9051
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2692 - accuracy: 0.9441 - val_loss: 1.9531 - val_accuracy: 0.9051
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2913 - accuracy: 0.9441 - val_loss: 0.4071 - val_accuracy: 0.9051
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2844 - accuracy: 0.9441 - val_loss: 0.3895 - val_accuracy: 0.9051
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3137 - accuracy: 0.9441 - val_loss: 2.0991 - val_accuracy: 0.9051
# Epoch 57/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2837 - accuracy: 0.9441 - val_loss: 6.1137 - val_accuracy: 0.9051
# Epoch 58/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2758 - accuracy: 0.9441 - val_loss: 0.7121 - val_accuracy: 0.9051
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2594 - accuracy: 0.9441 - val_loss: 3.8204 - val_accuracy: 0.9051
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3452 - accuracy: 0.9441 - val_loss: 2.9092 - val_accuracy: 0.9051
# Epoch 61/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2891 - accuracy: 0.9441 - val_loss: 0.6880 - val_accuracy: 0.9051
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5348 - accuracy: 0.9441 - val_loss: 8.9494 - val_accuracy: 0.9051
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2613 - accuracy: 0.9441 - val_loss: 2.4591 - val_accuracy: 0.9051
# Epoch 64/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3158 - accuracy: 0.9441 - val_loss: 1.8346 - val_accuracy: 0.9051
# Epoch 65/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2675 - accuracy: 0.9441 - val_loss: 0.6907 - val_accuracy: 0.9051
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3807 - accuracy: 0.9441 - val_loss: 1.0425 - val_accuracy: 0.9051
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2942 - accuracy: 0.9441 - val_loss: 0.3921 - val_accuracy: 0.9051
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2958 - accuracy: 0.9441 - val_loss: 11.7301 - val_accuracy: 0.9051
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2945 - accuracy: 0.9441 - val_loss: 0.6843 - val_accuracy: 0.9051
# Epoch 70/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.4034 - accuracy: 0.9441 - val_loss: 4.4483 - val_accuracy: 0.9051
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2663 - accuracy: 0.9441 - val_loss: 1.2652 - val_accuracy: 0.9051
# Epoch 72/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2570 - accuracy: 0.9441 - val_loss: 0.7000 - val_accuracy: 0.9051
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3469 - accuracy: 0.9441 - val_loss: 1.8650 - val_accuracy: 0.9051
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3209 - accuracy: 0.9441 - val_loss: 14.5005 - val_accuracy: 0.9051
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2671 - accuracy: 0.9441 - val_loss: 0.6091 - val_accuracy: 0.9051
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2686 - accuracy: 0.9441 - val_loss: 2.5709 - val_accuracy: 0.9051
# Epoch 77/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2788 - accuracy: 0.9441 - val_loss: 1.4244 - val_accuracy: 0.9051
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2806 - accuracy: 0.9441 - val_loss: 3.1833 - val_accuracy: 0.9051
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3219 - accuracy: 0.9441 - val_loss: 0.7506 - val_accuracy: 0.9051
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2837 - accuracy: 0.9441 - val_loss: 3.7921 - val_accuracy: 0.9051
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.8477 - accuracy: 0.9441 - val_loss: 44.3215 - val_accuracy: 0.9051
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4007 - accuracy: 0.9441 - val_loss: 18.0402 - val_accuracy: 0.9051
# Epoch 83/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2781 - accuracy: 0.9441 - val_loss: 7.3023 - val_accuracy: 0.9051
# Epoch 84/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2697 - accuracy: 0.9441 - val_loss: 0.4203 - val_accuracy: 0.9051
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3397 - accuracy: 0.9441 - val_loss: 0.6918 - val_accuracy: 0.9051
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2843 - accuracy: 0.9441 - val_loss: 0.6108 - val_accuracy: 0.9051
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2649 - accuracy: 0.9441 - val_loss: 1.0447 - val_accuracy: 0.9051
# Epoch 88/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3124 - accuracy: 0.9441 - val_loss: 0.4729 - val_accuracy: 0.9051
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.4183 - accuracy: 0.9441 - val_loss: 0.7322 - val_accuracy: 0.9051
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3462 - accuracy: 0.9441 - val_loss: 3.8221 - val_accuracy: 0.9051
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5350 - accuracy: 0.9441 - val_loss: 3.3985 - val_accuracy: 0.9051
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2727 - accuracy: 0.9441 - val_loss: 0.8625 - val_accuracy: 0.9051
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3190 - accuracy: 0.9441 - val_loss: 1.1655 - val_accuracy: 0.9051
# Epoch 94/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2658 - accuracy: 0.9441 - val_loss: 0.3970 - val_accuracy: 0.9051
# Epoch 95/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2573 - accuracy: 0.9441 - val_loss: 0.9714 - val_accuracy: 0.9051
# Epoch 96/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.3518 - accuracy: 0.9441 - val_loss: 0.8654 - val_accuracy: 0.9051
# Epoch 97/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.2709 - accuracy: 0.9441 - val_loss: 3.4749 - val_accuracy: 0.9051
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3111 - accuracy: 0.9441 - val_loss: 1.9258 - val_accuracy: 0.9051
# Epoch 99/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.3395 - accuracy: 0.9441 - val_loss: 2.7784 - val_accuracy: 0.9051
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.2570 - accuracy: 0.9436 - val_loss: 0.4224 - val_accuracy: 0.9051

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2008-12-06        746   750   750  ...              8   28297      21222750
# 2008-12-07        746   750   750  ...              3   13832      10374000
# 2008-12-10        746   724   724  ...             69  315545     228454580
# 2008-12-13        735   713   713  ...              3    7274       5186362
# 2008-12-14        735   750   750  ...            109  635286     476425695
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 2495

# %%
len(pictures)
# Out:
# 2495

# %%
# Divide the data into training and validation data
split_time = 2200
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_21 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_22 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_23 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_10 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_5 (Flatten)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 69/69 [==============================] - 2s 12ms/step - loss: 1.4975 - accuracy: 0.5377 - val_loss: 0.7233 - val_accuracy: 0.5356
# Epoch 2/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7262 - accuracy: 0.5377 - val_loss: 0.8469 - val_accuracy: 0.5356
# Epoch 3/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7118 - accuracy: 0.5377 - val_loss: 0.7152 - val_accuracy: 0.5356
# Epoch 4/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6983 - accuracy: 0.5377 - val_loss: 0.6916 - val_accuracy: 0.5356
# Epoch 5/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7035 - accuracy: 0.5377 - val_loss: 0.6879 - val_accuracy: 0.5356
# Epoch 6/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6959 - accuracy: 0.5377 - val_loss: 0.7092 - val_accuracy: 0.5356
# Epoch 7/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6939 - accuracy: 0.5377 - val_loss: 0.6999 - val_accuracy: 0.5356
# Epoch 8/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6974 - accuracy: 0.5377 - val_loss: 0.7093 - val_accuracy: 0.5356
# Epoch 9/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6921 - accuracy: 0.5377 - val_loss: 0.7211 - val_accuracy: 0.5356
# Epoch 10/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.5377 - val_loss: 0.7300 - val_accuracy: 0.5356
# Epoch 11/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6912 - accuracy: 0.5377 - val_loss: 0.7954 - val_accuracy: 0.5356
# Epoch 12/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6949 - accuracy: 0.5377 - val_loss: 0.8608 - val_accuracy: 0.5356
# Epoch 13/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6929 - accuracy: 0.5377 - val_loss: 0.6922 - val_accuracy: 0.5356
# Epoch 14/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.5377 - val_loss: 0.7143 - val_accuracy: 0.5356
# Epoch 15/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6895 - accuracy: 0.5377 - val_loss: 0.6924 - val_accuracy: 0.5356
# Epoch 16/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6911 - accuracy: 0.5377 - val_loss: 0.7257 - val_accuracy: 0.5356
# Epoch 17/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6911 - accuracy: 0.5377 - val_loss: 0.8407 - val_accuracy: 0.5356
# Epoch 18/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6955 - accuracy: 0.5377 - val_loss: 0.6910 - val_accuracy: 0.5356
# Epoch 19/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6900 - accuracy: 0.5377 - val_loss: 0.6938 - val_accuracy: 0.5356
# Epoch 20/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6900 - accuracy: 0.5377 - val_loss: 0.6950 - val_accuracy: 0.5356
# Epoch 21/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6917 - accuracy: 0.5377 - val_loss: 0.6975 - val_accuracy: 0.5356
# Epoch 22/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6896 - accuracy: 0.5377 - val_loss: 0.7056 - val_accuracy: 0.5356
# Epoch 23/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6884 - accuracy: 0.5377 - val_loss: 0.7386 - val_accuracy: 0.5356
# Epoch 24/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6868 - accuracy: 0.5377 - val_loss: 0.7163 - val_accuracy: 0.5356
# Epoch 25/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6893 - accuracy: 0.5377 - val_loss: 0.7389 - val_accuracy: 0.5356
# Epoch 26/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6931 - accuracy: 0.5377 - val_loss: 0.7701 - val_accuracy: 0.5356
# Epoch 27/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6986 - accuracy: 0.5377 - val_loss: 0.6974 - val_accuracy: 0.5356
# Epoch 28/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6889 - accuracy: 0.5377 - val_loss: 0.7309 - val_accuracy: 0.5356
# Epoch 29/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6886 - accuracy: 0.5377 - val_loss: 0.7134 - val_accuracy: 0.5356
# Epoch 30/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6898 - accuracy: 0.5377 - val_loss: 0.6949 - val_accuracy: 0.5356
# Epoch 31/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6904 - accuracy: 0.5377 - val_loss: 0.7136 - val_accuracy: 0.5356
# Epoch 32/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6942 - accuracy: 0.5377 - val_loss: 0.7660 - val_accuracy: 0.5356
# Epoch 33/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6867 - accuracy: 0.5377 - val_loss: 0.7811 - val_accuracy: 0.5356
# Epoch 34/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6872 - accuracy: 0.5377 - val_loss: 0.8323 - val_accuracy: 0.5356
# Epoch 35/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6903 - accuracy: 0.5377 - val_loss: 0.7564 - val_accuracy: 0.5356
# Epoch 36/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6895 - accuracy: 0.5377 - val_loss: 0.7044 - val_accuracy: 0.5356
# Epoch 37/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7150 - accuracy: 0.5377 - val_loss: 0.7160 - val_accuracy: 0.5356
# Epoch 38/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6864 - accuracy: 0.5377 - val_loss: 0.7487 - val_accuracy: 0.5356
# Epoch 39/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6898 - accuracy: 0.5377 - val_loss: 0.7123 - val_accuracy: 0.5356
# Epoch 40/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6928 - accuracy: 0.5377 - val_loss: 0.7941 - val_accuracy: 0.5356
# Epoch 41/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6860 - accuracy: 0.5377 - val_loss: 0.7123 - val_accuracy: 0.5356
# Epoch 42/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6902 - accuracy: 0.5377 - val_loss: 0.6989 - val_accuracy: 0.5356
# Epoch 43/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6853 - accuracy: 0.5377 - val_loss: 0.7210 - val_accuracy: 0.5356
# Epoch 44/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6841 - accuracy: 0.5377 - val_loss: 0.7436 - val_accuracy: 0.5356
# Epoch 45/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6874 - accuracy: 0.5377 - val_loss: 0.7184 - val_accuracy: 0.5356
# Epoch 46/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6824 - accuracy: 0.5377 - val_loss: 0.7174 - val_accuracy: 0.5356
# Epoch 47/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6822 - accuracy: 0.5377 - val_loss: 0.8676 - val_accuracy: 0.5356
# Epoch 48/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6845 - accuracy: 0.5377 - val_loss: 0.7369 - val_accuracy: 0.5356
# Epoch 49/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6812 - accuracy: 0.5377 - val_loss: 0.7685 - val_accuracy: 0.5356
# Epoch 50/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6880 - accuracy: 0.5377 - val_loss: 0.7678 - val_accuracy: 0.5356
# Epoch 51/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6841 - accuracy: 0.5377 - val_loss: 0.7481 - val_accuracy: 0.5356
# Epoch 52/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6816 - accuracy: 0.5377 - val_loss: 0.7275 - val_accuracy: 0.5356
# Epoch 53/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6895 - accuracy: 0.5377 - val_loss: 0.7312 - val_accuracy: 0.5356
# Epoch 54/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6801 - accuracy: 0.5377 - val_loss: 0.7174 - val_accuracy: 0.5356
# Epoch 55/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6813 - accuracy: 0.5377 - val_loss: 0.7360 - val_accuracy: 0.5356
# Epoch 56/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6823 - accuracy: 0.5377 - val_loss: 0.7859 - val_accuracy: 0.5356
# Epoch 57/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6815 - accuracy: 0.5377 - val_loss: 1.0080 - val_accuracy: 0.5356
# Epoch 58/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6874 - accuracy: 0.5377 - val_loss: 0.7471 - val_accuracy: 0.5356
# Epoch 59/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6786 - accuracy: 0.5377 - val_loss: 0.7691 - val_accuracy: 0.5356
# Epoch 60/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6939 - accuracy: 0.5377 - val_loss: 0.7673 - val_accuracy: 0.5356
# Epoch 61/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6827 - accuracy: 0.5377 - val_loss: 0.7343 - val_accuracy: 0.5356
# Epoch 62/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6912 - accuracy: 0.5377 - val_loss: 0.8329 - val_accuracy: 0.5356
# Epoch 63/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6765 - accuracy: 0.5377 - val_loss: 0.8919 - val_accuracy: 0.5356
# Epoch 64/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6863 - accuracy: 0.5377 - val_loss: 0.7034 - val_accuracy: 0.5356
# Epoch 65/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6857 - accuracy: 0.5377 - val_loss: 0.8495 - val_accuracy: 0.5356
# Epoch 66/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6912 - accuracy: 0.5377 - val_loss: 0.7141 - val_accuracy: 0.5356
# Epoch 67/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7101 - accuracy: 0.5377 - val_loss: 0.7060 - val_accuracy: 0.5356
# Epoch 68/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6841 - accuracy: 0.5377 - val_loss: 0.7736 - val_accuracy: 0.5356
# Epoch 69/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6958 - accuracy: 0.5377 - val_loss: 0.8563 - val_accuracy: 0.5356
# Epoch 70/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6815 - accuracy: 0.5377 - val_loss: 0.7184 - val_accuracy: 0.5356
# Epoch 71/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7048 - accuracy: 0.5377 - val_loss: 0.7106 - val_accuracy: 0.5356
# Epoch 72/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6869 - accuracy: 0.5377 - val_loss: 0.6923 - val_accuracy: 0.5356
# Epoch 73/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6875 - accuracy: 0.5377 - val_loss: 0.6956 - val_accuracy: 0.5356
# Epoch 74/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6870 - accuracy: 0.5377 - val_loss: 0.7127 - val_accuracy: 0.5356
# Epoch 75/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6906 - accuracy: 0.5377 - val_loss: 0.7048 - val_accuracy: 0.5356
# Epoch 76/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7327 - accuracy: 0.5377 - val_loss: 0.7115 - val_accuracy: 0.5356
# Epoch 77/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6831 - accuracy: 0.5377 - val_loss: 0.8393 - val_accuracy: 0.5356
# Epoch 78/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6912 - accuracy: 0.5377 - val_loss: 0.7884 - val_accuracy: 0.5356
# Epoch 79/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6903 - accuracy: 0.5377 - val_loss: 0.7267 - val_accuracy: 0.5356
# Epoch 80/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6831 - accuracy: 0.5377 - val_loss: 0.7204 - val_accuracy: 0.5356
# Epoch 81/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6885 - accuracy: 0.5377 - val_loss: 0.7084 - val_accuracy: 0.5356
# Epoch 82/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6884 - accuracy: 0.5377 - val_loss: 0.8519 - val_accuracy: 0.5356
# Epoch 83/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6874 - accuracy: 0.5377 - val_loss: 0.6946 - val_accuracy: 0.5356
# Epoch 84/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6845 - accuracy: 0.5377 - val_loss: 0.7406 - val_accuracy: 0.5356
# Epoch 85/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7076 - accuracy: 0.5377 - val_loss: 0.7977 - val_accuracy: 0.5356
# Epoch 86/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6904 - accuracy: 0.5377 - val_loss: 0.7146 - val_accuracy: 0.5356
# Epoch 87/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.5377 - val_loss: 0.9174 - val_accuracy: 0.5356
# Epoch 88/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7267 - accuracy: 0.5377 - val_loss: 0.7293 - val_accuracy: 0.5356
# Epoch 89/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7700 - accuracy: 0.5377 - val_loss: 0.7940 - val_accuracy: 0.5356
# Epoch 90/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6798 - accuracy: 0.5377 - val_loss: 1.1069 - val_accuracy: 0.5356
# Epoch 91/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7327 - accuracy: 0.5377 - val_loss: 0.8801 - val_accuracy: 0.5356
# Epoch 92/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6984 - accuracy: 0.5377 - val_loss: 0.7385 - val_accuracy: 0.5356
# Epoch 93/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6894 - accuracy: 0.5377 - val_loss: 0.7079 - val_accuracy: 0.5356
# Epoch 94/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7594 - accuracy: 0.5377 - val_loss: 0.7534 - val_accuracy: 0.5356
# Epoch 95/100
# 69/69 [==============================] - 1s 9ms/step - loss: 0.6879 - accuracy: 0.5377 - val_loss: 0.7511 - val_accuracy: 0.5356
# Epoch 96/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.7053 - accuracy: 0.5377 - val_loss: 0.7079 - val_accuracy: 0.5356
# Epoch 97/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6909 - accuracy: 0.5377 - val_loss: 0.7422 - val_accuracy: 0.5356
# Epoch 98/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.5377 - val_loss: 0.7392 - val_accuracy: 0.5356
# Epoch 99/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6947 - accuracy: 0.5377 - val_loss: 0.7459 - val_accuracy: 0.5356
# Epoch 100/100
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6853 - accuracy: 0.5377 - val_loss: 0.7187 - val_accuracy: 0.5356

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
