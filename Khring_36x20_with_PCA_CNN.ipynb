# %% [markdown]
# <a href="https://colab.research.google.com/github/omidmno2/stockMarketPrediction_DL/blob/main/Khring_36x20_with_PCA_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Getting Data from GitHub
# !wget --no-check-certificate \
    https://github.com/omidmno2/stockMarketPrediction_DL/raw/main/tse_en.csv \
    -o /tmp/tse_en.csv

# %%
# Import required libraries
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# Select the desired symbol
df = pd.read_csv("tse_en.csv")
df[df.Symbol == "خرينگ"].head()
# Out:
#             Date Symbol            Name  ...  Number Traded  Volume  Value Traded
# 106   2008-12-07  خرينگ  رينگ‌سازي‌مشهد  ...              1    1161        981045
# 4433  2009-02-01  خرينگ  رينگ‌سازي‌مشهد  ...              7   31464      26587080
# 5184  2009-02-09  خرينگ  رينگ‌سازي‌مشهد  ...              2    2000       1672000
# 5634  2009-02-17  خرينگ  رينگ‌سازي‌مشهد  ...              1     100         83500
# 7046  2009-03-08  خرينگ  رينگ‌سازي‌مشهد  ...              1      25         20875
#
# [5 rows x 13 columns]

# %%
# Data cleaning
data = df[df.Symbol == "خرينگ"]
data.index = pd.to_datetime(data['Date'])
data = data.drop(columns=['Symbol', 'Name', 'Date']).dropna()
data = data.head(2300)

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Data plotting
series = np.array(data["Last"])
time = np.array(data.index)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Installing required libraries for Technical Analysis
# !pip install ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.7/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)

# %%
import ta
#https://technical-analysis-library-in-python.readthedocs.io/en/latest/ta.html#volatility-indicators
#data = ta.add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")

import pandas_ta
#https://github.com/twopirllc/pandas-ta

#import talib
#https://github.com/mrjbq7/ta-lib
#https://ta-lib.org/function.html

# %%
# I1 = xo(t), Open Price
open_price = []
for i in range(len(data)-19):
    open_price.append(data.Open[i:i+20])
    
# I2 = xh(t), High Price
high_price = []
for i in range(len(data)-19):
    high_price.append(data.High[i:i+20])
    
# I3 = xl(t), Low Price
low_price = []
for i in range(len(data)-19):
    low_price.append(data.Low[i:i+20])
    
# I4 = x(t), Close Price
close_price = []
for i in range(len(data)-19):
    close_price.append(data.Last[i:i+20])
    
# I5 = MA5, Moving Average 5
ma5 = []
indicator_ma5 = ta.trend.SMAIndicator(close=data.Last, window=5)
indicator_ma5 = indicator_ma5.sma_indicator()
for i in range(len(data)-19):
    ma5.append(indicator_ma5[i:i+20])

#  I6 = MA10, Moving Average 10
ma10 = []
indicator_ma10 = ta.trend.SMAIndicator(close=data.Last, window=10)
indicator_ma10 = indicator_ma10.sma_indicator()
for i in range(len(data)-19):
    ma10.append(indicator_ma10[i:i+20])
    
# I7 = MA20,  Moving Average 20
ma20 = []
indicator_ma20 = ta.trend.SMAIndicator(close=data.Last, window=20)
indicator_ma20 = indicator_ma20.sma_indicator()
for i in range(len(data)-19):
    ma20.append(indicator_ma20[i:i+20])
    
# I8 = BIAS5, BIAS5
bias5 = []
indicator_bias5 = pandas_ta.bias(close=data.Last, length=5)
for i in range(len(data)-19):
    bias5.append(indicator_bias5[i:i+20])
    
# I9 = BIAS10, BIAS10
bias10 = []
indicator_bias10 = pandas_ta.bias(close=data.Last, length=10)
for i in range(len(data)-19):
    bias10.append(indicator_bias10[i:i+20])
    
# I10 DIFF EMA12-EMA26
diff = []
indicator_ema12 = ta.trend.EMAIndicator(close=data.Last, window=12)
indicator_ema12 = indicator_ema12.ema_indicator()
indicator_ema26 = ta.trend.EMAIndicator(close=data.Last, window=26)
indicator_ema26 = indicator_ema26.ema_indicator()
indicator_diff = indicator_ema12 - indicator_ema26
for i in range(len(data)-19):
    diff.append(indicator_diff[i:i+20])
    
# I11 = BU, (x(t)-bollinger upper)/bollinger upper
bu = []
indicator_bbu = pandas_ta.bbands(close=data.Last)['BBU_5_2.0']
indicator_bu = (data.Last - indicator_bbu) / indicator_bbu
for i in range(len(data)-19):
    bu.append(indicator_bu[i:i+20])
    
# I12 = BL, (x(t)-bollinger lower)/bollinger lower
bl = []
indicator_bbl = pandas_ta.bbands(close=data.Last)['BBL_5_2.0']
indicator_bl = (data.Last - indicator_bbl) / indicator_bbl
for i in range(len(data)-19):
    bl.append(indicator_bl[i:i+20])

# I13 = K, Stochastic Fast %K
k = []
indicator_k = ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    k.append(indicator_k[i:i+20])
    
# I14 = D, Stochastic Fast %D
d = []
indicator_d = ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    d.append(indicator_d[i:i+20])

# I15 = ROC, Price rate of change
roc = []
indicator_roc = ta.momentum.ROCIndicator(close=data.Last)
indicator_roc = indicator_roc.roc()
for i in range(len(data)-19):
    roc.append(indicator_roc[i:i+20])
    
# I16 = TR, True range of price movements
tr = []
indicator_tr = pandas_ta.true_range(high=data.High, low=data.Low, close=data.Last)
for i in range(len(data)-19):
    tr.append(indicator_tr[i:i+20])

# I17 = MTM6, Momentum 6
mtm6 = []
indicator_mtm6 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm6.append(indicator_mtm6[i:i+20])

# I18 = MTM12, Momentum 12
mtm12 = []
indicator_mtm12 = pandas_ta.mom(close=data.Last)
for i in range(len(data)-19):
    mtm12.append(indicator_mtm12[i:i+20])
    
# I19 = WR%10, Williams index %10
wr10 = []
indicator_wr10 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=10)
indicator_wr10 = indicator_wr10.williams_r()
for i in range(len(data)-19):
    wr10.append(indicator_wr10[i:i+20])
    
# I20 = WR%5, Williams index %5
wr5 = []
indicator_wr5 = ta.momentum.WilliamsRIndicator(high=data.High, low=data.Low, close=data.Last, lbp=5)
indicator_wr5 = indicator_wr5.williams_r()
for i in range(len(data)-19):
    wr5.append(indicator_wr5[i:i+20])

# I21 = OSC6, Oscillator 6
osc6 = []
indicator_osc6 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=6)
indicator_osc6 = indicator_osc6.awesome_oscillator()
for i in range(len(data)-19):
    osc6.append(indicator_osc6[i:i+20])
    
# I22 = OSC12, Oscillator12
osc12 = []
indicator_osc12 = ta.momentum.AwesomeOscillatorIndicator(high=data.High, low=data.Low, window1=12)
indicator_osc12 = indicator_osc12.awesome_oscillator()
for i in range(len(data)-19):
    osc12.append(indicator_osc12[i:i+20])
    
# I23 = RSI6, Relative strength index 6
rsi6 = []
indicator_rsi6 = ta.momentum.RSIIndicator(close=data.Last, window=6)
indicator_rsi6 = indicator_rsi6.rsi()
for i in range(len(data)-19):
    rsi6.append(indicator_rsi6[i:i+20]) 
    
# I24 = RSI12, Relative strength index 12
rsi12 = []
indicator_rsi12 = ta.momentum.RSIIndicator(close=data.Last, window=12)
indicator_rsi12 = indicator_rsi12.rsi()
for i in range(len(data)-19):
    rsi12.append(indicator_rsi12[i:i+20]) 

# I25 = PSY, Psychological line
psy = []
indicator_psy = pandas_ta.psl(close=data.Last, open=data.Open)
for i in range(len(data)-19):
    psy.append(indicator_psy[i:i+20]) 
    
# I26, K(t)-K(t-1)
i26 = []
indicator_i26 = ta.momentum.stochrsi_k(close=data.Last.shift(-1)) - ta.momentum.stochrsi_k(close=data.Last)
for i in range(len(data)-19):
    i26.append(indicator_i26[i:i+20])
    
# I27, D(t)-D(t-1)
i27 = []
indicator_i27 = ta.momentum.stochrsi_d(close=data.Last.shift(-1)) - ta.momentum.stochrsi_d(close=data.Last)
for i in range(len(data)-19):
    i27.append(indicator_i27[i:i+20])

# I28, (x(t)-x(t-1))/x(t-1)
i28 = []
indicator_i28 = (data.Last.shift(-1) - data.Last) / data.Last
for i in range(len(data)-19):
    i28.append(indicator_i28[i:i+20])
    
# I29, (x(t)-xo(t))/xo(t)
i29 = []
indicator_i29 = (data.Last - data.Open) / data.Open
for i in range(len(data)-19):
    i29.append(indicator_i29[i:i+20])
    
# I30, (x(t)-xl(t))/(xh(t)- xl(t))
i30 = []
indicator_i30 = (data.Last - data.Low) / (data.High - data.Low)
for i in range(len(data)-19):
    i30.append(indicator_i30[i:i+20])
    
# I31, (MA5(t)-MA5(t-1))/MA5(t-1)
i31 = []
ma5_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=5).sma_indicator()
ma5_t_1 = ta.trend.SMAIndicator(close=data.Last, window=5).sma_indicator()
indicator_i31 = (ma5_t - ma5_t_1) / ma5_t_1
for i in range(len(data)-19):
    i31.append(indicator_i31[i:i+20])
    
# I32, (MA20(t)-MA20(t-1))/MA20(t-1)
i32 = []
ma20_t = ta.trend.SMAIndicator(close=data.Last.shift(-1), window=20).sma_indicator()
ma20_t_1 = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i32 = (ma20_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i32.append(indicator_i32[i:i+20])
    
# I33, (MA5(t)-MA20(t-1))/MA20(t-1)
i33 = []
indicator_i33 = (ma5_t - ma20_t_1) / ma20_t_1
for i in range(len(data)-19):
    i33.append(indicator_i33[i:i+20])
    
# I34, (x(t)-MA20(t))/MA20(t)
i34 = []
ma20t = ta.trend.SMAIndicator(close=data.Last, window=20).sma_indicator()
indicator_i34 = (data.Last - ma20t) / ma20t
for i in range(len(data)-19):
    i34.append(indicator_i34[i:i+20])
    
# I35, (x(t)-min(x(t-1),x(t-2),...,x(t-N)))/ min(x(t),x(t-1),x(t-2),...,x(t-N))
i35 = []
max_list = []
min_list = []
for i in range(1, len(data)):
    max_list.append(data.Last.shift(-i).max())
    min_list.append(data.Last.shift(-i).min())
mini = np.array(min_list).min()
maxi = np.array(max_list).max()
indicator_i35 = (data.Last - mini) / mini
for i in range(len(data)-19):
    i35.append(indicator_i35[i:i+20])
    
# I36, (x(t)-max(x(t-1),x(t-2),...,x(t-N)))/ max(x(t),x(t-1),x(t-2),...,x(t-N))
i36 = []
indicator_i36 = (data.Last - maxi) / maxi
for i in range(len(data)-19):
    i36.append(indicator_i36[i:i+20])

# %%
pictures = list()
for i in range(0, len(open_price)):
    pic = pd.DataFrame(index=['day1', 'day2', 'day3', 'day4', 'day5',
                              'day6', 'day7', 'day8', 'day9', 'day10',
                              'day11', 'day12', 'day13', 'day14', 'day15',
                              'day16', 'day17', 'day18', 'day19', 'day20'])
    pic["Open Price"] = np.array(open_price[i:i+1]).transpose()
    pic["High Price"] = np.array(high_price[i:i+1]).transpose()
    pic["Low Price"] = np.array(low_price[i:i+1]).transpose()
    pic["Close Price"] = np.array(close_price[i:i+1]).transpose()
    pic["MA5"] = np.array(ma5[i:i+1]).transpose()
    pic["MA10"] = np.array(ma10[i:i+1]).transpose()
    pic["MA20"] = np.array(ma20[i:i+1]).transpose()
    pic["BIAS5"] = np.array(bias5[i:i+1]).transpose()
    pic["BIAS10"] = np.array(bias10[i:i+1]).transpose()
    pic["DIFF"] = np.array(diff[i:i+1]).transpose()
    pic["BU"] = np.array(bu[i:i+1]).transpose()
    pic["BL"] = np.array(bl[i:i+1]).transpose()
    pic["K"] = np.array(k[i:i+1]).transpose()
    pic["D"] = np.array(d[i:i+1]).transpose()
    pic["ROC"] = np.array(roc[i:i+1]).transpose()
    pic["TR"] = np.array(tr[i:i+1]).transpose()
    pic["MTM6"] = np.array(mtm6[i:i+1]).transpose()
    pic["MTM12"] = np.array(mtm12[i:i+1]).transpose()
    pic["WR%10"] = np.array(wr10[i:i+1]).transpose()
    pic["WR%5"] = np.array(wr5[i:i+1]).transpose()
    pic["OSC6"] = np.array(osc6[i:i+1]).transpose()
    pic["OSC12"] = np.array(osc12[i:i+1]).transpose()
    pic["RSI6"] = np.array(rsi6[i:i+1]).transpose()
    pic["RSI12"] = np.array(rsi12[i:i+1]).transpose()
    pic["PSY"] = np.array(psy[i:i+1]).transpose()
    pic["I26"] = np.array(i26[i:i+1]).transpose()
    pic["I27"] = np.array(i27[i:i+1]).transpose()
    pic["I28"] = np.array(i28[i:i+1]).transpose()
    pic["I29"] = np.array(i29[i:i+1]).transpose()
    pic["I30"] = np.array(i30[i:i+1]).transpose()
    pic["I31"] = np.array(i31[i:i+1]).transpose()
    pic["I32"] = np.array(i32[i:i+1]).transpose()
    pic["I33"] = np.array(i33[i:i+1]).transpose()
    pic["I34"] = np.array(i34[i:i+1]).transpose()
    pic["I35"] = np.array(i35[i:i+1]).transpose()
    pic["I36"] = np.array(i36[i:i+1]).transpose()
    pictures.append(pic.transpose())

# %%
len(pictures)
# Out:
# 2281

# %%
# Algorithm 1
# Labeling (Buy, Sell, Hold)

window_size = 11
counter = 0
bsh_labels = []

window_begin_idx=0
window_end_idx=0
window_middle_idx=0

min_idx=0
max_idx=0
number=0.0
mins=10000.0
maxs=0.0
while counter < len(data.Last):
    if counter > window_size:
        window_begin_idx = counter - window_size
        window_end_idx = window_begin_idx + window_size - 1
        window_middle_idx = (window_begin_idx + window_end_idx)//2
        for i in range(window_begin_idx, window_end_idx+1):
            number = data.Last[i]
            if number < mins:
                mins=number
                min_idx = np.where(data.Last==mins)[0][0]
            if number > maxs:
                maxs=number
                max_idx = np.where(data.Last==maxs)[0][0]
        if max_idx == window_middle_idx:
            bsh_labels.append(0) #SELL
        elif min_idx == window_middle_idx:
            bsh_labels.append(1) #BUY
        else:
            bsh_labels.append(2) #HOLD  
        mins = 10000.0
        maxs = 0.0
    counter+=1

# %%
len(bsh_labels)
# Out:
# 2288

# %%
len(data.Last)
# Out:
# 2300

# %%
len(data.Last) - len(bsh_labels)
# You should remove 6 rows from head and 6 rows from tail of data or actualy pictures.
# After checking, it was found that this difference is due to the fact that 6 lines from the top and 6 lines from the bottom have been removed.
# شش تای اول و شش تای آخر حذف میشوند موقع درست کردن لیبل
# Out:
# 12

# %%
bsh_labels = bsh_labels[13:]
pictures = pictures[:-6]
print(len(bsh_labels))
print(len(pictures))
# Out:
# 2275
# 2275

# %%
pictures = pictures[40:]
bsh_labels = bsh_labels[40:]

# %%
# This part of code belongs to Dimension Reduction with PCA. Also there is another way to reduse dimensions which name is (2D)square_PCA, but I couldn't find how to use it.

from sklearn.decomposition import PCA

# %%
for i in range(len(pictures)):
  x = pictures[i].replace([np.inf, -np.inf], np.nan).fillna(0)

  pca = PCA(n_components=10)
  principalComponents = pca.fit_transform(x)
  principalDf = pd.DataFrame(data = principalComponents)

  x = principalDf.transpose()

  pca = PCA(n_components=10)
  principalComponents = pca.fit_transform(x)
  principalDf = pd.DataFrame(data = principalComponents)

  pictures[i] = principalDf

# %%
pictures[100]
# Out:
#              0           1           2  ...          7          8             9
# 0  8850.720432    0.007172    0.009317  ...  -0.000003  -0.000012  1.984968e-13
# 1  -983.851074  195.825551   51.952061  ...  -0.006439  -0.022291  1.984968e-13
# 2  -983.719936  -86.054008  156.878860  ...  -0.008356  -0.028891  1.984968e-13
# 3  -983.406228  -19.359670  -40.920918  ...  -0.029066  -0.099170  1.984968e-13
# 4  -983.319886  -15.954944  -30.375679  ...  -0.091517  -0.300305  1.984968e-13
# 5  -983.305359  -15.496360  -29.113250  ...  -0.143339  -0.455894  1.984968e-13
# 6  -983.282094  -14.814409  -27.296353  ...  -1.539739  -2.678214  1.984968e-13
# 7  -983.279948  -14.754530  -27.140155  ... -15.154296  -4.865388  1.984968e-13
# 8  -983.279474  -14.741349  -27.105841  ...  15.849254  -5.938246  1.984968e-13
# 9  -983.276433  -14.657454  -26.888042  ...   1.123501  14.388410  1.984968e-13
#
# [10 rows x 10 columns]

# %%
# Divide the data into training and validation data
split_time = 2000
y_train = bsh_labels[:split_time]
x_train = pictures[:split_time]
y_valid = bsh_labels[split_time:]
x_valid = pictures[split_time:]

# %%
y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 3)
y_valid = tf.keras.utils.to_categorical(y_valid, 3)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_49 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_50 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_51 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_12 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_12 (Flatten)        (None, 128)               0
#
#  dense_24 (Dense)            (None, 128)               16512
#
#  dropout_25 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 257,155
# Trainable params: 257,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 63/63 [==============================] - 2s 13ms/step - loss: 1.5108 - accuracy: 0.9005 - val_loss: 1.2545 - val_accuracy: 0.9106
# Epoch 2/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.4938 - accuracy: 0.9310 - val_loss: 0.9905 - val_accuracy: 0.9106
# Epoch 3/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.4515 - accuracy: 0.9325 - val_loss: 1.5259 - val_accuracy: 0.9106
# Epoch 4/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4587 - accuracy: 0.9330 - val_loss: 0.7064 - val_accuracy: 0.9106
# Epoch 5/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4032 - accuracy: 0.9330 - val_loss: 0.4169 - val_accuracy: 0.9106
# Epoch 6/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3971 - accuracy: 0.9330 - val_loss: 1.1497 - val_accuracy: 0.9106
# Epoch 7/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3764 - accuracy: 0.9330 - val_loss: 0.6973 - val_accuracy: 0.9106
# Epoch 8/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3529 - accuracy: 0.9330 - val_loss: 0.4067 - val_accuracy: 0.9106
# Epoch 9/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3186 - accuracy: 0.9330 - val_loss: 0.3905 - val_accuracy: 0.9106
# Epoch 10/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3352 - accuracy: 0.9330 - val_loss: 0.3880 - val_accuracy: 0.9106
# Epoch 11/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3146 - accuracy: 0.9330 - val_loss: 0.4143 - val_accuracy: 0.9106
# Epoch 12/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3212 - accuracy: 0.9330 - val_loss: 0.3907 - val_accuracy: 0.9106
# Epoch 13/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3274 - accuracy: 0.9330 - val_loss: 0.3889 - val_accuracy: 0.9106
# Epoch 14/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3018 - accuracy: 0.9330 - val_loss: 0.4578 - val_accuracy: 0.9106
# Epoch 15/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3143 - accuracy: 0.9330 - val_loss: 0.4151 - val_accuracy: 0.9106
# Epoch 16/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3007 - accuracy: 0.9330 - val_loss: 0.4598 - val_accuracy: 0.9106
# Epoch 17/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3173 - accuracy: 0.9330 - val_loss: 0.6371 - val_accuracy: 0.9106
# Epoch 18/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3117 - accuracy: 0.9330 - val_loss: 0.3935 - val_accuracy: 0.9106
# Epoch 19/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3107 - accuracy: 0.9330 - val_loss: 0.3964 - val_accuracy: 0.9106
# Epoch 20/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3350 - accuracy: 0.9330 - val_loss: 0.4456 - val_accuracy: 0.9106
# Epoch 21/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2979 - accuracy: 0.9330 - val_loss: 0.7982 - val_accuracy: 0.9106
# Epoch 22/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3053 - accuracy: 0.9330 - val_loss: 0.4981 - val_accuracy: 0.9106
# Epoch 23/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3151 - accuracy: 0.9330 - val_loss: 0.6828 - val_accuracy: 0.9106
# Epoch 24/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3056 - accuracy: 0.9330 - val_loss: 0.4100 - val_accuracy: 0.9106
# Epoch 25/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3051 - accuracy: 0.9330 - val_loss: 0.4857 - val_accuracy: 0.9106
# Epoch 26/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3153 - accuracy: 0.9330 - val_loss: 0.4981 - val_accuracy: 0.9106
# Epoch 27/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3058 - accuracy: 0.9330 - val_loss: 0.8583 - val_accuracy: 0.9106
# Epoch 28/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3080 - accuracy: 0.9330 - val_loss: 0.3732 - val_accuracy: 0.9106
# Epoch 29/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3018 - accuracy: 0.9330 - val_loss: 0.4314 - val_accuracy: 0.9106
# Epoch 30/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3139 - accuracy: 0.9330 - val_loss: 0.3726 - val_accuracy: 0.9106
# Epoch 31/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3040 - accuracy: 0.9330 - val_loss: 0.3757 - val_accuracy: 0.9106
# Epoch 32/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2975 - accuracy: 0.9330 - val_loss: 0.6908 - val_accuracy: 0.9106
# Epoch 33/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2972 - accuracy: 0.9330 - val_loss: 0.5883 - val_accuracy: 0.9106
# Epoch 34/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2933 - accuracy: 0.9330 - val_loss: 0.6509 - val_accuracy: 0.9106
# Epoch 35/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3054 - accuracy: 0.9330 - val_loss: 1.5258 - val_accuracy: 0.9106
# Epoch 36/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3129 - accuracy: 0.9330 - val_loss: 0.4051 - val_accuracy: 0.9106
# Epoch 37/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2934 - accuracy: 0.9330 - val_loss: 0.4592 - val_accuracy: 0.9106
# Epoch 38/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3075 - accuracy: 0.9330 - val_loss: 0.4392 - val_accuracy: 0.9106
# Epoch 39/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2952 - accuracy: 0.9330 - val_loss: 1.0705 - val_accuracy: 0.9106
# Epoch 40/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3196 - accuracy: 0.9330 - val_loss: 1.0122 - val_accuracy: 0.9106
# Epoch 41/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2953 - accuracy: 0.9330 - val_loss: 0.3675 - val_accuracy: 0.9106
# Epoch 42/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3011 - accuracy: 0.9330 - val_loss: 0.7095 - val_accuracy: 0.9106
# Epoch 43/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3240 - accuracy: 0.9330 - val_loss: 0.4201 - val_accuracy: 0.9106
# Epoch 44/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2973 - accuracy: 0.9330 - val_loss: 0.5560 - val_accuracy: 0.9106
# Epoch 45/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3164 - accuracy: 0.9330 - val_loss: 0.4132 - val_accuracy: 0.9106
# Epoch 46/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3046 - accuracy: 0.9330 - val_loss: 0.6185 - val_accuracy: 0.9106
# Epoch 47/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3545 - accuracy: 0.9325 - val_loss: 0.4084 - val_accuracy: 0.9106
# Epoch 48/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2988 - accuracy: 0.9330 - val_loss: 0.5996 - val_accuracy: 0.9106
# Epoch 49/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3074 - accuracy: 0.9330 - val_loss: 1.3553 - val_accuracy: 0.9106
# Epoch 50/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3033 - accuracy: 0.9330 - val_loss: 1.0773 - val_accuracy: 0.9106
# Epoch 51/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2951 - accuracy: 0.9330 - val_loss: 0.4712 - val_accuracy: 0.9106
# Epoch 52/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3028 - accuracy: 0.9330 - val_loss: 0.4888 - val_accuracy: 0.9106
# Epoch 53/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3126 - accuracy: 0.9330 - val_loss: 1.0148 - val_accuracy: 0.9106
# Epoch 54/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3219 - accuracy: 0.9330 - val_loss: 0.6217 - val_accuracy: 0.9106
# Epoch 55/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2972 - accuracy: 0.9330 - val_loss: 0.3907 - val_accuracy: 0.9106
# Epoch 56/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2975 - accuracy: 0.9330 - val_loss: 0.4117 - val_accuracy: 0.9106
# Epoch 57/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3091 - accuracy: 0.9330 - val_loss: 0.7700 - val_accuracy: 0.9106
# Epoch 58/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3065 - accuracy: 0.9325 - val_loss: 0.8783 - val_accuracy: 0.9106
# Epoch 59/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3093 - accuracy: 0.9330 - val_loss: 0.4039 - val_accuracy: 0.9106
# Epoch 60/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3211 - accuracy: 0.9330 - val_loss: 0.6189 - val_accuracy: 0.9106
# Epoch 61/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3109 - accuracy: 0.9330 - val_loss: 0.6461 - val_accuracy: 0.9106
# Epoch 62/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2903 - accuracy: 0.9330 - val_loss: 0.6550 - val_accuracy: 0.9106
# Epoch 63/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3024 - accuracy: 0.9325 - val_loss: 1.1344 - val_accuracy: 0.9106
# Epoch 64/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3878 - accuracy: 0.9330 - val_loss: 0.4723 - val_accuracy: 0.9106
# Epoch 65/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3063 - accuracy: 0.9330 - val_loss: 0.7002 - val_accuracy: 0.9106
# Epoch 66/100
# 63/63 [==============================] - 1s 16ms/step - loss: 0.2945 - accuracy: 0.9330 - val_loss: 0.4164 - val_accuracy: 0.9106
# Epoch 67/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3027 - accuracy: 0.9330 - val_loss: 0.6472 - val_accuracy: 0.9106
# Epoch 68/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3145 - accuracy: 0.9330 - val_loss: 1.0980 - val_accuracy: 0.9106
# Epoch 69/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3150 - accuracy: 0.9330 - val_loss: 0.4670 - val_accuracy: 0.9106
# Epoch 70/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2893 - accuracy: 0.9335 - val_loss: 0.6220 - val_accuracy: 0.9106
# Epoch 71/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3095 - accuracy: 0.9330 - val_loss: 0.5361 - val_accuracy: 0.9106
# Epoch 72/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2940 - accuracy: 0.9330 - val_loss: 1.6537 - val_accuracy: 0.9106
# Epoch 73/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3491 - accuracy: 0.9330 - val_loss: 0.6288 - val_accuracy: 0.9106
# Epoch 74/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2993 - accuracy: 0.9330 - val_loss: 0.5188 - val_accuracy: 0.9106
# Epoch 75/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2962 - accuracy: 0.9325 - val_loss: 2.9908 - val_accuracy: 0.9106
# Epoch 76/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2950 - accuracy: 0.9330 - val_loss: 0.5336 - val_accuracy: 0.9106
# Epoch 77/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3240 - accuracy: 0.9330 - val_loss: 1.3693 - val_accuracy: 0.9106
# Epoch 78/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2976 - accuracy: 0.9330 - val_loss: 0.7271 - val_accuracy: 0.9106
# Epoch 79/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3062 - accuracy: 0.9330 - val_loss: 0.5549 - val_accuracy: 0.9106
# Epoch 80/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3112 - accuracy: 0.9330 - val_loss: 0.4923 - val_accuracy: 0.9106
# Epoch 81/100
# 63/63 [==============================] - 1s 16ms/step - loss: 0.3494 - accuracy: 0.9330 - val_loss: 0.6648 - val_accuracy: 0.9106
# Epoch 82/100
# 63/63 [==============================] - 1s 12ms/step - loss: 0.2915 - accuracy: 0.9330 - val_loss: 0.8849 - val_accuracy: 0.9106
# Epoch 83/100
# 63/63 [==============================] - 1s 14ms/step - loss: 0.2989 - accuracy: 0.9330 - val_loss: 0.7538 - val_accuracy: 0.9106
# Epoch 84/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2977 - accuracy: 0.9330 - val_loss: 0.5213 - val_accuracy: 0.9106
# Epoch 85/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2862 - accuracy: 0.9330 - val_loss: 0.6664 - val_accuracy: 0.9106
# Epoch 86/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3003 - accuracy: 0.9330 - val_loss: 2.3150 - val_accuracy: 0.9106
# Epoch 87/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3082 - accuracy: 0.9330 - val_loss: 0.9556 - val_accuracy: 0.9106
# Epoch 88/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3083 - accuracy: 0.9330 - val_loss: 0.5539 - val_accuracy: 0.9106
# Epoch 89/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2986 - accuracy: 0.9325 - val_loss: 0.6197 - val_accuracy: 0.9106
# Epoch 90/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3255 - accuracy: 0.9330 - val_loss: 0.4487 - val_accuracy: 0.9106
# Epoch 91/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2875 - accuracy: 0.9330 - val_loss: 0.9802 - val_accuracy: 0.9106
# Epoch 92/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3076 - accuracy: 0.9330 - val_loss: 0.4001 - val_accuracy: 0.9106
# Epoch 93/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3077 - accuracy: 0.9330 - val_loss: 1.0934 - val_accuracy: 0.9106
# Epoch 94/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3194 - accuracy: 0.9330 - val_loss: 1.0344 - val_accuracy: 0.9106
# Epoch 95/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3072 - accuracy: 0.9330 - val_loss: 0.9465 - val_accuracy: 0.9106
# Epoch 96/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3247 - accuracy: 0.9330 - val_loss: 0.5548 - val_accuracy: 0.9106
# Epoch 97/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3036 - accuracy: 0.9325 - val_loss: 0.4481 - val_accuracy: 0.9106
# Epoch 98/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3150 - accuracy: 0.9330 - val_loss: 0.7656 - val_accuracy: 0.9106
# Epoch 99/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3246 - accuracy: 0.9320 - val_loss: 0.3994 - val_accuracy: 0.9106
# Epoch 100/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3027 - accuracy: 0.9330 - val_loss: 0.4977 - val_accuracy: 0.9106

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()

# %%
# Test Up and Down labeling method

# %%
data.head()
# Out:
#             Yesterday  Open  Last  ...  Number Traded  Volume  Value Traded
# Date                               ...
# 2008-12-07        871   845   845  ...              1    1161        981045
# 2009-02-01        871   845   845  ...              7   31464      26587080
# 2009-02-09        861   836   836  ...              2    2000       1672000
# 2009-02-17        860   835   835  ...              1     100         83500
# 2009-03-08        860   835   835  ...              1      25         20875
#
# [5 rows x 10 columns]

# %%
# labeling Up or Down

ud_labels = []

for i in range(1, len(data.Last)):
    if data.Last[i] < data.Last[i-1]:
        ud_labels.append(0) # 0 = Down
    else:
        ud_labels.append(1) # 1 = Up
        
# This method miss first row from data, you should remove first row then train it

# %%
ud_labels = ud_labels[58:-6]
len(ud_labels)
# Out:
# 2235

# %%
len(pictures)
# Out:
# 2235

# %%
# Divide the data into training and validation data
split_time = 2000
y_train = ud_labels[:split_time]
x_train = pictures[:split_time]
y_valid = ud_labels[split_time:]
x_valid = pictures[split_time:]

y_train = np.array(y_train)
x_train = np.array(x_train)
y_valid = np.array(y_valid)
x_valid = np.array(x_valid)

#y_train = tf.keras.utils.to_categorical(y_train, 2)
#y_valid = tf.keras.utils.to_categorical(y_valid, 2)

# %%
# Create and train the model
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(10, 10, 1)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='softmax')
])

model.summary()

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_52 (Conv2D)          (None, 8, 8, 32)          320
#
#  conv2d_53 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_54 (Conv2D)          (None, 4, 4, 128)         73856
#
#  conv2d_55 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_13 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_26 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_13 (Flatten)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 128)               16512
#
#  dropout_27 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 256,897
# Trainable params: 256,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 63/63 [==============================] - 2s 13ms/step - loss: 2.0808 - accuracy: 0.5150 - val_loss: 0.7068 - val_accuracy: 0.5234
# Epoch 2/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7359 - accuracy: 0.5150 - val_loss: 0.6893 - val_accuracy: 0.5234
# Epoch 3/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7038 - accuracy: 0.5150 - val_loss: 0.7971 - val_accuracy: 0.5234
# Epoch 4/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7066 - accuracy: 0.5150 - val_loss: 0.6953 - val_accuracy: 0.5234
# Epoch 5/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7130 - accuracy: 0.5150 - val_loss: 0.6879 - val_accuracy: 0.5234
# Epoch 6/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7073 - accuracy: 0.5150 - val_loss: 0.6923 - val_accuracy: 0.5234
# Epoch 7/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6976 - accuracy: 0.5150 - val_loss: 0.6905 - val_accuracy: 0.5234
# Epoch 8/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7032 - accuracy: 0.5150 - val_loss: 0.6962 - val_accuracy: 0.5234
# Epoch 9/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7005 - accuracy: 0.5150 - val_loss: 0.7144 - val_accuracy: 0.5234
# Epoch 10/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7022 - accuracy: 0.5150 - val_loss: 0.6919 - val_accuracy: 0.5234
# Epoch 11/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6992 - accuracy: 0.5150 - val_loss: 0.6900 - val_accuracy: 0.5234
# Epoch 12/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6951 - accuracy: 0.5150 - val_loss: 0.6884 - val_accuracy: 0.5234
# Epoch 13/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6958 - accuracy: 0.5150 - val_loss: 0.6886 - val_accuracy: 0.5234
# Epoch 14/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6963 - accuracy: 0.5150 - val_loss: 0.6846 - val_accuracy: 0.5234
# Epoch 15/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6966 - accuracy: 0.5150 - val_loss: 0.6901 - val_accuracy: 0.5234
# Epoch 16/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6929 - accuracy: 0.5150 - val_loss: 0.7187 - val_accuracy: 0.5234
# Epoch 17/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6971 - accuracy: 0.5150 - val_loss: 0.6864 - val_accuracy: 0.5234
# Epoch 18/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6965 - accuracy: 0.5150 - val_loss: 0.6867 - val_accuracy: 0.5234
# Epoch 19/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6946 - accuracy: 0.5150 - val_loss: 0.6890 - val_accuracy: 0.5234
# Epoch 20/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6947 - accuracy: 0.5150 - val_loss: 0.6975 - val_accuracy: 0.5234
# Epoch 21/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6946 - accuracy: 0.5150 - val_loss: 0.7008 - val_accuracy: 0.5234
# Epoch 22/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6969 - accuracy: 0.5150 - val_loss: 0.6833 - val_accuracy: 0.5234
# Epoch 23/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6949 - accuracy: 0.5150 - val_loss: 0.6892 - val_accuracy: 0.5234
# Epoch 24/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6945 - accuracy: 0.5150 - val_loss: 0.6873 - val_accuracy: 0.5234
# Epoch 25/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.5150 - val_loss: 0.7065 - val_accuracy: 0.5234
# Epoch 26/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6908 - accuracy: 0.5150 - val_loss: 0.7538 - val_accuracy: 0.5234
# Epoch 27/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6964 - accuracy: 0.5150 - val_loss: 0.6869 - val_accuracy: 0.5234
# Epoch 28/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6918 - accuracy: 0.5150 - val_loss: 0.6854 - val_accuracy: 0.5234
# Epoch 29/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6914 - accuracy: 0.5150 - val_loss: 0.6824 - val_accuracy: 0.5234
# Epoch 30/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6920 - accuracy: 0.5150 - val_loss: 0.6852 - val_accuracy: 0.5234
# Epoch 31/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6906 - accuracy: 0.5150 - val_loss: 0.6856 - val_accuracy: 0.5234
# Epoch 32/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6913 - accuracy: 0.5150 - val_loss: 0.6895 - val_accuracy: 0.5234
# Epoch 33/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6911 - accuracy: 0.5150 - val_loss: 0.6876 - val_accuracy: 0.5234
# Epoch 34/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6881 - accuracy: 0.5150 - val_loss: 0.6875 - val_accuracy: 0.5234
# Epoch 35/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.5150 - val_loss: 0.6926 - val_accuracy: 0.5234
# Epoch 36/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6864 - accuracy: 0.5150 - val_loss: 0.9394 - val_accuracy: 0.5234
# Epoch 37/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.5150 - val_loss: 0.6942 - val_accuracy: 0.5234
# Epoch 38/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6847 - accuracy: 0.5150 - val_loss: 0.7244 - val_accuracy: 0.5234
# Epoch 39/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6870 - accuracy: 0.5150 - val_loss: 0.7056 - val_accuracy: 0.5234
# Epoch 40/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6872 - accuracy: 0.5150 - val_loss: 0.6952 - val_accuracy: 0.5234
# Epoch 41/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6862 - accuracy: 0.5150 - val_loss: 0.6966 - val_accuracy: 0.5234
# Epoch 42/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6864 - accuracy: 0.5150 - val_loss: 0.7098 - val_accuracy: 0.5234
# Epoch 43/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6852 - accuracy: 0.5150 - val_loss: 0.7151 - val_accuracy: 0.5234
# Epoch 44/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6824 - accuracy: 0.5150 - val_loss: 0.7428 - val_accuracy: 0.5234
# Epoch 45/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6835 - accuracy: 0.5150 - val_loss: 0.8572 - val_accuracy: 0.5234
# Epoch 46/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6882 - accuracy: 0.5150 - val_loss: 0.7728 - val_accuracy: 0.5234
# Epoch 47/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6816 - accuracy: 0.5150 - val_loss: 0.7347 - val_accuracy: 0.5234
# Epoch 48/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6849 - accuracy: 0.5150 - val_loss: 0.7397 - val_accuracy: 0.5234
# Epoch 49/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6802 - accuracy: 0.5150 - val_loss: 0.7788 - val_accuracy: 0.5234
# Epoch 50/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6835 - accuracy: 0.5150 - val_loss: 0.7203 - val_accuracy: 0.5234
# Epoch 51/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6775 - accuracy: 0.5150 - val_loss: 0.8393 - val_accuracy: 0.5234
# Epoch 52/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6800 - accuracy: 0.5150 - val_loss: 0.7288 - val_accuracy: 0.5234
# Epoch 53/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6791 - accuracy: 0.5150 - val_loss: 0.7587 - val_accuracy: 0.5234
# Epoch 54/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6830 - accuracy: 0.5150 - val_loss: 0.9417 - val_accuracy: 0.5234
# Epoch 55/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6785 - accuracy: 0.5150 - val_loss: 0.7584 - val_accuracy: 0.5234
# Epoch 56/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6816 - accuracy: 0.5150 - val_loss: 0.7742 - val_accuracy: 0.5234
# Epoch 57/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6784 - accuracy: 0.5150 - val_loss: 0.7617 - val_accuracy: 0.5234
# Epoch 58/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6793 - accuracy: 0.5150 - val_loss: 0.7958 - val_accuracy: 0.5234
# Epoch 59/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6783 - accuracy: 0.5150 - val_loss: 0.8000 - val_accuracy: 0.5234
# Epoch 60/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6740 - accuracy: 0.5150 - val_loss: 0.9864 - val_accuracy: 0.5234
# Epoch 61/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6817 - accuracy: 0.5150 - val_loss: 0.8023 - val_accuracy: 0.5234
# Epoch 62/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6778 - accuracy: 0.5150 - val_loss: 0.8539 - val_accuracy: 0.5234
# Epoch 63/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6790 - accuracy: 0.5150 - val_loss: 0.8712 - val_accuracy: 0.5234
# Epoch 64/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6800 - accuracy: 0.5150 - val_loss: 0.8026 - val_accuracy: 0.5234
# Epoch 65/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6741 - accuracy: 0.5150 - val_loss: 0.7814 - val_accuracy: 0.5234
# Epoch 66/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6711 - accuracy: 0.5150 - val_loss: 0.8402 - val_accuracy: 0.5234
# Epoch 67/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6710 - accuracy: 0.5150 - val_loss: 0.9422 - val_accuracy: 0.5234
# Epoch 68/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6743 - accuracy: 0.5150 - val_loss: 0.9074 - val_accuracy: 0.5234
# Epoch 69/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6707 - accuracy: 0.5150 - val_loss: 0.9718 - val_accuracy: 0.5234
# Epoch 70/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6736 - accuracy: 0.5150 - val_loss: 0.9881 - val_accuracy: 0.5234
# Epoch 71/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6680 - accuracy: 0.5150 - val_loss: 0.8888 - val_accuracy: 0.5234
# Epoch 72/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6768 - accuracy: 0.5150 - val_loss: 1.1212 - val_accuracy: 0.5234
# Epoch 73/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6771 - accuracy: 0.5150 - val_loss: 0.8138 - val_accuracy: 0.5234
# Epoch 74/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6709 - accuracy: 0.5150 - val_loss: 1.1233 - val_accuracy: 0.5234
# Epoch 75/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6702 - accuracy: 0.5150 - val_loss: 0.7752 - val_accuracy: 0.5234
# Epoch 76/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6681 - accuracy: 0.5150 - val_loss: 1.0014 - val_accuracy: 0.5234
# Epoch 77/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6676 - accuracy: 0.5150 - val_loss: 0.8645 - val_accuracy: 0.5234
# Epoch 78/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6657 - accuracy: 0.5150 - val_loss: 0.9856 - val_accuracy: 0.5234
# Epoch 79/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6729 - accuracy: 0.5150 - val_loss: 0.9851 - val_accuracy: 0.5234
# Epoch 80/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6711 - accuracy: 0.5150 - val_loss: 1.0276 - val_accuracy: 0.5234
# Epoch 81/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6626 - accuracy: 0.5150 - val_loss: 0.8807 - val_accuracy: 0.5234
# Epoch 82/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6643 - accuracy: 0.5150 - val_loss: 0.8066 - val_accuracy: 0.5234
# Epoch 83/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6664 - accuracy: 0.5150 - val_loss: 0.8445 - val_accuracy: 0.5234
# Epoch 84/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6758 - accuracy: 0.5150 - val_loss: 0.9140 - val_accuracy: 0.5234
# Epoch 85/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6711 - accuracy: 0.5150 - val_loss: 0.8863 - val_accuracy: 0.5234
# Epoch 86/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6665 - accuracy: 0.5150 - val_loss: 0.9558 - val_accuracy: 0.5234
# Epoch 87/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6580 - accuracy: 0.5150 - val_loss: 0.9628 - val_accuracy: 0.5234
# Epoch 88/100
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6705 - accuracy: 0.5150 - val_loss: 1.1465 - val_accuracy: 0.5234
# Epoch 89/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6619 - accuracy: 0.5150 - val_loss: 0.9412 - val_accuracy: 0.5234
# Epoch 90/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6613 - accuracy: 0.5150 - val_loss: 1.3472 - val_accuracy: 0.5234
# Epoch 91/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6595 - accuracy: 0.5150 - val_loss: 1.1100 - val_accuracy: 0.5234
# Epoch 92/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6604 - accuracy: 0.5150 - val_loss: 1.5410 - val_accuracy: 0.5234
# Epoch 93/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6620 - accuracy: 0.5150 - val_loss: 0.8916 - val_accuracy: 0.5234
# Epoch 94/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6662 - accuracy: 0.5150 - val_loss: 0.8337 - val_accuracy: 0.5234
# Epoch 95/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6692 - accuracy: 0.5150 - val_loss: 1.0356 - val_accuracy: 0.5234
# Epoch 96/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6652 - accuracy: 0.5150 - val_loss: 0.9403 - val_accuracy: 0.5234
# Epoch 97/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6597 - accuracy: 0.5150 - val_loss: 2.1569 - val_accuracy: 0.5234
# Epoch 98/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6754 - accuracy: 0.5150 - val_loss: 0.8633 - val_accuracy: 0.5234
# Epoch 99/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6856 - accuracy: 0.5150 - val_loss: 1.0752 - val_accuracy: 0.5234
# Epoch 100/100
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6554 - accuracy: 0.5150 - val_loss: 0.8205 - val_accuracy: 0.5234

# %%
# Ploting accuracy and loss diagrams
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure().add_subplot(xlabel='Epochs', ylabel='Accuracy')
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)

plt.figure().add_subplot(xlabel='Epochs', ylabel='Loss')
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend(loc=0)

plt.show()
